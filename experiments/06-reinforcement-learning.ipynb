# %%
import numpy as np

# Define the H_i(a) values for different actions
H = np.array([1.0, 2.0, 3.0, 4.0]) - 2 # Example values for 4 actions

# Calculate e^(H_i(a)) for all actions
exp_H = np.exp(H)

# Calculate the sum of e^(H_i(a)) for all actions
sum_exp_H = np.sum(exp_H)

# Calculate π_i(a) for each action
pi = exp_H / sum_exp_H

print("H_i(a) values:", H)
print("e^(H_i(a)) values:", exp_H)
print("Sum of e^(H_i(a)):", sum_exp_H)
print("π_i(a) probabilities:", pi)
print("Sum of probabilities:", np.sum(pi))  # Should be very close to 1.0
# Out:
# H_i(a) values: [-1.  0.  1.  2.]
# e^(H_i(a)) values: [0.36787944 1.         2.71828183 7.3890561 ]
# Sum of e^(H_i(a)): 11.475217368561138
# π_i(a) probabilities: [0.0320586  0.08714432 0.23688282 0.64391426]
# Sum of probabilities: 1.0

# %%
# Exercise 2.9: Soft-max distribution for two actions

import numpy as np
import matplotlib.pyplot as plt

def softmax(H):
    exp_H = np.exp(H)
    return exp_H / np.sum(exp_H)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Generate a range of H1 - H2 values
x = np.linspace(-10, 10, 1000)

# Calculate soft-max probabilities
softmax_probs = softmax(np.vstack([x, np.zeros_like(x)]))

# Calculate sigmoid probabilities
sigmoid_probs = sigmoid(x)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(x, softmax_probs[0], label='Soft-max π(a1)')
plt.plot(x, sigmoid_probs, label='Sigmoid', linestyle='--')
plt.xlabel('H1 - H2')
plt.ylabel('Probability')
plt.title('Soft-max vs Sigmoid for Two Actions')
plt.legend()
plt.grid(True)
plt.show()

# Verify that the probabilities are the same
np.testing.assert_allclose(softmax_probs[0], sigmoid_probs, atol=1e-6)
print("The soft-max distribution is equivalent to the sigmoid function for two actions.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 34
#      31 plt.show()
#      33 # Verify that the probabilities are the same
# ---> 34 np.testing.assert_allclose(softmax_probs[0], sigmoid_probs, atol=1e-6)
#      35 print("The soft-max distribution is equivalent to the sigmoid function for two actions.")
#
#     [... skipping hidden 1 frame]
#
# File /opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# ...
