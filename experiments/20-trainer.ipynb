# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>

# %%
import asyncio
import json
from lib.clue import Clue, DeductiveSolver
from lib.rl.episode import Episode, EpisodeCompletion
from lib.rl.ppo import PPOLoss
from lib.rl.recipe import ComponentConfig, TuneRecipeConfig
from lib.rl.trainer import ExploreOptions, Trainer, vLLMConfig
from lib.utils import return_exception
import random
import re
import torch
from torchtune.models.llama3_1 import llama3_1_8b
from typing import Literal, Optional

with open("./data/chain-of-thought-examples.json") as f:
    chain_of_thought_examples: list[dict[str, str]] = json.load(f)


def get_variable_difficulty_game(
    return_first_solver_as_winner: Optional[bool] = None,
) -> Clue:
    num_players = random.randint(3, 6)
    num_weapons = max(
        3,
        min(
            num_players + random.randint(-1, 5),
            len(Clue.weapons),
        ),
    )
    num_suspects = min(
        num_weapons + random.randint(0, num_weapons - 1), len(Clue.suspects)
    )
    num_rooms = min(num_suspects + random.randint(0, num_suspects - 2), len(Clue.rooms))
    elements = {
        "suspect": random.sample(Clue.suspects, k=num_suspects),
        "weapon": random.sample(Clue.weapons, k=num_weapons),
        "room": random.sample(Clue.rooms, k=num_rooms),
    }
    if random.random() < 0.1:
        elements["motive"] = random.sample(
            Clue.motives,
            k=max(3, min(num_weapons + random.randint(-1, 3), len(Clue.motives))),
        )
    if random.random() < 0.1:
        frequency = random.choice([0.25, 0.5, 1.0])
        start = 24.0 - frequency
        end = 0.0
        for _ in range(random.randint(1, num_weapons + 1)):
            if random.randint(0, 1):
                end += frequency
            else:
                start -= frequency

        def format_time(time: float) -> str:
            return f"{int(time):02d}:{int(60 * (time - int(time))):02d}"

        elements["time"] = Clue.get_times(
            format_time(start), format_time(end), f"{int(frequency * 60)}min"
        )
    game = Clue(
        num_players=num_players,
        elements=elements,
    )
    difficulty_level = num_players + random.randint(-2, 3)
    # print(f"Players: {num_players}")
    # for element in elements:
    #     print(f"{element.capitalize()}: {len(elements[element])}")
    # print(f"Difficulty level: {difficulty_level}")
    return game.play(
        deductive_solver=DeductiveSolver(
            # note_cards_in_hand=False,
            # note_responses_to_suggestions=False,
            # note_cards_that_players_do_not_have=False,
            # check_unique_card_placement_constraints=False,
            # check_player_hand_size_constraints=False,
            check_solution_has_one_and_only_one_card_per_element=difficulty_level > 1,
            check_one_of_constraints=difficulty_level > 2,
            check_inverse_one_of_constraints=difficulty_level > 3,
            merge_and_check_disjoint_inverse_one_of_constraints=difficulty_level > 4,
            exhaustively_test_possible_assignments=False,
        ),
        cp_solver_max_solve_time_per_turn=0.01,
        check_cp_solver_grid=False,
        check_if_deductive_solver_and_cp_solver_grids_match=False,
        return_first_solver_as_winner=(
            bool(random.randint(0, 1))
            if return_first_solver_as_winner is None
            else return_first_solver_as_winner
        ),
        print_playthrough=False,
        max_turns=100,
    )


def get_easy_game(return_first_solver_as_winner: Optional[bool] = None) -> Clue:
    game = Clue(
        num_players=3,
        elements={
            "suspect": random.sample(Clue.suspects, k=3),
            "weapon": random.sample(Clue.weapons, k=3),
            "room": random.sample(Clue.rooms, k=3),
            # "motive": random.sample(Clue.motives, k=3),
            # "time": Clue.get_times("21:00", "03:00", "1h"),
        },
    )
    game.play(
        deductive_solver=DeductiveSolver(
            # note_cards_in_hand=False,
            # note_responses_to_suggestions=False,
            # note_cards_that_players_do_not_have=False,
            # check_unique_card_placement_constraints=False,
            # check_player_hand_size_constraints=False,
            check_solution_has_one_and_only_one_card_per_element=False,
            check_one_of_constraints=False,
            check_inverse_one_of_constraints=False,
            merge_and_check_disjoint_inverse_one_of_constraints=False,
            exhaustively_test_possible_assignments=False,
        ),
        cp_solver_max_solve_time_per_turn=0.01,
        check_cp_solver_grid=False,
        check_if_deductive_solver_and_cp_solver_grids_match=False,
        return_first_solver_as_winner=return_first_solver_as_winner or False,
        print_playthrough=False,
        max_turns=100,
    )
    return game


@return_exception
def sample_random_episode(
    difficulty: Literal["easy", "variable"] = "variable",
    example_probability: float = 0.0,
    max_prompt_characters: int = 8192,
    reward_follow_up_completion: bool = True,
    return_first_solver_as_winner: Optional[bool] = None,
) -> Episode:
    while True:
        try:
            game = (
                get_easy_game if difficulty == "easy" else get_variable_difficulty_game
            )(return_first_solver_as_winner=return_first_solver_as_winner)
            prompt, follow_up, solution = game.get_prompt_and_follow_up_and_solution()
        except ValueError:
            continue
        if len(prompt) <= max_prompt_characters:
            break

    async def reward_completion(completion: EpisodeCompletion) -> EpisodeCompletion:
        if len(completion.messages) == 2:
            follow_up_completion = await completion.follow_up(
                messages=[
                    {"role": "user", "content": follow_up},
                ],
                max_tokens=10
                + len("\n".join(f"{key}: {value}" for key, value in solution.items()))
                // 2,
            )
        else:
            follow_up_completion = completion
        answer = follow_up_completion.last_assistant_message.get("content")
        assert isinstance(answer, str)
        if reward_follow_up_completion:
            completion = follow_up_completion
        completion.reward = sum(
            [
                bool(
                    # Find first match of key followed by colon and capture following text
                    (
                        match := re.search(
                            rf"{key}: ([A-Za-z \.:-]+)",
                            answer,
                            re.IGNORECASE,
                        )
                    )
                    # Check if captured group matches expected value
                    and match.group(1).strip().lower() == value.strip().lower()
                )
                for key, value in solution.items()
            ]
        ) / len(solution)
        completion.reward -= (
            completion.all_absent_stop_tokens
            / (3 if reward_follow_up_completion else 2)
            / len(solution)
        )
        return completion

    async def on_sample(completions: list[EpisodeCompletion]) -> None:
        for completion in await asyncio.gather(
            *[reward_completion(completion) for completion in completions]
        ):
            completion.commit()

    example = random.choice(chain_of_thought_examples)

    return Episode(
        messages=[{"role": "user", "content": prompt}],
        examples=lambda: (
            [
                {"role": "user", "content": example["prompt"]},
                {
                    "role": "assistant",
                    "content": example["chain_of_thought"]
                    + (example["answer"] and f"\n\n---\n\n{example['answer']}"),
                },
            ]
            if random.random() < example_probability
            else []
        ),
        on_sample=on_sample,
    )


def train_episodes():
    while True:
        yield sample_random_episode()


model_name = "rl32"

trainer = Trainer(
    base_model="NousResearch/Hermes-2-Theta-Llama-3-8B",
    output_dir=f"./models/{model_name}",
    explore_options=ExploreOptions(
        iterations=7,
        num_parents=6,
        branch_factor=3,
        patience=5,
        sample_probability_power=None,
        sampling_kwargs={"max_tokens": 1024},
    ),
    train_episodes=train_episodes(),
    episodes_per_iteration=64 * torch.cuda.device_count(),
    max_mask_sequence_batch_size=1,
    val_episodes=(
        sample_random_episode() for _ in range(8 * torch.cuda.device_count())
    ),
    val_patience=15,
    val_samples_per_episode=3,
    val_sampling_kwargs={"max_tokens": 1024},
    tune_model=llama3_1_8b,
    tune_model_type="LLAMA3",
    tune_recipe_config=TuneRecipeConfig(
        seed=42,
        shuffle=True,
        num_output_chunks=4,
        resume_from_checkpoint=False,
        batch_size=1,
        epochs=1,
        max_steps_per_epoch=8,
        optimizer=ComponentConfig(
            "torch.optim.AdamW",
            # "bitsandbytes.optim.PagedAdamW8bit",
            # "bitsandbytes.optim.AdamW",
            # params=PLACEHOLDER,
            lr=4e-6,
            fused=True,
        ),
        loss=ComponentConfig(
            PPOLoss,
            policy_coef=0.0,
            clip_epsilon=0.2,
            unclipped_policy_coef=0.0,
            tanh_log_policy_coef=0.8,
            value_coef=0.0,
            entropy_coef=0.0,
            entropy_target=0.6,
            entropy_target_coef=0.1,
            kl_coef=0.1,
            weighted_entropy_coef=0.2,
            weighted_kl_coef=0.0,
            weighted_ce_coef=0.0,
            normalize_values=False,
            normalize_advantages=False,
        ),
        compile=False,
        optimizer_in_bwd=False,
        gradient_accumulation_steps=1,
        enable_activation_checkpointing=True,
        enable_activation_offloading=False,
        custom_sharded_layers=["tok_embeddings", "output"],
        log_every_n_steps=1,
        log_peak_memory_stats=True,
    ),
    # tune_run=False,
    tune_sequence_length=16384,
    vllm_config=vLLMConfig(
        env={"VLLM_ALLOW_LONG_MAX_MODEL_LEN": "1"},
        kwargs=dict(
            block_size=32,
            disable_log_requests=True,
            enable_prefix_caching=True,
            enforce_eager=True,
            gpu_memory_utilization=0.9,
            max_model_len=16384,
            max_num_seqs=512,
            max_num_batched_tokens=16384 * 4,
            preemption_mode="swap",
            return_tokens_as_token_ids=True,
            swap_space=32,
        ),
        max_concurrent_samples=512,
        timeout=120 + 15 * torch.cuda.device_count(),
    ),
    wandb_kwargs=dict(
        name=model_name,
        id=model_name,
    ),
)
# Out:
# Resuming from /home/ubuntu/atreides/experiments/models/rl32/0001
# INFO 12-13 23:48:43 llm_engine.py:237] Initializing an LLM engine (v0.6.3.post1) with config: model='NousResearch/Hermes-2-Theta-Llama-3-8B', speculative_config=None, tokenizer='NousResearch/Hermes-2-Theta-Llama-3-8B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=NousResearch/Hermes-2-Theta-Llama-3-8B, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, mm_processor_kwargs=None)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: bradhilton. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/home/ubuntu/atreides/experiments/wandb/run-20241213_234844-rl32</code>
# Resuming run <strong><a href='https://wandb.ai/bradhilton/atreides-experiments/runs/rl32' target="_blank">rl32</a></strong> to <a href='https://wandb.ai/bradhilton/atreides-experiments' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bradhilton/atreides-experiments' target="_blank">https://wandb.ai/bradhilton/atreides-experiments</a>
#  View run at <a href='https://wandb.ai/bradhilton/atreides-experiments/runs/rl32' target="_blank">https://wandb.ai/bradhilton/atreides-experiments/runs/rl32</a>

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
await trainer.get_completion_sampler()

# %%
# %%prun
asyncio.run(trainer.eval("val", verbosity=0))
# Out:
#          136009487 function calls (135418141 primitive calls) in 336.141 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   3027164   58.511    0.000  120.968    0.000 type_check.py:403(nan_to_num)
#      7818   31.818    0.004  248.848    0.032 clue.py:564(fill_grid)
#   2693598   20.984    0.000   29.477    0.000 nanfunctions.py:68(_replace_nan)
#   5736706   18.558    0.000   39.240    0.000 fromnumeric.py:71(_wrapreduction)
#   5816745   16.781    0.000   16.781    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   5728716   15.323    0.000   57.947    0.000 fromnumeric.py:2177(sum)
#     526/0   14.174    0.027    0.000          threading.py:323(wait)
#   3027164   11.495    0.000   11.495    0.000 ufunclike.py:71(isposinf)
#   3027164   10.220    0.000   26.643    0.000 type_check.py:393(_getmaxmin)
#   2693598    9.249    0.000   66.486    0.000 nanfunctions.py:623(nansum)
# 15016592/14969722    9.046    0.000    9.749    0.000 {built-in method builtins.isinstance}
#   3027164    8.107    0.000    8.107    0.000 ufunclike.py:142(isneginf)
#   5720848    7.660    0.000    7.660    0.000 {built-in method numpy.array}
#  11782772    7.045    0.000    7.045    0.000 multiarray.py:1080(copyto)
# 3031282/3031281    6.371    0.000   10.288    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#      1408    5.334    0.004   10.333    0.007 {method 'validate_python' of 'pydantic_core._pydantic_core.SchemaValidator' objects}
#   4420306    5.248    0.000    5.248    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#   8839857    5.137    0.000    5.207    0.000 {built-in method builtins.issubclass}
#       256    4.572    0.018    4.589    0.018 decoder.py:344(raw_decode)
#   5917033    4.323    0.000    4.323    0.000 {method 'items' of 'dict' objects}
#       351    4.195    0.012    8.938    0.025 sock_client.py:242(_read_packet_bytes)
#   3043072    3.986    0.000    6.233    0.000 getlimits.py:484(__new__)
#   2001739    3.858    0.000    5.593    0.000 _model_construction.py:268(__instancecheck__)
#   6054328    3.492    0.000    3.492    0.000 ufunclike.py:14(_dispatcher)
#   5076188    3.301    0.000    3.306    0.000 {built-in method builtins.hasattr}
#   5728716    3.227    0.000    3.227    0.000 fromnumeric.py:2172(_sum_dispatcher)
#       384    2.481    0.006    2.481    0.006 {built-in method torch.log}
#   3184277    2.350    0.000    2.350    0.000 {method 'get' of 'dict' objects}
#    2320/3    2.186    0.001    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#     75084    1.921    0.000    3.699    0.000 clue.py:502(add_one_of_constraints)
#       384    1.902    0.005    1.902    0.005 {built-in method torch.exp}
#   3027164    1.825    0.000    1.825    0.000 type_check.py:399(_nan_to_num_dispatcher)
#    566/70    1.785    0.003    0.168    0.002 {method 'poll' of 'select.epoll' objects}
#   2693598    1.567    0.000    1.567    0.000 nanfunctions.py:618(_nansum_dispatcher)
#   2698536    1.507    0.000    1.507    0.000 {built-in method numpy.asanyarray}
#      2819    1.290    0.000    1.404    0.000 cp_model.py:1501(add_linear_expression_in_domain)
#    533019    1.091    0.000    1.806    0.000 typing.py:2340(get_origin)
#   1513582    0.864    0.000    0.864    0.000 multiarray.py:153(concatenate)
#  7816/547    0.860    0.000   13.183    0.024 clue.py:430(grid)
#     510/0    0.734    0.001    0.000          threading.py:637(wait)
# 189440/39168    0.606    0.000    2.799    0.000 typing.py:407(_eval_type)
#    242245    0.585    0.000    0.910    0.000 utils.py:45(get_token)
# 75264/256    0.512    0.000    7.769    0.030 _transform.py:288(_async_transform_recursive)
#     13524    0.486    0.000    0.486    0.000 {built-in method torch.tensor}
#    690232    0.466    0.000    0.466    0.000 {method 'append' of 'list' objects}
#    496344    0.457    0.000    0.461    0.000 clue.py:550(<genexpr>)
#     15908    0.442    0.000    0.707    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#     344/1    0.433    0.001    0.976    0.976 sock_client.py:286(read_server_response)
#     28242    0.401    0.000    0.733    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#  1399/348    0.394    0.000    2.162    0.006 {method 'recv' of '_socket.socket' objects}
#      2819    0.384    0.000    0.726    0.000 cp_model.py:344(get_integer_var_value_map)
# 620389/613460    0.371    0.000    0.379    0.000 {built-in method builtins.len}
#     39170    0.355    0.000    0.953    0.000 typing.py:175(_type_check)
#       256    0.328    0.001   33.557    0.131 _response.py:388(parse)
#    340058    0.327    0.000    0.330    0.000 clue.py:535(<genexpr>)
#     26280    0.325    0.000    5.447    0.000 completion.py:260(entropy_sum)
#     30773    0.318    0.000    0.645    0.000 numeric.py:2378(array_equal)
#      6912    0.303    0.000    3.230    0.000 typing.py:2215(get_type_hints)
#    243013    0.290    0.000    1.200    0.000 completion.py:824(<genexpr>)
#    303770    0.281    0.000    0.281    0.000 {method 'decode' of 'bytes' objects}
#    300892    0.272    0.000    0.272    0.000 clue.py:526(<genexpr>)
#     39168    0.243    0.000    2.698    0.000 typing.py:916(_evaluate)
# 171264/87552    0.229    0.000    0.711    0.000 typing.py:430(<genexpr>)
#    163584    0.203    0.000    0.748    0.000 _typing.py:29(is_required_type)
# 88064/75264    0.193    0.000    1.039    0.000 _typing.py:40(strip_annotated_type)
#    155904    0.187    0.000    0.698    0.000 _typing.py:11(is_annotated_type)
# 16290/11091    0.184    0.000    1.699    0.000 {method 'join' of 'str' objects}
#     68907    0.182    0.000    0.311    0.000 typing.py:2370(get_args)
#    233975    0.178    0.000    0.178    0.000 {method 'isdisjoint' of 'set' objects}
#    310662    0.173    0.000    0.173    0.000 threading.py:1198(ident)
#    246366    0.170    0.000    0.170    0.000 {method 'startswith' of 'str' objects}
#     75520    0.167    0.000    0.935    0.000 _transform.py:111(_get_annotated_type)
#    143598    0.156    0.000    0.240    0.000 typing.py:1279(__eq__)
#    133230    0.154    0.000    0.240    0.000 typing.py:1592(__eq__)
#     329/1    0.153    0.000    1.003    1.003 router_sock.py:25(_read_message)
#     75264    0.140    0.000    0.323    0.000 typing.py:448(is_typeddict)
# 128518/128500    0.138    0.000    0.165    0.000 {built-in method builtins.getattr}
#      7818    0.132    0.000    0.244    0.000 clue.py:262(_successful_accusation)
#     10048    0.131    0.000    0.141    0.000 cp_model.py:846(__init__)
#     67840    0.128    0.000    0.415    0.000 _typing.py:25(is_union_type)
#       751    0.125    0.000    0.125    0.000 {method 'poll' of 'select.poll' objects}
# 50902/50858    0.123    0.000    0.431    0.000 random.py:242(_randbelow_with_getrandbits)
#    107085    0.121    0.000    0.343    0.000 <frozen abc>:117(__instancecheck__)
#    107085    0.119    0.000    0.221    0.000 {built-in method _abc._abc_instancecheck}
#     301/0    0.114    0.000    0.000          mailbox.py:128(_get_and_clear)
#      6800    0.114    0.000    0.282    0.000 _asyncio.py:1190(receive)
#     345/0    0.114    0.000    0.000          mailbox.py:125(_wait)
#     75264    0.112    0.000    0.176    0.000 utils.py:181(lenient_issubclass)
#  6912/512    0.109    0.000    7.713    0.015 _transform.py:379(_async_transform_typeddict)
#     57906    0.097    0.000    0.283    0.000 typing.py:392(inner)
#     48359    0.097    0.000    0.346    0.000 {method 'all' of 'numpy.ndarray' objects}
# 33293/4434    0.096    0.000    6.550    0.001 {built-in method builtins.sum}
#     501/0    0.095    0.000    0.000          nest_asyncio.py:100(_run_once)
#     68352    0.095    0.000    0.327    0.000 _typing.py:19(is_iterable_type)
# 76211/76117    0.091    0.000    0.167    0.000 <frozen abc>:121(__subclasscheck__)
#      72/1    0.089    0.001    0.023    0.023 clue.py:100(play)
#     68352    0.087    0.000    0.324    0.000 _typing.py:15(is_list_type)
#      1482    0.086    0.000    0.087    0.000 {method 'join' of 'bytes' objects}
#     43405    0.085    0.000    0.518    0.000 {built-in method builtins.next}
#     29215    0.083    0.000    0.226    0.000 clue.py:210(<genexpr>)
#     39168    0.079    0.000    0.467    0.000 {built-in method builtins.eval}
#     55206    0.078    0.000    0.177    0.000 completion.py:757(<genexpr>)
# 76211/76117    0.077    0.000    0.077    0.000 {built-in method _abc._abc_subclasscheck}
#     14121    0.076    0.000    0.105    0.000 threading.py:1535(enumerate)
#      2442    0.076    0.000    0.323    0.000 utils.py:641(assert_array_compare)
#     31680    0.075    0.000    0.275    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      7326    0.075    0.000    0.162    0.000 utils.py:661(func_assert_same_pos)
# 51936/12516    0.074    0.000    0.080    0.000 completion.py:219(leaves)
#     90432    0.071    0.000    0.072    0.000 cp_model.py:429(__hash__)
#     48395    0.071    0.000    0.250    0.000 _methods.py:61(_all)
#     30144    0.070    0.000    0.426    0.000 cp_model.py:444(__add__)
#     47724    0.069    0.000    0.120    0.000 clue.py:209(<genexpr>)
#      9472    0.066    0.000    0.118    0.000 typing.py:1636(__hash__)
#     44239    0.065    0.000    0.341    0.000 cp_model_helper.py:63(assert_is_int64)
#      7312    0.063    0.000    1.263    0.000 http11.py:216(_receive_event)
#     27325    0.063    0.000    0.110    0.000 cp_model.py:681(__init__)
#     54812    0.061    0.000    0.087    0.000 events.py:127(__lt__)
#     23433    0.061    0.000    0.173    0.000 typing.py:1492(__subclasscheck__)
#     22958    0.061    0.000    0.061    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      7818    0.059    0.000    0.069    0.000 numeric.py:341(full_like)
#     28158    0.059    0.000    0.310    0.000 completion.py:765(num_token_logprobs)
#     48348    0.058    0.000    0.058    0.000 {built-in method builtins.sorted}
#     48283    0.058    0.000    0.058    0.000 {method 'union' of 'set' objects}
#     30144    0.054    0.000    0.247    0.000 cp_model_helper.py:36(is_zero)
#     41298    0.054    0.000    0.180    0.000 completion.py:766(<genexpr>)
#      6770    0.054    0.000    0.203    0.000 _asyncio.py:391(__enter__)
#      5074    0.053    0.000    0.218    0.000 random.py:350(shuffle)
#     21548    0.053    0.000    0.071    0.000 contextlib.py:104(__init__)
# 26280/6570    0.053    0.000    5.559    0.001 completion.py:308(all_entropy_sum)
#     77182    0.052    0.000    0.052    0.000 {built-in method numpy.asarray}
#     39770    0.051    0.000    0.051    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#     31491    0.050    0.000    0.082    0.000 _models.py:94(encoding)
#     60288    0.050    0.000    0.050    0.000 {method 'append' of 'google._upb._message.RepeatedScalarContainer' objects}
#     66721    0.050    0.000    0.050    0.000 typing.py:213(_should_unflatten_callable_args)
#      6770    0.050    0.000    0.135    0.000 _asyncio.py:422(__exit__)
#      7437    0.048    0.000    0.119    0.000 _models.py:212(__getitem__)
#  4864/256    0.048    0.000   28.618    0.112 _models.py:448(construct_type)
#     39170    0.048    0.000    0.074    0.000 typing.py:166(_type_convert)
#      7818    0.047    0.000    0.080    0.000 numeric.py:274(full)
# 28158/8448    0.047    0.000    0.358    0.000 completion.py:768(all_num_token_logprobs)
#     72704    0.047    0.000    0.047    0.000 typing.py:251(is_union)
#     18567    0.046    0.000    0.065    0.000 events.py:36(__init__)
#     14124    0.046    0.000    0.069    0.000 _impl.py:25(current_async_library)
#     31680    0.046    0.000    0.200    0.000 _methods.py:47(_sum)
#     21544    0.046    0.000    0.221    0.000 contextlib.py:141(__exit__)
#    8336/0    0.045    0.000    0.000          tasks.py:308(__step_run_and_handle_result)
#     23433    0.044    0.000    0.217    0.000 typing.py:1221(__instancecheck__)
#      6800    0.044    0.000    0.727    0.000 anyio.py:23(read)
#    8336/0    0.043    0.000    0.000          tasks.py:291(__step)
#      8366    0.043    0.000    0.396    0.000 _tasks.py:95(fail_after)
#      7307    0.040    0.000    0.337    0.000 _connection.py:426(next_event)
#     57398    0.040    0.000    0.040    0.000 {method 'keys' of 'dict' objects}
#     77343    0.040    0.000    0.040    0.000 {method 'getrandbits' of '_random.Random' objects}
#       602    0.039    0.000    0.060    0.000 {method 'send' of '_socket.socket' objects}
#     41682    0.039    0.000    0.039    0.000 completion.py:756(_token_logprob_sequences)
#     57926    0.039    0.000    0.039    0.000 {method 'pop' of 'list' objects}
#     12320    0.039    0.000    0.084    0.000 base_events.py:813(_call_soon)
#       517    0.038    0.000    0.098    0.000 _headers.py:150(normalize_and_validate)
#      6790    0.037    0.000    1.141    0.000 http11.py:205(_receive_response_body)
#     19106    0.037    0.000    0.098    0.000 contextlib.py:299(helper)
#     21544    0.037    0.000    0.385    0.000 contextlib.py:132(__enter__)
#     19922    0.036    0.000    0.060    0.000 _utils.py:31(normalize_header_key)
#     54272    0.036    0.000    0.036    0.000 typing.py:1626(<genexpr>)
#     27648    0.034    0.000    0.381    0.000 _transform.py:126(_maybe_transform_key)
#      4690    0.034    0.000    0.133    0.000 _connection.py:260(_process_event)
#   14430/3    0.034    0.000    0.000    0.000 events.py:86(_run)
# 14980/13700    0.034    0.000    0.078    0.000 typing.py:1600(__hash__)
#      7954    0.034    0.000    0.080    0.000 numerictypes.py:357(issubdtype)
#   14430/3    0.033    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#      4679    0.032    0.000    0.103    0.000 {built-in method _heapq.heappop}
#     12319    0.031    0.000    0.123    0.000 base_events.py:784(call_soon)
#      1911    0.031    0.000    0.121    0.000 _models.py:64(__init__)
#     50902    0.030    0.000    0.030    0.000 {method 'bit_length' of 'int' objects}
#     40324    0.030    0.000    0.030    0.000 {method 'values' of 'dict' objects}
# 1154/1111    0.029    0.000    0.149    0.000 random.py:889(getrandbits)
#      3395    0.028    0.000    0.028    0.000 _receivebuffer.py:53(__iadd__)
#   1052/27    0.028    0.000    0.104    0.004 cp_model.py:1397(new_bool_var)
#       384    0.028    0.000    0.049    0.000 constraints.py:440(check)
#  1024/256    0.028    0.000   28.586    0.112 _models.py:203(construct)
#      7187    0.027    0.000    1.437    0.000 _models.py:971(aiter_raw)
#     16012    0.027    0.000    0.044    0.000 _models.py:27(enforce_bytes)
#      7187    0.027    0.000    1.482    0.000 _models.py:916(aiter_bytes)
# 36370/31497    0.027    0.000    0.038    0.000 {built-in method builtins.hash}
#      2442    0.026    0.000    0.408    0.000 contextlib.py:78(inner)
#      7307    0.026    0.000    0.173    0.000 _connection.py:398(_extract_next_receive_event)
#     15908    0.026    0.000    0.042    0.000 numerictypes.py:283(issubclass_)
#      5908    0.026    0.000   45.469    0.008 completion_sampler.py:138(sample_completions)
#     45863    0.025    0.000    0.025    0.000 typing.py:2183(cast)
#       674    0.025    0.000    0.153    0.000 connection_pool.py:230(_assign_requests_to_connections)
#     10450    0.025    0.000    0.095    0.000 {built-in method builtins.any}
# 8457/5530    0.025    0.000   37.047    0.007 _base_client.py:1541(_request)
#      6790    0.024    0.000    0.080    0.000 _readers.py:127(__call__)
#       261    0.024    0.000    0.024    0.000 {method 'connect' of '_socket.socket' objects}
#      8513    0.024    0.000    6.041    0.001 trainer.py:356(<genexpr>)
#       662    0.024    0.000    0.159    0.000 _urlparse.py:152(urlparse)
#     26763    0.024    0.000    0.024    0.000 {method 'get' of 'mappingproxy' objects}
#     32642    0.024    0.000    0.024    0.000 {built-in method _asyncio.current_task}
#      4680    0.023    0.000    0.090    0.000 base_events.py:766(call_at)
#     10671    0.023    0.000    0.048    0.000 _util.py:84(validate)
#      6534    0.023    0.000    0.043    0.000 _receivebuffer.py:77(maybe_extract_at_most)
#      1536    0.023    0.000    0.023    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#      2330    0.023    0.000   15.779    0.007 239833578.py:148(reward_completion)
#     12909    0.022    0.000    0.037    0.000 _urlparse.py:212(<genexpr>)
#     28232    0.022    0.000    0.022    0.000 {method 'encode' of 'str' objects}
#      7954    0.022    0.000    0.141    0.000 fromnumeric.py:2979(prod)
#      7090    0.021    0.000    0.134    0.000 _asyncio.py:528(_timeout)
#   567/501    0.021    0.000    1.761    0.004 selectors.py:451(select)
#        79    0.021    0.000    0.082    0.001 sock_client.py:123(_sendall_with_error_handle)
#      7424    0.021    0.000    0.037    0.000 typing.py:521(__getitem__)
#      3651    0.021    0.000    0.021    0.000 _receivebuffer.py:67(_extract)
#      5379    0.021    0.000    0.044    0.000 _asyncio.py:2294(create_cancel_scope)
#      6912    0.021    0.000    3.264    0.000 typing_extensions.py:1197(get_type_hints)
#      2424    0.019    0.000    0.054    0.000 clue.py:310(turn)
#      4690    0.019    0.000    0.028    0.000 _state.py:318(_fire_state_triggered_transitions)
#     30773    0.019    0.000    0.019    0.000 numeric.py:2374(_array_equal_dispatcher)
#     11476    0.019    0.000    0.074    0.000 _eventloop.py:154(get_async_backend)
#     23365    0.019    0.000    0.020    0.000 {method 'add' of 'set' objects}
#     11909    0.019    0.000    0.044    0.000 typing.py:1285(__hash__)
#      4510    0.019    0.000    0.042    0.000 trainer.py:334(<genexpr>)
#     31422    0.019    0.000    0.019    0.000 base_events.py:2010(get_debug)
#     11664    0.019    0.000    0.019    0.000 {method 'fullmatch' of 're.Pattern' objects}
#      6790    0.018    0.000    1.165    0.000 http11.py:337(__aiter__)
#    7800/0    0.018    0.000    0.000          {method 'send' of 'coroutine' objects}
#     20310    0.018    0.000    0.018    0.000 {method 'pop' of 'dict' objects}
#     30144    0.018    0.000    0.018    0.000 cp_model.py:875(index)
#      5524    0.018    0.000   44.960    0.008 completions.py:1620(create)
#       960    0.018    0.000    0.018    0.000 {method 'flush' of '_io.TextIOWrapper' objects}
#      4048    0.018    0.000    1.586    0.000 _models.py:908(aread)
#      8320    0.017    0.000    0.067    0.000 typing.py:113(get_origin)
#      4884    0.017    0.000    0.017    0.000 utils.py:722(<lambda>)
#     15944    0.017    0.000    0.017    0.000 {built-in method time.monotonic}
#      7818    0.017    0.000    0.017    0.000 {built-in method numpy.empty}
#      8682    0.017    0.000    0.036    0.000 tasks.py:653(sleep)
#       261    0.017    0.000    0.017    0.000 socket.py:221(__init__)
#      8448    0.016    0.000    5.933    0.001 completion.py:294(all_entropy)
#     14292    0.016    0.000    0.016    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#      4690    0.016    0.000    0.051    0.000 _state.py:275(process_event)
#     13899    0.016    0.000    0.164    0.000 _utils.py:152(is_mapping)
#     11286    0.016    0.000    0.028    0.000 base_events.py:733(time)
# 1154/1111    0.016    0.000    0.064    0.000 {built-in method posix.urandom}
#      4680    0.016    0.000    0.032    0.000 events.py:155(cancel)
#     19186    0.016    0.000    0.016    0.000 {method 'popleft' of 'collections.deque' objects}
#     22253    0.016    0.000    0.016    0.000 {method 'lower' of 'str' objects}
#      1334    0.016    0.000    0.555    0.000 http11.py:72(handle_async_request)
#     27325    0.015    0.000    0.015    0.000 cp_model.py:688(left)
#      3784    0.015    0.000    0.061    0.000 __init__.py:280(_compile)
#     19942    0.015    0.000    0.015    0.000 {method 'lower' of 'bytes' objects}
#      4634    0.015    0.000    0.029    0.000 _models.py:274(__contains__)
#     27325    0.015    0.000    0.015    0.000 cp_model.py:691(right)
#      2819    0.015    0.000    0.024    0.000 cp_model.py:1078(__init__)
#       587    0.015    0.000    0.039    0.000 _models.py:130(keys)
#      2977    0.015    0.000    0.015    0.000 {method 'search' of 're.Pattern' objects}
#     18932    0.015    0.000    0.015    0.000 {method 'append' of 'collections.deque' objects}
#     14136    0.015    0.000    0.015    0.000 {built-in method __new__ of type object at 0x755bd46eb4c0}
#     19821    0.015    0.000    0.015    0.000 _connection.py:212(their_state)
#      4073    0.015    0.000    0.057    0.000 futures.py:161(__schedule_callbacks)
#      6770    0.015    0.000    0.023    0.000 weakref.py:451(get)
#     20736    0.015    0.000    0.015    0.000 {built-in method builtins.vars}
#      6024    0.015    0.000    0.020    0.000 _model_construction.py:257(__getattr__)
#      4946    0.015    0.000    0.038    0.000 _connection.py:330(_respond_to_state_changes)
#     18967    0.014    0.000    0.014    0.000 futures.py:181(done)
#     23502    0.014    0.000    0.015    0.000 _exceptions.py:7(map_exceptions)
#      9961    0.014    0.000    0.022    0.000 _utils.py:47(normalize_header_value)
#       843    0.014    0.000    0.074    0.000 _models.py:61(enforce_headers)
#       940    0.014    0.000    0.047    0.000 _sockets.py:58(extra_attributes)
#      6790    0.014    0.000    1.199    0.000 default.py:255(__aiter__)
#     12870    0.014    0.000    0.014    0.000 {method 'add' of 'google._upb._message.RepeatedCompositeContainer' objects}
#     12867    0.014    0.000    0.014    0.000 {method 'extend' of 'google._upb._message.RepeatedScalarContainer' objects}
# 2291/1966    0.014    0.000    0.043    0.000 _asyncio.py:536(_deliver_cancellation)
#       334    0.013    0.000    0.013    0.000 encoder.py:205(iterencode)
#      6790    0.013    0.000    1.180    0.000 connection_pool.py:361(__aiter__)
#      3594    0.013    0.000    0.031    0.000 selectors.py:69(__getitem__)
#      7705    0.013    0.000    0.013    0.000 _asyncio.py:376(__init__)
#      6790    0.013    0.000    1.214    0.000 _client.py:149(__aiter__)
#      1408    0.013    0.000    0.037    0.000 main.py:858(__setattr__)
#      6247    0.013    0.000    0.017    0.000 events.py:72(cancel)
#      1994    0.013    0.000    1.024    0.001 default.py:358(handle_async_request)
#  1536/768    0.013    0.000    0.034    0.000 copy.py:118(deepcopy)
#      3648    0.013    0.000    0.039    0.000 locks.py:199(wait)
#      1994    0.013    0.000    0.928    0.000 connection_pool.py:159(handle_async_request)
#      4884    0.013    0.000    0.013    0.000 utils.py:725(<lambda>)
#      3594    0.013    0.000    0.048    0.000 selectors.py:180(get_key)
#      5530    0.012    0.000    2.810    0.001 _client.py:1639(send)
#     19470    0.012    0.000    0.012    0.000 base_events.py:538(_check_closed)
#     14127    0.012    0.000    0.012    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#      5524    0.012    0.000   37.159    0.007 _base_client.py:1825(post)
#      4680    0.012    0.000    0.029    0.000 {built-in method _heapq.heappush}
#      4680    0.012    0.000    0.035    0.000 events.py:111(__init__)
#     19911    0.012    0.000    0.012    0.000 {method 'isascii' of 'str' objects}
#      5638    0.012    0.000    0.098    0.000 cp_model_helper.py:111(capped_subtraction)
#      6340    0.012    0.000    0.019    0.000 futures.py:286(__await__)
#      7900    0.012    0.000    0.012    0.000 weakref.py:414(__getitem__)
#      4864    0.012    0.000    0.068    0.000 typing.py:166(get_args)
#     79/78    0.011    0.000    0.117    0.002 sock_client.py:147(_send_message)
#      6289    0.011    0.000    0.018    0.000 _urlparse.py:162(<genexpr>)
#       384    0.011    0.000    0.087    0.000 categorical.py:52(__init__)
#      2176    0.011    0.000    0.026    0.000 typing.py:146(_generic_get_args)
#      2458    0.011    0.000   14.668    0.006 completion_sampler.py:386(sample_completions)
#     12516    0.011    0.000    0.014    0.000 trainer.py:337(<genexpr>)
#      9429    0.011    0.000    0.016    0.000 connection.py:190(is_idle)
#    3266/0    0.011    0.000    0.000          tasks.py:383(__wakeup)
#      5524    0.011    0.000   37.057    0.007 _base_client.py:1519(request)
#     17543    0.011    0.000    0.011    0.000 {method 'isprintable' of 'str' objects}
#      1994    0.011    0.000    1.186    0.001 _client.py:1762(_send_single_request)
# 1410/1409    0.011    0.000   13.997    0.010 type_adapter.py:132(wrapped)
#     11995    0.010    0.000    0.010    0.000 {method 'groupdict' of 're.Match' objects}
#       256    0.010    0.000    0.055    0.000 main.py:243(model_construct)
#      6770    0.010    0.000    0.017    0.000 _asyncio.py:371(__new__)
#      4514    0.010    0.000    0.024    0.000 _asyncio.py:2254(current_time)
#      9472    0.010    0.000    0.010    0.000 typing.py:1625(_value_and_type_iter)
# 4644/4068    0.010    0.000    0.012    0.000 completion.py:112(value)
#      1567    0.010    0.000    0.010    0.000 {method 'register' of 'select.epoll' objects}
#      1729    0.010    0.000    0.015    0.000 _trace.py:10(__init__)
#       384    0.010    0.000    0.010    0.000 {built-in method torch.all}
#      6732    0.010    0.000    0.023    0.000 selectors.py:215(_fileobj_lookup)
#      2442    0.010    0.000    0.418    0.000 utils.py:808(assert_array_equal)
#      4627    0.010    0.000    0.017    0.000 futures.py:220(add_done_callback)
#      64/1    0.010    0.000    0.023    0.023 239833578.py:19(get_variable_difficulty_game)
#      1306    0.010    0.000    0.068    0.000 selector_events.py:278(_add_reader)
#      3656    0.009    0.000    0.009    0.000 _events.py:299(__init__)
#      5752    0.009    0.000    0.023    0.000 _asyncio.py:2262(checkpoint)
#      6732    0.009    0.000    0.013    0.000 selectors.py:21(_fileobj_to_fd)
#       704    0.009    0.000    0.028    0.000 {method 'settimeout' of '_socket.socket' objects}
#      1099    0.009    0.000    0.025    0.000 main.py:782(__copy__)
#     14149    0.009    0.000    0.009    0.000 {method '__exit__' of '_thread.RLock' objects}
#      4920    0.009    0.000    0.019    0.000 _ufunc_config.py:452(_no_nep50_warning)
#     11036    0.009    0.000    0.009    0.000 {built-in method _contextvars.copy_context}
#      4133    0.009    0.000    0.023    0.000 trainer.py:347(<genexpr>)
#       902    0.009    0.000    0.028    0.000 tasks.py:111(__init__)
#      78/2    0.009    0.000    0.001    0.001 interface_sock.py:49(_publish)
#      8400    0.009    0.000    0.009    0.000 {built-in method _asyncio._leave_task}
#      3162    0.009    0.000    0.017    0.000 base_events.py:446(create_future)
#      3703    0.009    0.000    0.009    0.000 {method 'match' of 're.Pattern' objects}
#      3523    0.009    0.000    0.058    0.000 futures.py:251(set_result)
#       783    0.009    0.000    0.147    0.000 _sockets.py:114(connect_tcp)
#      1569    0.009    0.000    0.036    0.000 selectors.py:351(register)
#      6253    0.009    0.000    0.010    0.000 futures.py:189(result)
#      1738    0.009    0.000    0.039    0.000 _asyncio.py:2285(cancel_shielded_checkpoint)
#      1479    0.009    0.000    0.047    0.000 selector_events.py:294(_remove_reader)
#      8400    0.009    0.000    0.009    0.000 {built-in method _asyncio._enter_task}
#      1792    0.009    0.000    0.030    0.000 _utils.py:298(strip_not_given)
#      9578    0.008    0.000    0.008    0.000 {method 'remove' of 'set' objects}
#      2008    0.008    0.000    0.784    0.000 connection.py:67(handle_async_request)
#      3395    0.008    0.000    0.037    0.000 _connection.py:352(receive_data)
#      6800    0.008    0.000    0.012    0.000 _receivebuffer.py:60(__len__)
#       384    0.008    0.000    2.546    0.007 categorical.py:144(entropy)
#      1569    0.008    0.000    0.018    0.000 selectors.py:234(register)
#     11996    0.008    0.000    0.008    0.000 {built-in method _asyncio.get_running_loop}
#       331    0.008    0.000    0.528    0.002 _base_client.py:446(_build_request)
#      2368    0.008    0.000    0.012    0.000 ipaddress.py:1213(_parse_octet)
#      6656    0.008    0.000    0.081    0.000 _utils.py:168(is_iterable)
#       384    0.008    0.000    0.066    0.000 distribution.py:40(__init__)
# 4224/1536    0.008    0.000   28.462    0.019 _models.py:382(_construct_field)
#      3297    0.008    0.000    0.014    0.000 copy.py:61(copy)
#      1567    0.008    0.000    0.008    0.000 {method 'unregister' of 'select.epoll' objects}
#       768    0.008    0.000    1.411    0.002 completion.py:816(message_param)
# 2243/2215    0.008    0.000    0.292    0.000 random.py:341(choice)
#      1324    0.008    0.000    0.175    0.000 _urls.py:77(__init__)
#      2175    0.008    0.000    0.028    0.000 cp_model.py:583(__le__)
#     12582    0.008    0.000    0.008    0.000 trainer.py:269(model)
#       993    0.008    0.000    0.012    0.000 _base_client.py:2063(_merge_mappings)
#      4072    0.008    0.000    0.010    0.000 futures.py:72(__init__)
#      1324    0.008    0.000    0.029    0.000 _urlparse.py:452(quote)
#      2819    0.007    0.000    0.007    0.000 {built-in method ortools.util.python.sorted_interval_list.from_flat_intervals}
#      1305    0.007    0.000    0.124    0.000 anyio.py:39(write)
#       261    0.007    0.000    0.108    0.000 _events.py:82(__init__)
#      1334    0.007    0.000    0.017    0.000 streams.py:580(readuntil)
#        43    0.007    0.000    0.009    0.000 _compiler.py:243(_optimize_charset)
#       256    0.007    0.000    0.096    0.000 _models.py:1183(__init__)
#      1994    0.007    0.000    1.205    0.001 _client.py:1690(_send_handling_auth)
#      2442    0.007    0.000    0.017    0.000 contextlib.py:118(_recreate_cm)
#      3289    0.007    0.000    0.010    0.000 _weakrefset.py:85(add)
#      1664    0.007    0.000    0.017    0.000 _compat.py:92(field_get_default)
#       240    0.007    0.000    0.007    0.000 {function socket.close at 0x755bd2325d00}
#       168    0.007    0.000    0.007    0.000 {method 'shutdown' of '_socket.socket' objects}
#      1024    0.007    0.000    0.034    0.000 typing_extensions.py:626(__instancecheck__)
#      2189    0.007    0.000    0.018    0.000 _connection.py:308(_get_io_object)
#      1024    0.007    0.000    0.023    0.000 inspect.py:1845(getattr_static)
#      1200    0.007    0.000    0.007    0.000 {method 'getpeername' of '_socket.socket' objects}
#        83    0.007    0.000    0.229    0.003 clue.py:302(get_prompt_and_follow_up_and_solution)
#      4107    0.007    0.000    0.007    0.000 {method 'format' of 'str' objects}
#      90/8    0.007    0.000   11.220    1.403 mailbox.py:249(wait)
#      2073    0.007    0.000    0.009    0.000 _headers.py:205(get_comma_header)
#       522    0.007    0.000    0.104    0.000 http11.py:159(_send_request_body)
#      3072    0.007    0.000    0.007    0.000 inspect.py:1832(_shadowed_dict)
#      2330    0.007    0.000   14.654    0.006 episode.py:65(follow_up)
#      3586    0.007    0.000    0.009    0.000 futures.py:301(_get_loop)
#      7046    0.006    0.000    0.006    0.000 _decoders.py:215(decode)
#      32/1    0.006    0.000    0.030    0.030 interface.py:910(deliver_internal_messages)
#      1408    0.006    0.000   18.063    0.013 _models.py:728(_validate_non_model_type)
#      2539    0.006    0.000    0.027    0.000 locks.py:181(set)
#      1044    0.006    0.000    0.050    0.000 _asyncio.py:1225(send)
#      9135    0.006    0.000    0.006    0.000 _util.py:127(bytesify)
#      4951    0.006    0.000    0.006    0.000 _state.py:301(_fire_event_triggered_transitions)
#      3518    0.006    0.000    0.010    0.000 _weakrefset.py:39(_remove)
#      5266    0.006    0.000    0.006    0.000 {method 'copy' of 'list' objects}
#       512    0.006    0.000    0.015    0.000 _models.py:159(multi_items)
#       748    0.006    0.000    0.064    0.000 _asyncio.py:698(__aexit__)
#      2573    0.006    0.000    0.006    0.000 _models.py:123(raw)
#      4437    0.006    0.000    0.010    0.000 <frozen _collections_abc>:1022(__iter__)
#      2048    0.006    0.000    0.010    0.000 message.py:421(__setitem__)
#       331    0.006    0.000    0.073    0.000 _models.py:202(update)
#      3180    0.006    0.000    0.065    0.000 http11.py:281(has_expired)
#      1754    0.006    0.000    0.051    0.000 _asyncio.py:1733(acquire)
#       536    0.006    0.000    0.072    0.000 {method 'throw' of 'coroutine' objects}
#       331    0.006    0.000    0.230    0.001 _client.py:320(build_request)
#       374    0.006    0.000    0.046    0.000 vllm.py:150(log_output)
#      7954    0.006    0.000    0.006    0.000 fromnumeric.py:2974(_prod_dispatcher)
#      1569    0.006    0.000    0.024    0.000 selectors.py:365(unregister)
#      8338    0.006    0.000    0.006    0.000 tasks.py:641(__sleep0)
#      6790    0.006    0.000    0.006    0.000 <string>:2(__eq__)
#      7818    0.006    0.000    0.006    0.000 multiarray.py:346(where)
#       974    0.006    0.000    0.018    0.000 tasks.py:522(_wait)
#       331    0.006    0.000    0.078    0.000 _models.py:375(_prepare)
#      4096    0.006    0.000    0.009    0.000 request.py:397(add_header)
#       517    0.006    0.000    0.010    0.000 _receivebuffer.py:104(maybe_extract_lines)
#      1408    0.006    0.000   25.704    0.018 _models.py:677(validate_type)
#     10378    0.006    0.000    0.006    0.000 clue.py:317(<genexpr>)
# 3002/2007    0.006    0.000   15.492    0.008 _base_client.py:1645(_retry_request)
#       662    0.006    0.000    0.008    0.000 _models.py:232(__setitem__)
#       256    0.006    0.000    0.009    0.000 _utils.py:241(wrapper)
#  1792/640    0.006    0.000    1.428    0.002 completion.py:417(all_message_params)
#       331    0.006    0.000    0.136    0.000 _models.py:311(__init__)
#       522    0.006    0.000    0.167    0.000 connection.py:103(_connect)
#       974    0.005    0.000    0.031    0.000 tasks.py:435(wait)
#      8448    0.005    0.000    0.005    0.000 completion.py:208(matches_model)
#      1792    0.005    0.000    1.421    0.001 completion.py:405(message_params)
#       256    0.005    0.000   33.545    0.131 _response.py:128(_parse)
#      2460    0.005    0.000    0.070    0.000 __init__.py:174(search)
#       384    0.005    0.000    0.005    0.000 {built-in method torch.clamp}
#      1408    0.005    0.000   10.361    0.007 type_adapter.py:341(validate_python)
#      3964    0.005    0.000    0.008    0.000 connection.py:195(is_closed)
#      8304    0.005    0.000    0.005    0.000 {built-in method builtins.id}
#      8107    0.005    0.000    0.005    0.000 http11.py:295(is_idle)
#      4884    0.005    0.000    0.005    0.000 utils.py:655(isnumber)
#      3456    0.005    0.000    0.032    0.000 typing.py:417(is_literal_type)
#      2460    0.005    0.000    0.005    0.000 {method 'set' of '_contextvars.ContextVar' objects}
#       522    0.005    0.000    0.157    0.000 anyio.py:100(connect_tcp)
#       653    0.005    0.000    0.165    0.000 connection_pool.py:369(aclose)
#       768    0.005    0.000    2.516    0.003 utils.py:144(__get__)
#      2243    0.005    0.000    0.013    0.000 socket.py:100(_intenum_converter)
#      5034    0.005    0.000    0.005    0.000 {method 'update' of 'dict' objects}
#      2329    0.005    0.000    0.008    0.000 enum.py:720(__call__)
#       384    0.005    0.000    0.005    0.000 {method 'clamp' of 'torch._C.TensorBase' objects}
#      1306    0.005    0.000    0.076    0.000 selector_events.py:925(_add_reader)
#      3400    0.005    0.000    0.016    0.000 _receivebuffer.py:57(__bool__)
#       256    0.005    0.000    0.030    0.000 request.py:315(__init__)
#      4340    0.005    0.000    0.007    0.000 enum.py:202(__get__)
#      1985    0.005    0.000    0.005    0.000 locks.py:166(__init__)
#      2442    0.005    0.000    0.005    0.000 {built-in method _operator.eq}
#      6770    0.005    0.000    0.010    0.000 _asyncio.py:579(_restart_cancellation_in_parent)
#      1293    0.005    0.000    0.051    0.000 selector_events.py:851(pause_reading)
#       256    0.005    0.000   33.573    0.131 _base_client.py:1674(_process_response)
#       662    0.005    0.000    0.008    0.000 _models.py:256(__delitem__)
#     86/43    0.005    0.000    0.014    0.000 _parser.py:512(_parse)
#      7818    0.005    0.000    0.005    0.000 numeric.py:337(_full_like_dispatcher)
#       261    0.005    0.000    0.007    0.000 _writers.py:22(write_headers)
#       935    0.005    0.000    0.029    0.000 _synchronization.py:197(__init__)
#       522    0.005    0.000    0.008    0.000 base_events.py:100(_ipaddr_info)
#      1024    0.005    0.000    0.006    0.000 inspect.py:1797(_check_instance)
#       331    0.005    0.000    0.082    0.000 _base_client.py:411(_build_headers)
#        18    0.005    0.000    0.016    0.001 datetimes.py:397(_generate_range)
#       517    0.005    0.000    0.045    0.000 _readers.py:94(maybe_read_from_SEND_RESPONSE_server)
#       261    0.005    0.000    0.021    0.000 _asyncio.py:749(_spawn)
#      5990    0.005    0.000    0.005    0.000 _connection.py:205(our_state)
#      3889    0.005    0.000    0.070    0.000 connection.py:185(has_expired)
#      2460    0.005    0.000    0.005    0.000 {method 'reset' of '_contextvars.ContextVar' objects}
#       902    0.005    0.000    0.033    0.000 base_events.py:450(create_task)
#       768    0.005    0.000    0.014    0.000 copy.py:247(_reconstruct)
#      6834    0.005    0.000    0.005    0.000 tasks.py:252(cancelling)
#      2688    0.005    0.000    0.040    0.000 _utils.py:303(smart_deepcopy)
#      2688    0.005    0.000    0.044    0.000 fields.py:552(get_default)
#       782    0.005    0.000    0.151    0.000 _asyncio.py:2519(connect_tcp)
#      2017    0.005    0.000    0.070    0.000 _models.py:170(get)
#      1608    0.005    0.000    0.006    0.000 mixins.py:12(_get_loop)
#      1994    0.005    0.000    1.192    0.001 _client.py:1724(_send_handling_redirects)
#      1631    0.005    0.000    0.008    0.000 {built-in method builtins.all}
#       567    0.005    0.000    0.010    0.000 selector_events.py:750(_process_events)
#      1046    0.005    0.000    0.122    0.000 selector_events.py:1009(_read_ready__data_received)
#       749    0.005    0.000    0.010    0.000 _utils.py:7(is_socket_readable)
#      1730    0.004    0.000    0.013    0.000 _synchronization.py:21(current_async_library)
#      7818    0.004    0.000    0.004    0.000 multiarray.py:85(empty_like)
#       959    0.004    0.000    0.005    0.000 _models.py:287(origin)
#      2507    0.004    0.000    0.058    0.000 clue.py:343(<genexpr>)
#       512    0.004    0.000    0.030    0.000 _models.py:1204(info)
#      1722    0.004    0.000    0.015    0.000 socket.py:517(family)
#       783    0.004    0.000    0.053    0.000 _connection.py:518(send_with_data_passthrough)
#      1764    0.004    0.000    0.017    0.000 {built-in method from_bytes}
#      2629    0.004    0.000    0.010    0.000 _asyncio.py:1186(_raw_socket)
#      2361    0.004    0.000    0.006    0.000 _models.py:173(__eq__)
#       260    0.004    0.000    0.013    0.000 selector_events.py:779(__init__)
#      1754    0.004    0.000    0.070    0.000 _synchronization.py:69(__aenter__)
#       842    0.004    0.000    0.074    0.000 connection_pool.py:301(_close_connections)
#       256    0.004    0.000    0.090    0.000 _models.py:810(construct)
#      1305    0.004    0.000    0.185    0.000 http11.py:170(_send_event)
#       522    0.004    0.000    0.214    0.000 http11.py:147(_send_request_headers)
#       940    0.004    0.000    0.069    0.000 anyio.py:84(get_extra_info)
#      4680    0.004    0.000    0.004    0.000 base_events.py:1910(_timer_handle_cancelled)
#      4504    0.004    0.000    0.004    0.000 {method 'capitalize' of 'str' objects}
#      2385    0.004    0.000    0.011    0.000 base_events.py:551(_asyncgen_firstiter_hook)
#      1152    0.004    0.000    0.007    0.000 main.py:927(_check_frozen)
#      2819    0.004    0.000    0.031    0.000 cp_model.py:455(__radd__)
#      1046    0.004    0.000    0.025    0.000 _asyncio.py:1130(data_received)
#      3907    0.004    0.000    0.004    0.000 _connection.py:248(_server_switch_event)
#       940    0.004    0.000    0.055    0.000 _typedattr.py:58(extra)
#       331    0.004    0.000    0.180    0.001 _base_client.py:430(_prepare_url)
#       768    0.004    0.000    0.009    0.000 main.py:826(__getattr__)
#      1024    0.004    0.000    0.007    0.000 inspect.py:1806(_check_class)
#      5370    0.004    0.000    0.004    0.000 {method 'strip' of 'str' objects}
#       522    0.004    0.000    0.064    0.000 selector_events.py:631(sock_connect)
#       256    0.004    0.000    0.014    0.000 random.py:359(sample)
#      2629    0.004    0.000    0.006    0.000 transports.py:19(get_extra_info)
#      2599    0.004    0.000    0.005    0.000 selector_events.py:848(is_reading)
#       782    0.004    0.000    0.134    0.000 base_events.py:1019(create_connection)
#       653    0.004    0.000    0.177    0.000 _client.py:153(aclose)
#       512    0.004    0.000    0.013    0.000 completion_sampler.py:70(_wait)
#       320    0.004    0.000    0.008    0.000 tasks.py:767(_done_callback)
#       522    0.004    0.000    0.038    0.000 selector_events.py:1055(write)
#      2803    0.004    0.000    0.005    0.000 base_events.py:1900(_add_callback)
#      2954    0.004    0.000    0.006    0.000 inspect.py:302(isclass)
#      4306    0.004    0.000    0.004    0.000 futures.py:91(__del__)
#      1324    0.004    0.000    0.017    0.000 __init__.py:219(finditer)
#      1569    0.004    0.000    0.010    0.000 selectors.py:247(unregister)
#       782    0.004    0.000    0.006    0.000 selector_events.py:260(_ensure_fd_no_transport)
#       261    0.004    0.000    0.046    0.000 selector_events.py:656(_sock_connect)
#       384    0.003    0.000    0.003    0.000 {method 'abs' of 'torch._C.TensorBase' objects}
#      4437    0.003    0.000    0.003    0.000 _headers.py:117(__getitem__)
#      1046    0.003    0.000    0.066    0.000 selector_events.py:859(resume_reading)
#      3876    0.003    0.000    0.003    0.000 clue.py:254(<genexpr>)
#      1280    0.003    0.000    0.012    0.000 _readers.py:64(_decode_header_lines)
#      1334    0.003    0.000    0.021    0.000 streams.py:549(readline)
#      3550    0.003    0.000    0.003    0.000 {method 'discard' of 'set' objects}
#      5638    0.003    0.000    0.003    0.000 cp_model.py:2760(proto)
#      2578    0.003    0.000    0.003    0.000 {method 'split' of 'str' objects}
#       768    0.003    0.000    0.016    0.000 completion_sampler.py:62(_wait_if_needed)
#       522    0.003    0.000    0.084    0.000 base_events.py:976(_connect_sock)
#      2088    0.003    0.000    0.008    0.000 connection.py:165(can_handle_request)
#       581    0.003    0.000    0.028    0.000 tasks.py:412(create_task)
#       522    0.003    0.000    0.028    0.000 http11.py:245(_response_closed)
#    129/43    0.003    0.000    0.016    0.000 _compiler.py:37(_compile)
#      2442    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      2528    0.003    0.000    0.005    0.000 completion_sampler.py:374(__hash__)
#       592    0.003    0.000    0.020    0.000 ipaddress.py:1187(_ip_int_from_string)
#       993    0.003    0.000    0.106    0.000 _urlparse.py:125(copy_with)
#      2198    0.003    0.000    0.008    0.000 coroutines.py:32(iscoroutine)
#       512    0.003    0.000    0.026    0.000 completion_sampler.py:50(acquire)
#       192    0.003    0.000    0.020    0.000 tasks.py:731(gather)
#        79    0.003    0.000    0.004    0.000 interface_shared.py:123(_make_request)
#      2822    0.003    0.000    0.003    0.000 type_adapter.py:259(_with_frame_depth)
#      1324    0.003    0.000    0.003    0.000 {method 'finditer' of 're.Pattern' objects}
#       653    0.003    0.000    0.168    0.000 default.py:260(aclose)
#      1208    0.003    0.000    0.006    0.000 _asyncio.py:1705(__init__)
#      2244    0.003    0.000    0.003    0.000 {built-in method builtins.max}
#      2304    0.003    0.000    0.005    0.000 _utils.py:164(is_list)
#       378    0.003    0.000    0.003    0.000 {built-in method posix.read}
#        22    0.003    0.000    2.174    0.099 interface.py:894(deliver_stop_status)
#       935    0.003    0.000    0.016    0.000 _tasks.py:28(__new__)
#       768    0.003    0.000    0.004    0.000 copy.py:231(_keep_alive)
#       869    0.003    0.000    0.005    0.000 _asyncio.py:2266(checkpoint_if_cancelled)
#   715/685    0.003    0.000    0.372    0.001 mailbox.py:17(<genexpr>)
#       592    0.003    0.000    0.024    0.000 ipaddress.py:1286(__init__)
#       331    0.003    0.000    0.021    0.000 _content.py:176(encode_json)
#       653    0.003    0.000    0.184    0.000 _models.py:999(aclose)
#      3922    0.003    0.000    0.003    0.000 _synchronization.py:717(__exit__)
#      2797    0.003    0.000    0.003    0.000 __init__.py:1790(isEnabledFor)
#      3922    0.003    0.000    0.003    0.000 _synchronization.py:711(__enter__)
#       782    0.003    0.000    0.168    0.000 _sockets.py:162(try_connect)
#      2098    0.003    0.000    0.003    0.000 {method 'remove' of 'collections.deque' objects}
#      4016    0.003    0.000    0.003    0.000 selector_events.py:845(is_closing)
#       587    0.003    0.000    0.009    0.000 _utils.py:292(_get_time)
#       384    0.003    0.000    0.003    0.000 {method 'all' of 'torch._C.TensorBase' objects}
#       522    0.003    0.000    0.170    0.000 http11.py:179(_receive_response_headers)
#       517    0.003    0.000    0.003    0.000 _events.py:337(__init__)
#      3185    0.003    0.000    0.003    0.000 http11.py:298(is_closed)
#       331    0.003    0.000    0.010    0.000 _client.py:376(default_headers)
#       256    0.003    0.000    4.594    0.018 decoder.py:333(decode)
#       260    0.003    0.000    0.031    0.000 selector_events.py:936(__init__)
#      2329    0.003    0.000    0.003    0.000 enum.py:1123(__new__)
#      3427    0.003    0.000    0.003    0.000 futures.py:119(get_loop)
#       517    0.003    0.000    0.008    0.000 _connection.py:81(_body_framing)
#       512    0.003    0.000    0.032    0.000 http11.py:351(aclose)
#     79/78    0.003    0.000    0.122    0.002 sock_client.py:156(send_server_request)
#      3661    0.003    0.000    0.003    0.000 locks.py:177(is_set)
#       906    0.003    0.000    0.003    0.000 tasks.py:142(__del__)
#      4178    0.002    0.000    0.002    0.000 _asyncio.py:626(cancelled_caught)
#       783    0.002    0.000    0.056    0.000 _connection.py:491(send)
#      2048    0.002    0.000    0.004    0.000 typing.py:1630(__eq__)
#      1099    0.002    0.000    0.027    0.000 main.py:324(model_copy)
#         6    0.002    0.000    0.002    0.000 {built-in method marshal.loads}
#       256    0.002    0.000    0.015    0.000 _events.py:137(__init__)
#       536    0.002    0.000    0.012    0.000 tasks.py:210(cancel)
#       644    0.002    0.000    0.009    0.000 cp_model.py:565(__eq__)
#      3521    0.002    0.000    0.002    0.000 connection_pool.py:39(is_queued)
#       452    0.002    0.000    0.015    0.000 _synchronization.py:58(setup)
#       904    0.002    0.000    0.002    0.000 _asyncio.py:1728(__init__)
#       260    0.002    0.000    0.007    0.000 _asyncio.py:1115(connection_made)
#       331    0.002    0.000    0.004    0.000 _base_client.py:607(default_headers)
#       616    0.002    0.000    0.003    0.000 _asyncio.py:362(is_anyio_cancellation)
#       256    0.002    0.000    0.039    0.000 cookiejar.py:1680(extract_cookies)
#      2349    0.002    0.000    0.002    0.000 {method 'appendleft' of 'collections.deque' objects}
#       520    0.002    0.000    0.042    0.000 base_events.py:1166(_create_connection_transport)
#      1046    0.002    0.000    0.124    0.000 selector_events.py:969(_read_ready)
#       512    0.002    0.000    0.004    0.000 message.py:529(get_all)
#       407    0.002    0.000    0.005    0.000 sock_client.py:227(_extract_packet_bytes)
#       256    0.002    0.000    0.004    0.000 parse.py:374(urlparse)
#       442    0.002    0.000    0.012    0.000 selector_events.py:331(_remove_writer)
#       256    0.002    0.000    0.002    0.000 _receivebuffer.py:64(__bytes__)
#      3597    0.002    0.000    0.002    0.000 selectors.py:272(get_map)
#       261    0.002    0.000    0.014    0.000 selector_events.py:315(_add_writer)
# ...
#        16    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1577(<genexpr>)
#         5    0.000    0.000    0.000    0.000 _generate_schema.py:891(_get_first_arg_or_any)
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:178(check_decorator_fields_exist)
#         1    0.000    0.000    0.000    0.000 inspect.py:2896(args)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 wandb_run.py:421(wrapper)
#         1    0.000    0.000    0.000    0.000 warnings.py:184(_add_filter)
#         1    0.000    0.000    0.000    0.000 _base.py:393(done)
#         1    0.000    0.000    0.000    0.000 futures.py:383(_set_state)
#         9    0.000    0.000    0.000    0.000 _generate_schema.py:2347(_validators_require_validate_default)
#         1    0.000    0.000    0.000    0.000 interface_shared.py:85(_publish_partial_history)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:229(obj2sctype)
#        10    0.000    0.000    0.000    0.000 _typing_extra.py:574(is_zoneinfo_type)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:305(validator)
#         4    0.000    0.000    0.000    0.000 _generate_schema.py:2552(resolve_original_schema)
#         1    0.000    0.000    0.000    0.000 selectors.py:209(__init__)
#         1    0.000    0.000    0.000    0.000 _loader.py:21(get_plugins)
#       2/1    0.000    0.000    0.000    0.000 wandb_settings.py:530(value)
#         1    0.000    0.000    0.000    0.000 threading.py:975(start)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:463(_lock_unlock_module)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         3    0.000    0.000    0.000    0.000 _typing_extra.py:206(get_module_ns_of)
#         1    0.000    0.000    0.000    0.000 _typing_extra.py:170(parent_frame_namespace)
#         9    0.000    0.000    0.000    0.000 _generate_schema.py:211(apply_each_item_validators)
#         3    0.000    0.000    0.000    0.000 selectors.py:66(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.generic' objects}
#         1    0.000    0.000    0.000    0.000 wandb_run.py:826(__setattr__)
#         9    0.000    0.000    0.000    0.000 _generate_schema.py:2200(_apply_field_serializers)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 subprocess.py:1961(_handle_exitstatus)
#         1    0.000    0.000    0.000    0.000 functools.py:979(__get__)
#         1    0.000    0.000    0.000    0.000 subprocess.py:2008(_try_wait)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:599(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:811(__contains__)
#         1    0.000    0.000    0.000    0.000 sysconfig.py:744(get_config_var)
#         1    0.000    0.000    0.000    0.000 typing.py:1603(__repr__)
#         1    0.000    0.000    0.000    0.000 threading.py:1356(_make_invoke_excepthook)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1233(poll)
#         1    0.000    0.000    0.000    0.000 wandb_run.py:1477(_visualization_hack)
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:2256(_apply_model_serializers)
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 core_schema.py:3750(definitions_schema)
#         9    0.000    0.000    0.000    0.000 _generate_schema.py:2070(<lambda>)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         3    0.000    0.000    0.000    0.000 utils.py:152(wrapper_setattr)
#         2    0.000    0.000    0.000    0.000 core_schema.py:630(float_schema)
#         2    0.000    0.000    0.000    0.000 getlimits.py:24(_fr1)
#         2    0.000    0.000    0.000    0.000 _typing_extra.py:115(annotated_type)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.confstr}
#         1    0.000    0.000    0.000    0.000 synchronize.py:217(Condition)
#         1    0.000    0.000    0.000    0.000 _core_utils.py:122(collect_definitions)
#         3    0.000    0.000    0.000    0.000 _schema_generation_shared.py:103(resolve_ref_schema)
#         6    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         3    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         6    0.000    0.000    0.000    0.000 case.py:426(addTypeEqualityFunc)
#         1    0.000    0.000    0.000    0.000 synchronize.py:90(_make_methods)
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         1    0.000    0.000    0.000    0.000 getlimits.py:86(_str_smallest_subnormal)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1092(__exit__)
#         1    0.000    0.000    0.000    0.000 wandb_run.py:400(wrapper_fn)
#         8    0.000    0.000    0.000    0.000 {built-in method math.floor}
#         1    0.000    0.000    0.000    0.000 warnings.py:168(simplefilter)
#         1    0.000    0.000    0.000    0.000 _config.py:278(prepare_config)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:158(__init__)
#        10    0.000    0.000    0.000    0.000 inspect.py:2808(kind)
#         1    0.000    0.000    0.000    0.000 _base.py:428(result)
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:221(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:333(tail)
#         1    0.000    0.000    0.000    0.000 _core_utils.py:158(collect_invalid_schemas)
#         1    0.000    0.000    0.000    0.000 {method 'tobytes' of 'numpy.generic' objects}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1157(__init__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 base_events.py:1995(_set_coroutine_origin_tracking)
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:804(get)
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         3    0.000    0.000    0.000    0.000 wandb_run.py:1650(<genexpr>)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:100(_getattr_no_parents)
#         3    0.000    0.000    0.000    0.000 _core_utils.py:65(is_function_with_inner_schema)
#         2    0.000    0.000    0.000    0.000 utils.py:62(val_to_json)
#         1    0.000    0.000    0.000    0.000 inspect.py:2919(kwargs)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:193(__init__)
#         1    0.000    0.000    0.000    0.000 trainer.py:863(get_completion_sampler)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:412(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:71(_relax_case)
#         4    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#         4    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 <frozen os>:808(getenv)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1182(get_filename)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:789(_unpack_refs_defs)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:990(create_module)
#         1    0.000    0.000    0.000    0.000 selectors.py:202(__exit__)
#         1    0.000    0.000    0.000    0.000 subprocess.py:268(_cleanup)
#         3    0.000    0.000    0.000    0.000 _core_utils.py:469(can_be_inlined)
#         1    0.000    0.000    0.000    0.000 utils.py:1938(clear_and_catch_warnings)
#         4    0.000    0.000    0.000    0.000 _generate_schema.py:2564(__init__)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:323(_defer_build)
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 _base.py:383(cancelled)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:653(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:268(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 futures.py:389(_call_check_cancel)
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio._set_running_loop}
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:182(__subclasshook__)
#         4    0.000    0.000    0.000    0.000 _core_utils.py:467(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _base.py:463(exception)
#         4    0.000    0.000    0.000    0.000 typing.py:1273(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         2    0.000    0.000    0.000    0.000 getlimits.py:101(_float_conv)
#         1    0.000    0.000    0.000    0.000 utils.py:1261(_Dummy)
#         2    0.000    0.000    0.000    0.000 contextlib.py:548(_push_exit_callback)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1120(__del__)
#         2    0.000    0.000    0.000    0.000 threading.py:1236(daemon)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 threading.py:1042(_set_native_id)
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.getencoding}
#         4    0.000    0.000    0.000    0.000 subprocess.py:1239(_remaining_time)
#       1/0    0.000    0.000    0.000          builtins.py:108(gen)
#         1    0.000    0.000    0.000    0.000 threading.py:1485(current_thread)
#         2    0.000    0.000    0.000    0.000 {method 'unregister' of 'select.poll' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:1038(_set_ident)
#         2    0.000    0.000    0.000    0.000 contextlib.py:477(_exit_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen os>:795(decode)
#         1    0.000    0.000    0.000    0.000 getlimits.py:16(_fr0)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:110(remove)
#         3    0.000    0.000    0.000    0.000 _core_utils.py:136(define_expected_missing_refs)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         2    0.000    0.000    0.000    0.000 contextlib.py:475(_create_cb_wrapper)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:76(__init__)
#         1    0.000    0.000    0.000    0.000 platform.py:890(uname)
#         1    0.000    0.000    0.000    0.000 contextlib.py:481(__init__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:328(Event)
#         2    0.000    0.000    0.000    0.000 notebook.py:272(close)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 subprocess.py:2164(_save_input)
#         4    0.000    0.000    0.000    0.000 inspect.py:2796(name)
#         1    0.000    0.000    0.000    0.000 std.py:1147(__del__)
#         1    0.000    0.000    0.000    0.000 threading.py:839(_newname)
#         4    0.000    0.000    0.000    0.000 inspect.py:3089(parameters)
#         1    0.000    0.000    0.000    0.000 wandb_settings.py:731(<lambda>)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:200(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 {method 'rfind' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 util.py:48(debug)
#         1    0.000    0.000    0.000    0.000 queues.py:47(_init)
#         1    0.000    0.000    0.000    0.000 {built-in method posix._path_normpath}
#         1    0.000    0.000    0.000    0.000 synchronize.py:130(Semaphore)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread._set_sentinel}
#         2    0.000    0.000    0.000    0.000 subprocess.py:1311(_on_error_fd_closer)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#         2    0.000    0.000    0.000    0.000 subprocess.py:1247(_check_timeout)
#         1    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _generate_schema.py:2516(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:729(is_running)
#         1    0.000    0.000    0.000    0.000 context.py:197(get_start_method)
#         2    0.000    0.000    0.000    0.000 subprocess.py:1973(_internal_poll)
#         1    0.000    0.000    0.000    0.000 synchronize.py:166(Lock)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:1896(IgnoreException)
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 warnings.py:458(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         1    0.000    0.000    0.000    0.000 synchronize.py:149(BoundedSemaphore)
#       1/0    0.000    0.000    0.000          239833578.py:235(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 _generate_schema.py:2583(__init__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:191(RLock)
#         1    0.000    0.000    0.000    0.000 utils.py:45(KnownFailureException)
#         1    0.000    0.000    0.000    0.000 {method '__init_subclass__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.WIFSTOPPED}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.daemon_threads_allowed}
#         1    0.000    0.000    0.000    0.000 inspect.py:2888(__init__)
#         1    0.000    0.000    0.000    0.000 subprocess.py:481(__init__)
#         1    0.000    0.000    0.000    0.000 process.py:37(current_process)
#         1    0.000    0.000    0.000    0.000 selectors.py:63(__init__)
#         1    0.000    0.000    0.000    0.000 _generate_schema.py:330(__init__)
#         1    0.000    0.000    0.000    0.000 _config.py:208(__init__)
#         1    0.000    0.000    0.000    0.000 selectors.py:199(__enter__)
#         1    0.000    0.000    0.000    0.000 trainer.py:322(<lambda>)
#         1    0.000    0.000    0.000    0.000 _base.py:398(__get_result)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1089(__enter__)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.waitstatus_to_exitcode}
#         1    0.000    0.000    0.000    0.000 contextlib.py:564(__enter__)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:570(<lambda>)

# %%
for episode in trainer.eval_episodes["val"]:
    episode.completion.children = set()

# %%
# %%prun
asyncio.run(trainer.eval("val", verbosity=0))
# Out:
#          13499472 function calls (12989829 primitive calls) in 65.954 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     90/84   15.791    0.175   19.592    0.233 threading.py:323(wait)
#  1241/444    4.989    0.004    2.276    0.005 {method 'poll' of 'select.epoll' objects}
#      1408    4.717    0.003    9.323    0.007 {method 'validate_python' of 'pydantic_core._pydantic_core.SchemaValidator' objects}
#        56    4.710    0.084    6.331    0.113 sock_client.py:242(_read_packet_bytes)
#       256    3.866    0.015    3.882    0.015 decoder.py:344(raw_decode)
#     397/3    3.739    0.009    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#   1910050    3.591    0.000    5.203    0.000 _model_construction.py:268(__instancecheck__)
#       384    2.411    0.006    2.411    0.006 {built-in method torch.log}
# 1243/1242    2.088    0.002   65.037    0.052 nest_asyncio.py:100(_run_once)
#       384    1.760    0.005    1.760    0.005 {built-in method torch.exp}
# 2699274/2652982    1.582    0.000    1.929    0.000 {built-in method builtins.isinstance}
#   1075/56    1.525    0.001    1.446    0.026 {method 'recv' of '_socket.socket' objects}
#    532864    1.021    0.000    1.694    0.000 typing.py:2340(get_origin)
#   1936930    0.982    0.000    0.987    0.000 {built-in method builtins.hasattr}
# 189440/39168    0.566    0.000    2.598    0.000 typing.py:407(_eval_type)
#    229049    0.534    0.000    0.821    0.000 utils.py:45(get_token)
#     13518    0.493    0.000    0.493    0.000 {built-in method torch.tensor}
# 75264/256    0.481    0.000    7.200    0.028 _transform.py:288(_async_transform_recursive)
#     26668    0.372    0.000    0.680    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#     26268    0.339    0.000    5.222    0.000 completion.py:260(entropy_sum)
#     39168    0.335    0.000    0.900    0.000 typing.py:175(_type_check)
#       256    0.309    0.001   35.127    0.137 _response.py:388(parse)
#      6912    0.279    0.000    2.997    0.000 typing.py:2215(get_type_hints)
#    229817    0.257    0.000    1.078    0.000 completion.py:824(<genexpr>)
#    280923    0.231    0.000    0.231    0.000 {method 'decode' of 'bytes' objects}
#     39168    0.223    0.000    2.503    0.000 typing.py:916(_evaluate)
# 171264/87552    0.212    0.000    0.656    0.000 typing.py:430(<genexpr>)
#    163584    0.188    0.000    0.701    0.000 _typing.py:29(is_required_type)
# 88064/75264    0.181    0.000    0.979    0.000 _typing.py:40(strip_annotated_type)
#    155904    0.179    0.000    0.661    0.000 _typing.py:11(is_annotated_type)
#     68864    0.171    0.000    0.292    0.000 typing.py:2370(get_args)
#     75520    0.165    0.000    0.886    0.000 _transform.py:111(_get_annotated_type)
#    306682    0.164    0.000    0.164    0.000 threading.py:1198(ident)
#    232468    0.149    0.000    0.149    0.000 {method 'startswith' of 'str' objects}
#    143488    0.147    0.000    0.229    0.000 typing.py:1279(__eq__)
#    133120    0.147    0.000    0.226    0.000 typing.py:1592(__eq__)
#      9460    0.141    0.000    1.339    0.000 {method 'join' of 'str' objects}
#     75264    0.126    0.000    0.297    0.000 typing.py:448(is_typeddict)
#     67840    0.120    0.000    0.380    0.000 _typing.py:25(is_union_type)
#     75264    0.105    0.000    0.165    0.000 utils.py:181(lenient_issubclass)
# 1242/1234    0.104    0.000    5.092    0.004 selectors.py:451(select)
#  6912/512    0.098    0.000    7.170    0.014 _transform.py:379(_async_transform_typeddict)
#     90/84    0.093    0.001   19.805    0.236 threading.py:637(wait)
#    130868    0.089    0.000    0.089    0.000 {method 'get' of 'dict' objects}
#     68352    0.087    0.000    0.308    0.000 _typing.py:19(is_iterable_type)
#      6548    0.086    0.000    0.238    0.000 _asyncio.py:1190(receive)
#     57746    0.084    0.000    0.256    0.000 typing.py:392(inner)
# 52100/12698    0.083    0.000    0.088    0.000 completion.py:219(leaves)
#    108138    0.082    0.000    0.107    0.000 {built-in method builtins.getattr}
#        56    0.080    0.001    6.492    0.116 sock_client.py:286(read_server_response)
#     68352    0.080    0.000    0.304    0.000 _typing.py:15(is_list_type)
#     55275    0.076    0.000    0.175    0.000 completion.py:757(<genexpr>)
#     39168    0.070    0.000    0.426    0.000 {built-in method builtins.eval}
#     13334    0.067    0.000    0.093    0.000 threading.py:1535(enumerate)
#     36958    0.065    0.000    0.430    0.000 {built-in method builtins.next}
#     67698    0.063    0.000    0.127    0.000 {built-in method builtins.issubclass}
#     28239    0.062    0.000    0.320    0.000 completion.py:765(num_token_logprobs)
#      9472    0.061    0.000    0.109    0.000 typing.py:1636(__hash__)
# 30360/1481    0.060    0.000    5.920    0.004 {built-in method builtins.sum}
#     23146    0.056    0.000    0.160    0.000 typing.py:1492(__subclasscheck__)
#     41373    0.055    0.000    0.180    0.000 completion.py:766(<genexpr>)
# 26268/6567    0.055    0.000    5.293    0.001 completion.py:308(all_entropy_sum)
#      7055    0.054    0.000    1.113    0.000 http11.py:216(_receive_event)
#     49304    0.052    0.000    0.075    0.000 events.py:127(__lt__)
#      1332    0.048    0.000    0.048    0.000 {method 'join' of 'bytes' objects}
# 28239/8538    0.047    0.000    0.367    0.000 completion.py:768(all_num_token_logprobs)
#     66688    0.046    0.000    0.046    0.000 typing.py:213(_should_unflatten_callable_args)
#      6193    0.046    0.000    0.174    0.000 _asyncio.py:391(__enter__)
#       201    0.045    0.000    0.080    0.000 random.py:889(getrandbits)
#  4864/256    0.045    0.000   23.990    0.094 _models.py:448(construct_type)
#     41757    0.045    0.000    0.045    0.000 completion.py:756(_token_logprob_sequences)
#     39168    0.045    0.000    0.069    0.000 typing.py:166(_type_convert)
#     72704    0.044    0.000    0.044    0.000 typing.py:251(is_union)
#      8603    0.044    0.000    5.824    0.001 trainer.py:356(<genexpr>)
#      6968    0.044    0.000    0.100    0.000 _models.py:212(__getitem__)
#      6193    0.041    0.000    0.107    0.000 _asyncio.py:422(__exit__)
#     28744    0.040    0.000    0.065    0.000 _models.py:94(encoding)
#     18264    0.040    0.000    0.054    0.000 contextlib.py:104(__init__)
#     23146    0.040    0.000    0.200    0.000 typing.py:1221(__instancecheck__)
#     15864    0.038    0.000    0.053    0.000 events.py:36(__init__)
#     12686    0.038    0.000    0.056    0.000 _impl.py:25(current_async_library)
#      6548    0.038    0.000    0.632    0.000 anyio.py:23(read)
#      7992    0.037    0.000    0.348    0.000 _tasks.py:95(fail_after)
#      7510    0.037    0.000   47.208    0.006 tasks.py:308(__step_run_and_handle_result)
# 52765/46217    0.037    0.000    0.045    0.000 {built-in method builtins.len}
#     54177    0.037    0.000    0.037    0.000 {method 'keys' of 'dict' objects}
#      7510    0.036    0.000   47.263    0.006 tasks.py:291(__step)
#      7047    0.036    0.000    0.310    0.000 _connection.py:426(next_event)
#       520    0.035    0.000    0.089    0.000 _headers.py:150(normalize_and_validate)
#       547    0.035    0.000    0.035    0.000 {method 'send' of '_socket.socket' objects}
#     18264    0.034    0.000    0.170    0.000 contextlib.py:141(__exit__)
#     18264    0.033    0.000    0.087    0.000 contextlib.py:299(helper)
#     54272    0.033    0.000    0.033    0.000 typing.py:1626(<genexpr>)
# 28781/28778    0.033    0.000    0.059    0.000 <frozen abc>:121(__subclasscheck__)
#     27648    0.032    0.000    0.365    0.000 _transform.py:126(_maybe_transform_key)
#      6527    0.032    0.000    0.988    0.000 http11.py:205(_receive_response_body)
#      4565    0.031    0.000    0.120    0.000 _connection.py:260(_process_event)
# 14976/13696    0.031    0.000    0.072    0.000 typing.py:1600(__hash__)
#     10127    0.030    0.000    0.065    0.000 base_events.py:813(_call_soon)
#      4331    0.029    0.000    0.091    0.000 {built-in method _heapq.heappop}
#     18264    0.028    0.000    0.322    0.000 contextlib.py:132(__enter__)
#     16304    0.028    0.000    0.045    0.000 _utils.py:31(normalize_header_key)
#       384    0.027    0.000    0.044    0.000 constraints.py:440(check)
#     34655    0.026    0.000    0.026    0.000 {method 'items' of 'dict' objects}
#  1024/256    0.026    0.000   23.959    0.094 _models.py:203(construct)
# 28781/28778    0.026    0.000    0.026    0.000 {built-in method _abc._abc_subclasscheck}
#       539    0.025    0.000    0.166    0.000 connection_pool.py:230(_assign_requests_to_connections)
# 36352/31488    0.025    0.000    0.036    0.000 {built-in method builtins.hash}
# 11743/11735    0.025    0.000   59.979    0.005 events.py:86(_run)
#      6899    0.025    0.000    1.282    0.000 _models.py:971(aiter_raw)
#        18    0.024    0.001    0.031    0.002 sock_client.py:123(_sendall_with_error_handle)
# 11743/11735    0.024    0.000   59.930    0.005 {method 'run' of '_contextvars.Context' objects}
#     10126    0.024    0.000    0.095    0.000 base_events.py:784(call_soon)
#      6899    0.024    0.000    1.322    0.000 _models.py:916(aiter_bytes)
#      1576    0.024    0.000    0.093    0.000 _models.py:64(__init__)
#      7047    0.023    0.000    0.162    0.000 _connection.py:398(_extract_next_receive_event)
#      6527    0.023    0.000    0.076    0.000 _readers.py:127(__call__)
#     26752    0.023    0.000    0.023    0.000 {method 'get' of 'mappingproxy' objects}
#      5487    0.022    0.000   45.799    0.008 completion_sampler.py:138(sample_completions)
#      2226    0.022    0.000   18.973    0.009 239833578.py:148(reward_completion)
#     13600    0.021    0.000    0.035    0.000 _models.py:27(enforce_bytes)
#      3266    0.021    0.000    0.021    0.000 _receivebuffer.py:53(__iadd__)
#     10017    0.021    0.000    0.075    0.000 {built-in method builtins.any}
#     10776    0.021    0.000    0.044    0.000 _util.py:84(validate)
#      6271    0.020    0.000    0.039    0.000 _receivebuffer.py:77(maybe_extract_at_most)
#     28773    0.020    0.000    0.020    0.000 {built-in method _asyncio.current_task}
#      7424    0.019    0.000    0.033    0.000 typing.py:521(__getitem__)
#      4332    0.019    0.000    0.075    0.000 base_events.py:766(call_at)
#      3517    0.019    0.000    0.019    0.000 _receivebuffer.py:67(_extract)
#     34979    0.019    0.000    0.019    0.000 typing.py:2183(cast)
#      6912    0.019    0.000    3.020    0.000 typing_extensions.py:1197(get_type_hints)
#      4508    0.019    0.000    0.042    0.000 trainer.py:334(<genexpr>)
#      1536    0.018    0.000    0.018    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#     26932    0.018    0.000    0.018    0.000 {method 'values' of 'dict' objects}
#       528    0.018    0.000    0.118    0.000 _urlparse.py:152(urlparse)
#     11904    0.018    0.000    0.042    0.000 typing.py:1285(__hash__)
#      6286    0.018    0.000    0.105    0.000 _asyncio.py:528(_timeout)
#      4993    0.018    0.000    0.038    0.000 _asyncio.py:2294(create_cancel_scope)
#      4565    0.017    0.000    0.026    0.000 _state.py:318(_fire_state_triggered_transitions)
#     11568    0.017    0.000    0.017    0.000 {method 'fullmatch' of 're.Pattern' objects}
#     23592    0.017    0.000    0.017    0.000 {method 'encode' of 'str' objects}
#     21817    0.017    0.000    0.018    0.000 {method 'add' of 'set' objects}
#     10296    0.017    0.000    0.027    0.000 _urlparse.py:212(<genexpr>)
# 4736/4160    0.017    0.000    0.018    0.000 completion.py:112(value)
#      8320    0.017    0.000    0.064    0.000 typing.py:113(get_origin)
#      8538    0.016    0.000    5.684    0.001 completion.py:294(all_entropy)
#     10436    0.016    0.000    0.061    0.000 _eventloop.py:154(get_async_backend)
#      6527    0.016    0.000    1.008    0.000 http11.py:337(__aiter__)
#       194    0.016    0.000    0.016    0.000 {method 'connect' of '_socket.socket' objects}
#      1196    0.016    0.000    0.054    0.000 _sockets.py:58(extra_attributes)
#     14286    0.016    0.000    0.016    0.000 {method 'size' of 'torch._C.TensorBase' objects}
# 5182/5103    0.016    0.000   37.993    0.007 _base_client.py:1541(_request)
#      5103    0.016    0.000   45.359    0.009 completions.py:1620(create)
#     13832    0.015    0.000    0.152    0.000 _utils.py:152(is_mapping)
#     27331    0.015    0.000    0.015    0.000 base_events.py:2010(get_debug)
#     15181    0.015    0.000    0.015    0.000 {built-in method time.monotonic}
#      7122    0.015    0.000   47.028    0.007 {method 'send' of 'coroutine' objects}
#     22116    0.015    0.000    0.015    0.000 {method 'append' of 'list' objects}
#     11052    0.015    0.000    0.026    0.000 base_events.py:733(time)
#      2980    0.015    0.000    0.015    0.000 {method 'search' of 're.Pattern' objects}
#      3894    0.015    0.000    1.385    0.000 _models.py:908(aread)
#     12558    0.014    0.000    0.022    0.000 connection.py:190(is_idle)
#      6016    0.014    0.000    0.019    0.000 _model_construction.py:257(__getattr__)
#      1350    0.014    0.000    0.528    0.000 http11.py:72(handle_async_request)
#     20416    0.014    0.000    0.014    0.000 {method 'lower' of 'str' objects}
#     20736    0.014    0.000    0.014    0.000 {built-in method builtins.vars}
#      8200    0.014    0.000    0.024    0.000 tasks.py:653(sleep)
#     16857    0.014    0.000    0.014    0.000 {method 'pop' of 'dict' objects}
#      4565    0.014    0.000    0.045    0.000 _state.py:275(process_event)
#      4332    0.013    0.000    0.028    0.000 events.py:155(cancel)
#      4821    0.013    0.000    0.035    0.000 _connection.py:330(_respond_to_state_changes)
#       520    0.013    0.000    0.032    0.000 _models.py:130(keys)
#     16138    0.013    0.000    0.013    0.000 {method 'popleft' of 'collections.deque' objects}
#     19179    0.013    0.000    0.013    0.000 _connection.py:212(their_state)
#     12898    0.013    0.000    0.013    0.000 {built-in method __new__ of type object at 0x755bd46eb4c0}
#     22614    0.012    0.000    0.012    0.000 _exceptions.py:7(map_exceptions)
#      1408    0.012    0.000    0.035    0.000 main.py:858(__setattr__)
#      6527    0.012    0.000    1.039    0.000 default.py:255(__aiter__)
#      6193    0.012    0.000    0.019    0.000 weakref.py:451(get)
#      3525    0.012    0.000    0.012    0.000 _events.py:299(__init__)
#     17584    0.012    0.000    0.012    0.000 {method 'lower' of 'bytes' objects}
#  1536/768    0.012    0.000    0.031    0.000 copy.py:118(deepcopy)
#      3516    0.012    0.000    0.020    0.000 __init__.py:280(_compile)
#      6527    0.012    0.000    1.022    0.000 connection_pool.py:361(__aiter__)
#      6527    0.012    0.000    1.052    0.000 _client.py:149(__aiter__)
#      1721    0.012    0.000    0.846    0.000 default.py:358(handle_async_request)
#       424    0.012    0.000    0.012    0.000 {method 'flush' of '_io.TextIOWrapper' objects}
#     16802    0.011    0.000    0.011    0.000 futures.py:181(done)
#      3696    0.011    0.000    0.022    0.000 _models.py:274(__contains__)
#       776    0.011    0.000    0.060    0.000 _models.py:61(enforce_headers)
#      4864    0.011    0.000    0.066    0.000 typing.py:166(get_args)
#      5737    0.011    0.000    0.015    0.000 events.py:72(cancel)
#      3462    0.011    0.000    0.034    0.000 locks.py:199(wait)
#     12698    0.011    0.000    0.014    0.000 trainer.py:337(<genexpr>)
#     15439    0.011    0.000    0.011    0.000 {method 'append' of 'collections.deque' objects}
#      4225    0.011    0.000    0.031    0.000 trainer.py:347(<genexpr>)
#      3162    0.011    0.000    0.029    0.000 selectors.py:69(__getitem__)
#      8152    0.011    0.000    0.017    0.000 _utils.py:47(normalize_header_value)
#      6996    0.011    0.000    0.011    0.000 _asyncio.py:376(__init__)
#      3162    0.011    0.000    0.043    0.000 selectors.py:180(get_key)
#      3303    0.011    0.000    0.041    0.000 futures.py:161(__schedule_callbacks)
#       384    0.011    0.000    0.081    0.000 categorical.py:52(__init__)
#      2176    0.011    0.000    0.025    0.000 typing.py:146(_generic_get_args)
#      4332    0.011    0.000    0.030    0.000 events.py:111(__init__)
#      5103    0.011    0.000    2.415    0.000 _client.py:1639(send)
#      5103    0.010    0.000   38.095    0.007 _base_client.py:1825(post)
#       267    0.010    0.000    0.010    0.000 encoder.py:205(iterencode)
#     16700    0.010    0.000    0.010    0.000 base_events.py:538(_check_closed)
#      4332    0.010    0.000    0.023    0.000 {built-in method _heapq.heappush}
#      7199    0.010    0.000    0.010    0.000 weakref.py:414(__getitem__)
#      1408    0.010    0.000   14.237    0.010 type_adapter.py:132(wrapped)
#      4190    0.010    0.000    0.022    0.000 _asyncio.py:2254(current_time)
#       384    0.009    0.000    0.009    0.000 {built-in method torch.all}
#     12686    0.009    0.000    0.009    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#      1721    0.009    0.000    0.772    0.000 connection_pool.py:159(handle_async_request)
#       256    0.009    0.000    0.050    0.000 main.py:243(model_construct)
#      9472    0.009    0.000    0.009    0.000 typing.py:1625(_value_and_type_iter)
#      5103    0.009    0.000   38.002    0.007 _base_client.py:1519(request)
#      1721    0.009    0.000    0.999    0.001 _client.py:1762(_send_single_request)
#     15824    0.009    0.000    0.009    0.000 {method 'isascii' of 'str' objects}
#      6193    0.009    0.000    0.015    0.000 _asyncio.py:371(__new__)
#     11832    0.009    0.000    0.009    0.000 {method 'groupdict' of 're.Match' objects}
#      4934    0.009    0.000    0.013    0.000 futures.py:286(__await__)
#      5016    0.009    0.000    0.014    0.000 _urlparse.py:162(<genexpr>)
#      1211    0.008    0.000    0.060    0.000 selector_events.py:278(_add_reader)
#     13338    0.008    0.000    0.008    0.000 {method '__exit__' of '_thread.RLock' objects}
#      3517    0.008    0.000    0.009    0.000 {method 'format' of 'str' objects}
#      5570    0.008    0.000    0.022    0.000 _asyncio.py:2262(checkpoint)
#      6548    0.008    0.000    0.012    0.000 _receivebuffer.py:60(__len__)
#      1032    0.008    0.000    0.022    0.000 main.py:782(__copy__)
#      1675    0.008    0.000    0.013    0.000 _trace.py:10(__init__)
#      5972    0.008    0.000    0.019    0.000 selectors.py:215(_fileobj_lookup)
#      1405    0.008    0.000    0.008    0.000 {method 'register' of 'select.epoll' objects}
#     13992    0.008    0.000    0.008    0.000 {method 'isprintable' of 'str' objects}
#      2653    0.008    0.000    8.989    0.003 tasks.py:383(__wakeup)
#      5972    0.008    0.000    0.011    0.000 selectors.py:21(_fileobj_to_fd)
#      1792    0.008    0.000    0.028    0.000 _utils.py:298(strip_not_given)
#       384    0.008    0.000    2.456    0.006 categorical.py:144(entropy)
#       120    0.008    0.000    0.122    0.001 random.py:341(choice)
#       384    0.008    0.000    0.061    0.000 distribution.py:40(__init__)
# 4224/1536    0.008    0.000   23.934    0.016 _models.py:382(_construct_field)
#      6656    0.008    0.000    0.075    0.000 _utils.py:168(is_iterable)
#      1388    0.008    0.000    0.042    0.000 selector_events.py:294(_remove_reader)
#       120    0.008    0.000    0.093    0.001 random.py:242(_randbelow_with_getrandbits)
#       528    0.007    0.000    0.099    0.000 http11.py:159(_send_request_body)
#     12764    0.007    0.000    0.007    0.000 trainer.py:269(model)
#      1624    0.007    0.000    0.034    0.000 _asyncio.py:2285(cancel_shielded_checkpoint)
#     12008    0.007    0.000    0.007    0.000 http11.py:295(is_idle)
#       768    0.007    0.000    1.262    0.002 completion.py:816(message_param)
#  1197/876    0.007    0.000    0.024    0.000 _asyncio.py:536(_deliver_cancellation)
#      3368    0.007    0.000    0.007    0.000 {method 'match' of 're.Pattern' objects}
#      7510    0.007    0.000    0.007    0.000 {built-in method _asyncio._leave_task}
#      3266    0.007    0.000    0.028    0.000 _connection.py:352(receive_data)
#      1390    0.007    0.000    0.007    0.000 {method 'getpeername' of '_socket.socket' objects}
#      9182    0.007    0.000    0.007    0.000 {built-in method _contextvars.copy_context}
#      3096    0.007    0.000    0.012    0.000 copy.py:61(copy)
#      2354    0.007    0.000   17.979    0.008 completion_sampler.py:386(sample_completions)
#       256    0.007    0.000    0.092    0.000 _models.py:1183(__init__)
#      1320    0.007    0.000    0.119    0.000 anyio.py:39(write)
#      7510    0.007    0.000    0.007    0.000 {built-in method _asyncio._enter_task}
#      8367    0.007    0.000    0.007    0.000 {method 'remove' of 'set' objects}
#      3302    0.007    0.000    0.009    0.000 futures.py:72(__init__)
#      1664    0.007    0.000    0.017    0.000 _compat.py:92(field_get_default)
#       835    0.007    0.000    0.023    0.000 tasks.py:111(__init__)
#      3660    0.007    0.000    0.079    0.000 http11.py:281(has_expired)
#      1024    0.007    0.000    0.032    0.000 typing_extensions.py:626(__instancecheck__)
#      1024    0.007    0.000    0.022    0.000 inspect.py:1845(getattr_static)
#      1819    0.007    0.000    0.668    0.000 connection.py:67(handle_async_request)
#      3551    0.007    0.000    0.012    0.000 futures.py:220(add_done_callback)
#      2204    0.007    0.000    0.017    0.000 _connection.py:308(_get_io_object)
#      1405    0.007    0.000    0.007    0.000 {method 'unregister' of 'select.epoll' objects}
#       264    0.007    0.000    0.098    0.000 _events.py:82(__init__)
#       169    0.006    0.000    0.006    0.000 {method 'shutdown' of '_socket.socket' objects}
#      2915    0.006    0.000    0.042    0.000 futures.py:251(set_result)
#      2088    0.006    0.000    0.009    0.000 _headers.py:205(get_comma_header)
#      3157    0.006    0.000    0.009    0.000 _weakrefset.py:85(add)
#        18    0.006    0.000    0.043    0.002 sock_client.py:147(_send_message)
#      3072    0.006    0.000    0.006    0.000 inspect.py:1832(_shadowed_dict)
#      1405    0.006    0.000    0.028    0.000 selectors.py:351(register)
#      2465    0.006    0.000    0.012    0.000 base_events.py:446(create_future)
#      1405    0.006    0.000    0.014    0.000 selectors.py:234(register)
#      4995    0.006    0.000    0.007    0.000 futures.py:189(result)
#      1408    0.006    0.000   20.237    0.014 _models.py:728(_validate_non_model_type)
#     10170    0.006    0.000    0.006    0.000 {built-in method _asyncio.get_running_loop}
#      2048    0.006    0.000    0.009    0.000 message.py:421(__setitem__)
#      1056    0.006    0.000    0.130    0.000 _urls.py:77(__init__)
#      8044    0.006    0.000    0.006    0.000 tasks.py:641(__sleep0)
#      9240    0.006    0.000    0.006    0.000 _util.py:127(bytesify)
#       512    0.006    0.000    0.014    0.000 _models.py:159(multi_items)
#       264    0.006    0.000    0.393    0.001 _base_client.py:446(_build_request)
#      1056    0.006    0.000    0.048    0.000 _asyncio.py:1225(send)
#      1832    0.006    0.000    0.009    0.000 ipaddress.py:1213(_parse_octet)
#      4488    0.006    0.000    0.009    0.000 <frozen _collections_abc>:1022(__iter__)
#      3163    0.006    0.000    0.009    0.000 _weakrefset.py:39(_remove)
#      1002    0.006    0.000    0.013    0.000 _utils.py:7(is_socket_readable)
#      6778    0.006    0.000    0.006    0.000 _decoders.py:215(decode)
#       582    0.006    0.000    0.089    0.000 _sockets.py:114(connect_tcp)
#      4314    0.006    0.000    0.006    0.000 {built-in method _abc._abc_instancecheck}
#      2226    0.006    0.000   17.977    0.008 episode.py:65(follow_up)
#       792    0.006    0.000    0.009    0.000 _base_client.py:2063(_merge_mappings)
#      4829    0.006    0.000    0.006    0.000 _state.py:301(_fire_event_triggered_transitions)
#      1056    0.006    0.000    0.022    0.000 _urlparse.py:452(quote)
#      2291    0.006    0.000    0.024    0.000 locks.py:181(set)
#      4314    0.006    0.000    0.011    0.000 <frozen abc>:117(__instancecheck__)
#      3918    0.006    0.000    0.008    0.000 connection.py:195(is_closed)
#      1721    0.006    0.000    1.014    0.001 _client.py:1690(_send_handling_auth)
#       520    0.006    0.000    0.010    0.000 _receivebuffer.py:104(maybe_extract_lines)
#      8538    0.005    0.000    0.005    0.000 completion.py:208(matches_model)
#      4096    0.005    0.000    0.009    0.000 request.py:397(add_header)
#      1408    0.005    0.000   21.581    0.015 _models.py:677(validate_type)
#      2460    0.005    0.000    0.032    0.000 __init__.py:174(search)
#       384    0.005    0.000    0.005    0.000 {built-in method torch.clamp}
#      4852    0.005    0.000    0.007    0.000 enum.py:202(__get__)
#      1628    0.005    0.000    0.044    0.000 _asyncio.py:1733(acquire)
#      1792    0.005    0.000    1.276    0.001 completion.py:405(message_params)
#      1408    0.005    0.000    9.389    0.007 type_adapter.py:341(validate_python)
#       768    0.005    0.000    2.433    0.003 utils.py:144(__get__)
#      6522    0.005    0.000    0.005    0.000 <string>:2(__eq__)
#  1792/640    0.005    0.000    1.281    0.002 completion.py:417(all_message_params)
#      3394    0.005    0.000    0.012    0.000 _asyncio.py:1186(_raw_socket)
#       256    0.005    0.000   28.480    0.111 _response.py:128(_parse)
#      3456    0.005    0.000    0.031    0.000 typing.py:417(is_literal_type)
#       384    0.005    0.000    0.005    0.000 {method 'clamp' of 'torch._C.TensorBase' objects}
#      1405    0.005    0.000    0.020    0.000 selectors.py:365(unregister)
#      3910    0.005    0.000    0.084    0.000 connection.py:185(has_expired)
#       628    0.005    0.000    0.176    0.000 connection_pool.py:369(aclose)
#       256    0.005    0.000    0.029    0.000 request.py:315(__init__)
#       264    0.005    0.000    0.007    0.000 _writers.py:22(write_headers)
#      2910    0.005    0.000    0.007    0.000 futures.py:301(_get_loop)
#      2104    0.005    0.000    0.005    0.000 _models.py:123(raw)
#      1024    0.005    0.000    0.006    0.000 inspect.py:1797(_check_instance)
#       256    0.005    0.000   35.141    0.137 _base_client.py:1674(_process_response)
#       256    0.005    0.000    0.008    0.000 _utils.py:241(wrapper)
#      2166    0.005    0.000    0.011    0.000 socket.py:100(_intenum_converter)
#      3394    0.005    0.000    0.007    0.000 transports.py:19(get_extra_info)
#      3274    0.005    0.000    0.015    0.000 _receivebuffer.py:57(__bool__)
#       520    0.005    0.000    0.044    0.000 _readers.py:94(maybe_read_from_SEND_RESPONSE_server)
#       264    0.005    0.000    0.055    0.000 _models.py:202(update)
#      1242    0.005    0.000    0.009    0.000 selector_events.py:750(_process_events)
#      2688    0.004    0.000    0.040    0.000 fields.py:552(get_default)
#      1196    0.004    0.000    0.080    0.000 anyio.py:84(get_extra_info)
#      1196    0.004    0.000    0.063    0.000 _typedattr.py:58(extra)
#      1211    0.004    0.000    0.067    0.000 selector_events.py:925(_add_reader)
#      2166    0.004    0.000    0.007    0.000 enum.py:720(__call__)
#       388    0.004    0.000    0.076    0.000 {method 'throw' of 'coroutine' objects}
#      4829    0.004    0.000    0.004    0.000 {method 'update' of 'dict' objects}
#      1816    0.004    0.000    0.055    0.000 _models.py:170(get)
#       768    0.004    0.000    0.013    0.000 copy.py:247(_reconstruct)
#       180    0.004    0.000    0.004    0.000 {function socket.close at 0x755bd2325d00}
#      5877    0.004    0.000    0.004    0.000 _connection.py:205(our_state)
#      1211    0.004    0.000    0.045    0.000 selector_events.py:851(pause_reading)
#       264    0.004    0.000    0.058    0.000 _models.py:375(_prepare)
#       264    0.004    0.000    0.171    0.001 _client.py:320(build_request)
#      2688    0.004    0.000    0.036    0.000 _utils.py:303(smart_deepcopy)
#       264    0.004    0.000    0.102    0.000 _models.py:311(__init__)
#       528    0.004    0.000    0.006    0.000 _models.py:232(__setitem__)
#      6193    0.004    0.000    0.005    0.000 _asyncio.py:579(_restart_cancellation_in_parent)
#      6257    0.004    0.000    0.004    0.000 tasks.py:252(cancelling)
#       512    0.004    0.000    0.028    0.000 _models.py:1204(info)
#       803    0.004    0.000    0.024    0.000 _synchronization.py:197(__init__)
#      1520    0.004    0.000    0.006    0.000 mixins.py:12(_get_loop)
#       792    0.004    0.000    0.048    0.000 _connection.py:518(send_with_data_passthrough)
#      1778    0.004    0.000    0.014    0.000 socket.py:517(family)
#      1583    0.004    0.000    0.004    0.000 locks.py:166(__init__)
#       528    0.004    0.000    0.006    0.000 _models.py:256(__delitem__)
#      1017    0.004    0.000    0.105    0.000 selector_events.py:1009(_read_ready__data_received)
#      1024    0.004    0.000    0.007    0.000 inspect.py:1806(_check_class)
#       528    0.004    0.000    0.198    0.000 http11.py:147(_send_request_headers)
#      1152    0.004    0.000    0.007    0.000 main.py:927(_check_frozen)
#      1721    0.004    0.000    1.004    0.001 _client.py:1724(_send_handling_redirects)
#      1664    0.004    0.000    0.006    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       655    0.004    0.000    0.009    0.000 streams.py:580(readuntil)
#      1320    0.004    0.000    0.175    0.000 http11.py:170(_send_event)
#       768    0.004    0.000    0.008    0.000 main.py:826(__getattr__)
#       442    0.004    0.000    0.034    0.000 _asyncio.py:698(__aexit__)
#       194    0.004    0.000    0.004    0.000 socket.py:221(__init__)
#       256    0.004    0.000    0.082    0.000 _models.py:810(construct)
#      2205    0.004    0.000    0.005    0.000 _models.py:173(__eq__)
#      4332    0.004    0.000    0.004    0.000 base_events.py:1910(_timer_handle_cancelled)
#      5288    0.004    0.000    0.004    0.000 {method 'strip' of 'str' objects}
#     60/50    0.004    0.000   68.844    1.377 mailbox.py:125(_wait)
#      4096    0.004    0.000    0.004    0.000 {method 'capitalize' of 'str' objects}
#      3773    0.004    0.000    0.004    0.000 _connection.py:248(_server_switch_event)
#       835    0.004    0.000    0.027    0.000 base_events.py:450(create_task)
#       708    0.004    0.000    0.061    0.000 connection_pool.py:301(_close_connections)
#       264    0.004    0.000    0.060    0.000 _base_client.py:411(_build_headers)
#      2321    0.003    0.000    0.010    0.000 base_events.py:551(_asyncgen_firstiter_hook)
#       384    0.003    0.000    0.003    0.000 {method 'abs' of 'torch._C.TensorBase' objects}
#       320    0.003    0.000    0.008    0.000 tasks.py:767(_done_callback)
#      1628    0.003    0.000    0.059    0.000 _synchronization.py:69(__aenter__)
#      1466    0.003    0.000    0.010    0.000 _synchronization.py:21(current_async_library)
#      2944    0.003    0.000    0.005    0.000 inspect.py:302(isclass)
#       825    0.003    0.000    0.004    0.000 _models.py:287(origin)
#      1017    0.003    0.000    0.022    0.000 _asyncio.py:1130(data_received)
#       388    0.003    0.000    0.096    0.000 connection.py:103(_connect)
#       528    0.003    0.000    0.037    0.000 selector_events.py:1055(write)
#       388    0.003    0.000    0.094    0.000 anyio.py:100(connect_tcp)
#      5512    0.003    0.000    0.003    0.000 {built-in method builtins.id}
#      2422    0.003    0.000    0.005    0.000 selector_events.py:848(is_reading)
#       388    0.003    0.000    0.005    0.000 base_events.py:100(_ipaddr_info)
#       582    0.003    0.000    0.095    0.000 _asyncio.py:2519(connect_tcp)
#       628    0.003    0.000    0.187    0.000 _client.py:153(aclose)
#      2443    0.003    0.000    0.005    0.000 base_events.py:1900(_add_callback)
#      2717    0.003    0.000    0.003    0.000 {built-in method builtins.max}
#      4488    0.003    0.000    0.003    0.000 _headers.py:117(__getitem__)
#       512    0.003    0.000    0.012    0.000 completion_sampler.py:70(_wait)
#      1280    0.003    0.000    0.012    0.000 _readers.py:64(_decode_header_lines)
#      1017    0.003    0.000    0.059    0.000 selector_events.py:859(resume_reading)
#      1405    0.003    0.000    0.008    0.000 selectors.py:247(unregister)
#       231    0.003    0.000    0.026    0.000 vllm.py:150(log_output)
#      2389    0.003    0.000    0.003    0.000 {method 'split' of 'str' objects}
#       528    0.003    0.000    0.026    0.000 http11.py:245(_response_closed)
#      3163    0.003    0.000    0.003    0.000 {method 'discard' of 'set' objects}
#       194    0.003    0.000    0.015    0.000 _asyncio.py:749(_spawn)
#        18    0.003    0.000    0.048    0.003 sock_client.py:156(send_server_request)
#       264    0.003    0.000    0.133    0.001 _base_client.py:430(_prepare_url)
#      1930    0.003    0.000    0.007    0.000 connection.py:165(can_handle_request)
#      2816    0.003    0.000    0.003    0.000 type_adapter.py:259(_with_frame_depth)
#      1056    0.003    0.000    0.012    0.000 __init__.py:219(finditer)
#       388    0.003    0.000    0.044    0.000 selector_events.py:631(sock_connect)
#      2304    0.003    0.000    0.004    0.000 _utils.py:164(is_list)
#       194    0.003    0.000    0.009    0.000 selector_events.py:779(__init__)
#      3668    0.003    0.000    0.003    0.000 http11.py:298(is_closed)
#       528    0.003    0.000    0.167    0.000 http11.py:179(_receive_response_headers)
#       458    0.003    0.000    0.015    0.000 ipaddress.py:1187(_ip_int_from_string)
#       659    0.003    0.000    0.012    0.000 {built-in method from_bytes}
#       201    0.003    0.000    0.003    0.000 {built-in method posix.urandom}
#       768    0.003    0.000    0.003    0.000 copy.py:231(_keep_alive)
#       496    0.003    0.000    0.010    0.000 tasks.py:522(_wait)
#       812    0.003    0.000    0.004    0.000 _asyncio.py:2266(checkpoint_if_cancelled)
#      1002    0.003    0.000    0.003    0.000 {method 'poll' of 'select.poll' objects}
#       628    0.003    0.000    0.194    0.000 _models.py:999(aclose)
#       628    0.003    0.000    0.179    0.000 default.py:260(aclose)
#       384    0.003    0.000    0.003    0.000 {method 'all' of 'torch._C.TensorBase' objects}
#       496    0.003    0.000    0.015    0.000 tasks.py:435(wait)
#       192    0.003    0.000    0.018    0.000 tasks.py:731(gather)
#       768    0.003    0.000    0.014    0.000 completion_sampler.py:62(_wait_if_needed)
#       520    0.003    0.000    0.003    0.000 _events.py:337(__init__)
#      3802    0.002    0.000    0.002    0.000 _synchronization.py:711(__enter__)
#      3802    0.002    0.000    0.002    0.000 _synchronization.py:717(__exit__)
#       256    0.002    0.000    0.014    0.000 _events.py:137(__init__)
#       582    0.002    0.000    0.004    0.000 selector_events.py:260(_ensure_fd_no_transport)
#       803    0.002    0.000    0.013    0.000 _tasks.py:28(__new__)
#       512    0.002    0.000    0.023    0.000 completion_sampler.py:50(acquire)
#      1196    0.002    0.000    0.004    0.000 _sockets.py:636(convert_ipv6_sockaddr)
#      3806    0.002    0.000    0.002    0.000 selector_events.py:845(is_closing)
#      2048    0.002    0.000    0.004    0.000 typing.py:1630(__eq__)
#       520    0.002    0.000    0.007    0.000 _connection.py:81(_body_framing)
#       582    0.002    0.000    0.083    0.000 base_events.py:1019(create_connection)
#       194    0.002    0.000    0.032    0.000 selector_events.py:656(_sock_connect)
#      3309    0.002    0.000    0.002    0.000 futures.py:91(__del__)
#       792    0.002    0.000    0.079    0.000 _urlparse.py:125(copy_with)
#       512    0.002    0.000    0.030    0.000 http11.py:351(aclose)
#       248    0.002    0.000    0.003    0.000 futures.py:236(remove_done_callback)
#       256    0.002    0.000    3.886    0.015 decoder.py:333(decode)
#      3988    0.002    0.000    0.002    0.000 _asyncio.py:626(cancelled_caught)
#       520    0.002    0.000    0.008    0.000 _utils.py:292(_get_time)
#       256    0.002    0.000    0.004    0.000 parse.py:374(urlparse)
#      2166    0.002    0.000    0.002    0.000 enum.py:1123(__new__)
#      2475    0.002    0.000    0.002    0.000 __init__.py:1790(isEnabledFor)
#       512    0.002    0.000    0.004    0.000 message.py:529(get_all)
#       256    0.002    0.000    0.037    0.000 cookiejar.py:1680(extract_cookies)
#       792    0.002    0.000    0.052    0.000 _connection.py:491(send)
#       256    0.002    0.000    3.946    0.015 __init__.py:299(loads)
#      1197    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:645(parent)
#      3220    0.002    0.000    0.002    0.000 connection_pool.py:39(is_queued)
#      1408    0.002    0.000    0.003    0.000 _fields.py:328(is_valid_field_name)
#       839    0.002    0.000    0.003    0.000 tasks.py:142(__del__)
#      1056    0.002    0.000    0.002    0.000 {method 'finditer' of 're.Pattern' objects}
#       938    0.002    0.000    0.004    0.000 _asyncio.py:1705(__init__)
#       256    0.002    0.000    0.002    0.000 _receivebuffer.py:64(__bytes__)
#      1032    0.002    0.000    0.024    0.000 main.py:324(model_copy)
#      1017    0.002    0.000    0.107    0.000 selector_events.py:969(_read_ready)
#      1196    0.002    0.000    0.009    0.000 trsock.py:76(getpeername)
#       231    0.002    0.000    0.002    0.000 {built-in method posix.read}
#      2724    0.002    0.000    0.002    0.000 futures.py:119(get_loop)
#       256    0.002    0.000    0.132    0.001 _models.py:1035(extract_cookies)
#      2652    0.002    0.000    0.002    0.000 239833578.py:155(<genexpr>)
#       388    0.002    0.000    0.050    0.000 base_events.py:976(_connect_sock)
#      3468    0.002    0.000    0.002    0.000 locks.py:177(is_set)
#      2249    0.002    0.000    0.002    0.000 {method 'appendleft' of 'collections.deque' objects}
#      1280    0.002    0.000    0.003    0.000 _readers.py:43(_obsolete_line_fold)
#       264    0.002    0.000    0.016    0.000 _content.py:176(encode_json)
#       458    0.002    0.000    0.017    0.000 ipaddress.py:1286(__init__)
#      2420    0.002    0.000    0.002    0.000 {method 'group' of 're.Match' objects}
#      1653    0.002    0.000    0.004    0.000 coroutines.py:32(iscoroutine)
#       256    0.002    0.000    0.005    0.000 typing_extensions.py:600(__subclasscheck__)
#   768/192    0.002    0.000    0.004    0.000 completion.py:91(commit)
#      1655    0.002    0.000    0.003    0.000 connection.py:173(is_available)
#       514    0.002    0.000    0.021    0.000 tasks.py:412(create_task)
#       256    0.002    0.000   23.999    0.094 _base_client.py:571(_process_response_data)
#       512    0.002    0.000    0.003    0.000 _decoders.py:238(flush)
#       520    0.002    0.000    0.002    0.000 _urlparse.py:106(authority)
#      3162    0.002    0.000    0.002    0.000 selectors.py:272(get_map)
#      1229    0.002    0.000    0.003    0.000 nest_asyncio.py:37(_get_event_loop)
#      1196    0.002    0.000    0.011    0.000 trsock.py:18(family)
#       264    0.002    0.000    0.007    0.000 _client.py:376(default_headers)
#      2443    0.002    0.000    0.002    0.000 selectors.py:275(_key_from_fd)
#      3261    0.002    0.000    0.002    0.000 _decoders.py:31(decode)
#       814    0.002    0.000    0.002    0.000 _asyncio.py:1774(release)
#      2750    0.002    0.000    0.002    0.000 {built-in method _asyncio._get_running_loop}
#       776    0.002    0.000    0.002    0.000 _asyncio.py:1728(__init__)
#       384    0.002    0.000    0.007    0.000 utils.py:93(clamp_probs)
#       384    0.002    0.000    2.422    0.006 categorical.py:95(logits)
#       388    0.002    0.000    0.012    0.000 _synchronization.py:58(setup)
#       192    0.002    0.000    0.026    0.000 episode.py:402(_sample_completions)
#       256    0.002    0.000    0.003    0.000 _models.py:180(get_list)
#      1536    0.002    0.000    0.007    0.000 copy.py:252(<genexpr>)
#       192    0.002    0.000    0.002    0.000 std.py:419(format_num)
#       194    0.002    0.000    0.021    0.000 selector_events.py:936(__init__)
#       768    0.002    0.000    0.002    0.000 {method '__reduce_ex__' of 'object' objects}
#       582    0.002    0.000    0.107    0.000 _sockets.py:162(try_connect)
#       256    0.002    0.000    0.017    0.000 cookiejar.py:1599(make_cookies)
#       338    0.002    0.000    0.024    0.000 connection.py:168(aclose)
#       118    0.002    0.000    0.035    0.000 trainer.py:307(eval)
#      1803    0.002    0.000    0.002    0.000 {method 'copy' of 'dict' objects}
#       194    0.002    0.000    0.005    0.000 _asyncio.py:1115(connection_made)
#       264    0.002    0.000    0.003    0.000 _base_client.py:607(default_headers)
#       814    0.002    0.000    0.004    0.000 _synchronization.py:80(__aexit__)
#       835    0.002    0.000    0.004    0.000 {built-in method _asyncio._register_task}
#       655    0.002    0.000    0.011    0.000 streams.py:549(readline)
#       363    0.002    0.000    0.009    0.000 selector_events.py:331(_remove_writer)
#       386    0.002    0.000    0.013    0.000 tasks.py:670(ensure_future)
#       192    0.002    0.000    0.529    0.003 episode.py:42(last_assistant_message)
#       520    0.002    0.000    0.005    0.000 _connection.py:72(_keep_alive)
#       384    0.002    0.000    2.420    0.006 utils.py:119(probs_to_logits)
#        64    0.002    0.000    0.006    0.000 std.py:1402(set_postfix)
#       528    0.002    0.000    0.003    0.000 _auth.py:87(async_auth_flow)
#       388    0.002    0.000    0.027    0.000 base_events.py:1166(_create_connection_transport)
#      1792    0.002    0.000    0.002    0.000 {method 'endswith' of 'bytearray' objects}
#       388    0.002    0.000    0.009    0.000 tasks.py:210(cancel)
#      1559    0.002    0.000    0.002    0.000 {method 'remove' of 'collections.deque' objects}
#       792    0.002    0.000    0.002    0.000 _urls.py:282(raw_path)
#       803    0.002    0.000    0.009    0.000 _synchronization.py:216(__exit__)
#      1453    0.002    0.000    0.002    0.000 {method 'rpartition' of 'str' objects}
#       256    0.001    0.000    0.002    0.000 _base_client.py:1891(make_request_options)
#       512    0.001    0.000    0.029    0.000 _models.py:373(__init__)
#       267    0.001    0.000    0.012    0.000 encoder.py:183(encode)
#      2460    0.001    0.000    0.001    0.000 enum.py:1286(value)
#      1040    0.001    0.000    0.002    0.000 _utils.py:122(is_given)
#       346    0.001    0.000    0.020    0.000 _asyncio.py:1250(aclose)
#       384    0.001    0.000    0.013    0.000 completion_sampler.py:355(_remove_prefix_and_unwanted_leading_tokens)
#       469    0.001    0.000    0.005    0.000 _asyncio.py:2326(create_event)
#       803    0.001    0.000    0.014    0.000 _synchronization.py:209(__enter__)
#       388    0.001    0.000    0.003    0.000 _asyncio.py:2330(create_lock)
#       528    0.001    0.000    0.012    0.000 <frozen _collections_abc>:940(pop)
#       256    0.001    0.000    0.006    0.000 request.py:297(request_host)
#       194    0.001    0.000    0.011    0.000 selector_events.py:315(_add_writer)
#       528    0.001    0.000    0.009    0.000 <frozen _collections_abc>:992(setdefault)
#       256    0.001    0.000    0.002    0.000 __init__.py:244(detect_encoding)
#       469    0.001    0.000    0.008    0.000 _synchronization.py:81(__new__)
#       231    0.001    0.000    0.008    0.000 unix_events.py:523(_read_ready)
#     22/12    0.001    0.000  122.607   10.217 mailbox.py:249(wait)
#       256    0.001    0.000    0.005    0.000 _models.py:633(_get_content_decoder)
#       768    0.001    0.000    0.001    0.000 {built-in method torch._C._set_grad_enabled}
#       784    0.001    0.000    0.002    0.000 parse.py:676(unquote)
#   768/192    0.001    0.000    0.005    0.000 completion.py:241(all_absent_stop_tokens)
#       264    0.001    0.000    0.037    0.000 _models.py:326(__init__)
#       427    0.001    0.000    0.002    0.000 _asyncio.py:362(is_anyio_cancellation)
#       576    0.001    0.000    0.001    0.000 completion.py:65(__init__)
#       768    0.001    0.000    0.004    0.000 completion.py:234(absent_stop_tokens)
#       256    0.001    0.000    4.191    0.016 _models.py:765(json)
#      1002    0.001    0.000    0.002    0.000 trsock.py:56(fileno)
#       528    0.001    0.000    0.012    0.000 _urlparse.py:303(encode_host)
#       194    0.001    0.000    0.003    0.000 _connection.py:155(__init__)
#      1002    0.001    0.000    0.005    0.000 _sockets.py:67(<lambda>)
#       256    0.001    0.000    0.008    0.000 request.py:339(full_url)
#       768    0.001    0.000    0.002    0.000 copyreg.py:98(__newobj__)
#       384    0.001    0.000    0.002    0.000 grad_mode.py:135(__enter__)
#       462    0.001    0.000    0.004    0.000 streams.py:521(_wait_for_data)
#      1088    0.001    0.000    0.002    0.000 completion.py:776(__hash__)
#       264    0.001    0.000    0.057    0.000 _client.py:404(_merge_headers)
#       194    0.001    0.000    0.002    0.000 _asyncio.py:756(task_done)
#       256    0.001    0.000    0.005    0.000 request.py:370(_parse)
#      1675    0.001    0.000    0.001    0.000 _trace.py:93(__aexit__)
#       388    0.001    0.000    0.006    0.000 base_events.py:1452(_ensure_resolved)
#       834    0.001    0.000    0.001    0.000 futures.py:205(exception)
#       388    0.001    0.000    0.006    0.000 _synchronization.py:140(__new__)
#      2064    0.001    0.000    0.001    0.000 _exceptions.py:366(request_context)
#       275    0.001    0.000    0.010    0.000 _synchronization.py:116(setup)
#      1024    0.001    0.000    0.001    0.000 _compat.py:109(get_model_config)
#       768    0.001    0.000    0.002    0.000 constraints.py:148(is_dependent)
#      1304    0.001    0.000    0.001    0.000 {method 'split' of 'bytes' objects}
#       194    0.001    0.000    0.004    0.000 http11.py:54(__init__)
#       194    0.001    0.000    0.001    0.000 {method 'getsockname' of '_socket.socket' objects}
#       114    0.001    0.000    0.001    0.000 {method 'settimeout' of '_socket.socket' objects}
#      2048    0.001    0.000    0.001    0.000 _policybase.py:313(header_store_parse)
#      1832    0.001    0.000    0.001    0.000 {method 'isdigit' of 'str' objects}
#       256    0.001    0.000    0.003    0.000 _urlparse.py:139(__str__)
#      1584    0.001    0.000    0.001    0.000 {method 'fileno' of '_socket.socket' objects}
#       194    0.001    0.000    0.005    0.000 base_events.py:192(_set_nodelay)
#       264    0.001    0.000    0.004    0.000 _client.py:437(_build_request_auth)
#       512    0.001    0.000    0.004    0.000 _typing.py:47(extract_type_arg)
#       264    0.001    0.000    0.006    0.000 _models.py:402(read)
#       231    0.001    0.000    0.006    0.000 streams.py:499(feed_data)
#       528    0.001    0.000    0.003    0.000 _writers.py:63(__call__)
#       256    0.001    0.000    7.242    0.028 _transform.py:265(async_transform)
#       512    0.001    0.000    0.024    0.000 completion_sampler.py:96(__aenter__)
#       805    0.001    0.000    0.002    0.000 completion.py:235(<genexpr>)
#       388    0.001    0.000    0.006    0.000 futures.py:146(cancel)
#       384    0.001    0.000    0.001    0.000 utils.py:160(__init__)
#      1032    0.001    0.000    0.001    0.000 {method 'copy' of 'set' objects}
#      1024    0.001    0.000    0.001    0.000 _compat.py:115(get_model_fields)
#       384    0.001    0.000    0.001    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#      1675    0.001    0.000    0.001    0.000 _trace.py:87(__aenter__)
#       528    0.001    0.000    0.002    0.000 _urlparse.py:377(validate_path)
#       264    0.001    0.000    0.008    0.000 _writers.py:36(write_request)
#      1304    0.001    0.000    0.001    0.000 {method 'strip' of 'bytes' objects}
#       528    0.001    0.000    0.002    0.000 _urlparse.py:437(percent_encoded)
#      2048    0.001    0.000    0.001    0.000 _policybase.py:209(header_max_count)
#       194    0.001    0.000    0.002    0.000 _asyncio.py:335(get_callable_name)
#       388    0.001    0.000    0.090    0.000 auto.py:21(connect_tcp)
# ...
#       264    0.000    0.000    0.000    0.000 _client.py:309(params)
#        18    0.000    0.000    0.070    0.004 interface_sock.py:49(_publish)
#       264    0.000    0.000    0.000    0.000 copy.py:102(_copy_immutable)
#        29    0.000    0.000    0.000    0.000 _weakrefset.py:53(_commit_removals)
#       194    0.000    0.000    0.000    0.000 transports.py:14(__init__)
#         6    0.000    0.000    0.002    0.000 iostream.py:118(_run_event_pipe_gc)
#       181    0.000    0.000    0.000    0.000 queues.py:95(empty)
#       2/1    0.000    0.000   56.338   56.338 {built-in method builtins.exec}
#       264    0.000    0.000    0.000    0.000 _base_client.py:599(custom_auth)
#       177    0.000    0.000    0.000    0.000 selector_events.py:896(_force_close)
#        29    0.000    0.000    0.000    0.000 _weakrefset.py:27(__exit__)
#        10    0.000    0.000    0.137    0.014 mailbox.py:442(get_handle)
#       128    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#       194    0.000    0.000    0.000    0.000 selector_events.py:838(set_protocol)
#        14    0.000    0.000    0.001    0.000 _weakrefset.py:37(__init__)
#       192    0.000    0.000    0.000    0.000 {method 'get_loop' of '_asyncio.Future' objects}
#        65    0.000    0.000    0.000    0.000 builtins.py:108(gen)
#        14    0.000    0.000    0.001    0.000 _monitor.py:47(get_instances)
#       194    0.000    0.000    0.000    0.000 anyio.py:20(__init__)
#        64    0.000    0.000    0.000    0.000 completion_sampler.py:411(get_model)
#         9    0.000    0.000    0.000    0.000 std.py:102(acquire)
#       194    0.000    0.000    0.000    0.000 trsock.py:15(__init__)
#        10    0.000    0.000    0.130    0.013 mailbox.py:433(_allocate_slot)
#       194    0.000    0.000    0.000    0.000 tasks.py:158(get_coro)
#         6    0.000    0.000    1.603    0.267 interface.py:910(deliver_internal_messages)
#       192    0.000    0.000    0.000    0.000 episode.py:54(reward)
#        10    0.000    0.000    0.128    0.013 mailbox.py:16(_generate_address)
#        10    0.000    0.000    0.000    0.000 threading.py:277(__init__)
#       194    0.000    0.000    0.000    0.000 events.py:83(cancelled)
#        10    0.000    0.000    0.140    0.014 interface_shared.py:450(_deliver_record)
#       105    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#        18    0.000    0.000    0.000    0.000 interface_sock.py:45(_assign)
#       120    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#        18    0.000    0.000    0.000    0.000 {method 'ByteSize' of 'google._upb._message.Message' objects}
#        64    0.000    0.000    0.000    0.000 queues.py:50(_get)
#        20    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         8    0.000    0.000    0.000    0.000 _base_client.py:687(_calculate_retry_timeout)
#        24    0.000    0.000    0.000    0.000 wandb_run.py:283(<lambda>)
#        10    0.000    0.000    0.001    0.000 router.py:102(_handle_msg_rcv)
#        10    0.000    0.000    0.001    0.000 mailbox.py:137(_deliver)
#         8    0.000    0.000    0.000    0.000 std.py:760(get_lock)
#       2/1    0.000    0.000    0.202    0.202 nest_asyncio.py:86(run_until_complete)
#        64    0.000    0.000    0.000    0.000 timeouts.py:33(__init__)
#        10    0.000    0.000    0.000    0.000 threading.py:588(__init__)
#        32    0.000    0.000    0.001    0.000 {method 'throw' of 'generator' objects}
#        14    0.000    0.000    0.001    0.000 _weakrefset.py:120(update)
#        20    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#        29    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#         7    0.000    0.000    0.019    0.003 interface_shared.py:435(_publish_keepalive)
#         1    0.000    0.000    0.000    0.000 inspect.py:3133(_bind)
#        10    0.000    0.000    0.000    0.000 mailbox.py:110(__init__)
#         1    0.000    0.000    0.001    0.001 interface.py:618(publish_partial_history)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         9    0.000    0.000    0.000    0.000 std.py:106(release)
#         4    0.000    0.000    0.050    0.013 interface_shared.py:485(_deliver_stop_status)
#        10    0.000    0.000    0.000    0.000 {method 'ParseFromString' of 'google._upb._message.Message' objects}
#        77    0.000    0.000    0.000    0.000 sock_client.py:34(length)
#         3    0.000    0.000    0.000    0.000 selector_events.py:807(__repr__)
#        10    0.000    0.000    0.001    0.000 mailbox.py:426(deliver)
#        10    0.000    0.000    0.000    0.000 sock_client.py:77(put)
#         6    0.000    0.000    0.128    0.021 interface_shared.py:499(_deliver_internal_messages)
#         4    0.000    0.000    0.051    0.013 interface.py:894(deliver_stop_status)
#        18    0.000    0.000    0.000    0.000 threading.py:1155(_wait_for_tstate_lock)
#        64    0.000    0.000    0.000    0.000 std.py:1198(update)
#        14    0.000    0.000    0.001    0.000 _weakrefset.py:95(copy)
#        64    0.000    0.000    0.000    0.000 queues.py:99(full)
#        16    0.000    0.000    0.001    0.000 _eventloop.py:80(sleep)
#        10    0.000    0.000    0.000    0.000 sock_client.py:74(peek)
#        64    0.000    0.000    0.000    0.000 completion_sampler.py:341(get_model)
#        65    0.000    0.000    0.000    0.000 std.py:1325(refresh)
#        64    0.000    0.000    0.000    0.000 episode.py:253(<genexpr>)
#        11    0.000    0.000    0.000    0.000 connection_pool.py:27(clear_connection)
#        17    0.000    0.000    0.000    0.000 interface_shared.py:64(_transport_mark_success)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#        11    0.000    0.000    0.000    0.000 threading.py:627(clear)
#        10    0.000    0.000    0.000    0.000 mailbox.py:321(abandon)
#        64    0.000    0.000    0.000    0.000 episode.py:414(<genexpr>)
#         9    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#        10    0.000    0.000    0.000    0.000 mailbox.py:145(_notify_abandon)
#        16    0.000    0.000    0.001    0.000 _asyncio.py:2290(sleep)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#        18    0.000    0.000    0.000    0.000 {method 'SerializeToString' of 'google._upb._message.Message' objects}
#        29    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#         6    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#        10    0.000    0.000    0.000    0.000 mailbox.py:318(_release)
#         8    0.000    0.000    0.000    0.000 selector_events.py:882(_fatal_error)
#         4    0.000    0.000    0.000    0.000 wandb_run.py:295(_process_stop_status)
#         9    0.000    0.000    0.000    0.000 std.py:110(__enter__)
#         1    0.000    0.000    0.000    0.000 notebook.py:202(__init__)
#         1    0.000    0.000    0.000    0.000 history.py:845(writeout_cache)
#         9    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#        12    0.000    0.000    0.000    0.000 wandb_run.py:327(<lambda>)
#         8    0.000    0.000    0.000    0.000 _exceptions.py:112(__init__)
#         1    0.000    0.000    0.000    0.000 std.py:663(__new__)
#         6    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:221(__subclasshook__)
#         8    0.000    0.000    0.000    0.000 _exceptions.py:92(__init__)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         8    0.000    0.000    0.000    0.000 wandb_run.py:307(<lambda>)
#         6    0.000    0.000    0.000    0.000 selector_events.py:42(_test_selector_event)
#         2    0.000    0.000    0.000    0.000 nest_asyncio.py:141(manage_run)
#       2/1    0.000    0.000    0.202    0.202 nest_asyncio.py:25(run)
#        10    0.000    0.000    0.000    0.000 sock_client.py:71(get)
#         1    0.000    0.000    0.000    0.000 std.py:952(__init__)
#        10    0.000    0.000    0.000    0.000 mailbox.py:439(_release_slot)
#        10    0.000    0.000    0.000    0.000 interface_shared.py:445(_get_mailbox)
#         1    0.000    0.000    0.000    0.000 inspect.py:2949(apply_defaults)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.001    0.001 wandb_run.py:1512(_partial_history_callback)
#        20    0.000    0.000    0.000    0.000 mailbox.py:332(address)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 inspect.py:2896(args)
#         1    0.000    0.000    0.000    0.000 history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 futures.py:347(_copy_future_state)
#         1    0.000    0.000    0.001    0.001 wandb_run.py:1641(_log)
#         1    0.000    0.000    0.001    0.001 wandb_run.py:367(wrapper)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 base_events.py:1995(_set_coroutine_origin_tracking)
#        18    0.000    0.000    0.000    0.000 tracelog.py:205(log_message_send)
#         1    0.000    0.000    0.000    0.000 inspect.py:3272(bind)
#         1    0.000    0.000    0.000    0.000 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 utils.py:213(__init__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 utils.py:187(disable_on_exception)
#         1    0.000    0.000    0.000    0.000 std.py:679(_get_free_pos)
#        10    0.000    0.000    0.000    0.000 mailbox.py:231(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 builtins.py:87(iter)
#       2/1    0.000    0.000    0.000    0.000 wandb_settings.py:1454(__getattribute__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 queues.py:33(__init__)
#         3    0.000    0.000    0.000    0.000 util.py:840(json_dumps_safer_history)
#         1    0.000    0.000    0.001    0.001 wandb_run.py:421(wrapper)
#         1    0.000    0.000    0.000    0.000 utils.py:34(history_dict_to_json)
#       2/1    0.000    0.000    0.000    0.000 wandb_settings.py:530(value)
#         1    0.000    0.000    0.000    0.000 functools.py:393(__get__)
#        10    0.000    0.000    0.000    0.000 inspect.py:2808(kind)
#         1    0.000    0.000    0.001    0.001 interface_shared.py:85(_publish_partial_history)
#         1    0.000    0.000    0.000    0.000 base_events.py:2013(set_debug)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.pow}
#         1    0.000    0.000    0.001    0.001 wandb_run.py:1679(log)
#         1    0.000    0.000    0.000    0.000 inspect.py:2919(kwargs)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         9    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#        10    0.000    0.000    0.000    0.000 tracelog.py:209(log_message_recv)
#         1    0.000    0.000    0.000    0.000 wandb_run.py:826(__setattr__)
#         3    0.000    0.000    0.000    0.000 <frozen _collections_abc>:104(_check_methods)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         1    0.000    0.000    0.000    0.000 base_events.py:837(call_soon_threadsafe)
#         3    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         8    0.000    0.000    0.000    0.000 _exceptions.py:102(request)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 wandb_run.py:1477(_visualization_hack)
#         1    0.000    0.000    0.000    0.000 _base.py:393(done)
#         1    0.000    0.000    0.000    0.000 decorator.py:229(fun)
#         3    0.000    0.000    0.000    0.000 utils.py:152(wrapper_setattr)
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'google._upb._message.RepeatedCompositeContainer' objects}
#         1    0.000    0.000    0.001    0.001 wandb_run.py:400(wrapper_fn)
#         2    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         2    0.000    0.000    0.000    0.000 utils.py:62(val_to_json)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 futures.py:383(_set_state)
#         1    0.000    0.000    0.000    0.000 queues.py:47(_init)
#         8    0.000    0.000    0.000    0.000 _base_client.py:653(_parse_retry_after_header)
#         1    0.000    0.000    0.000    0.000 _base.py:428(result)
#         1    0.000    0.000    0.000    0.000 utils.py:156(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         3    0.000    0.000    0.000    0.000 wandb_run.py:1650(<genexpr>)
#         4    0.000    0.000    0.000    0.000 inspect.py:2796(name)
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         4    0.000    0.000    0.000    0.000 inspect.py:3089(parameters)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:110(remove)
#         1    0.000    0.000    0.000    0.000 std.py:1147(__del__)
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 _base.py:383(cancelled)
#         1    0.000    0.000    0.000    0.000 _base.py:463(exception)
#         4    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 wandb_settings.py:731(<lambda>)
#         1    0.000    0.000    0.000    0.000 trainer.py:863(get_completion_sampler)
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio._set_running_loop}
#         1    0.000    0.000    0.000    0.000 futures.py:389(_call_check_cancel)
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:268(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:200(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2888(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 notebook.py:272(close)
#         1    0.000    0.000    0.000    0.000 base_events.py:729(is_running)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 _base.py:398(__get_result)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 kernelbase.py:570(<lambda>)

# %%
await trainer.explore()

# %%
await trainer.tune(trainer.explore_results[-1])

# %%
await trainer.eval("val", verbosity=1)

# %%
await trainer.train(iterations=4, verbosity=1)
