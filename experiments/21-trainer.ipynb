# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#     background-color: transparent !important;
# }
# :root {
#     --jp-widgets-color: var(--vscode-editor-foreground);
#     --jp-widgets-font-size: var(--vscode-editor-font-size);
# }
# </style>

# %%
import asyncio
import httpx
import json
from lib.rl.episode import Episode, EpisodeCompletion
from lib.rl.ppo import PPOLoss
from lib.rl.recipe import ComponentConfig, TuneRecipeConfig
from lib.rl.trainer import ExploreOptions, Trainer, vLLMConfig
import random
import re
import torch
from torchtune.models.llama3_1 import llama3_1_8b
from typing import Any, AsyncIterable, Literal, Optional

with open("./data/chain-of-thought-examples.json") as f:
    chain_of_thought_examples: list[dict[str, str]] = json.load(f)


async def sample_random_episode(
    difficulty: Literal["easy", "variable"] = "variable",
    example_probability: float = 0.0,
    max_prompt_characters: int = 8192,
    reward_follow_up_completion: bool = True,
    return_first_solver_as_winner: Optional[bool] = None,
) -> Episode:
    while True:
        async with httpx.AsyncClient(timeout=httpx.Timeout(5.0, read=600.0)) as client:
            params: dict[str, Any] = {
                "difficulty": difficulty,
            }
            if return_first_solver_as_winner is not None:
                params["return_first_solver_as_winner"] = return_first_solver_as_winner
            response = await client.get(
                "http://0.0.0.0:2218/new-episode-data",
                params=params,
            )
            response.raise_for_status()
            result = response.json()
            prompt = result["prompt"]
            follow_up = result["follow_up"]
            solution = result["solution"]
        if len(prompt) <= max_prompt_characters:
            break

    async def reward_completion(completion: EpisodeCompletion) -> EpisodeCompletion:
        if len(completion.messages) == 2:
            follow_up_completion = await completion.follow_up(
                messages=[
                    {"role": "user", "content": follow_up},
                ],
                max_tokens=10
                + len("\n".join(f"{key}: {value}" for key, value in solution.items()))
                // 2,
            )
        else:
            follow_up_completion = completion
        answer = follow_up_completion.last_assistant_message.get("content")
        assert isinstance(answer, str)
        if reward_follow_up_completion:
            completion = follow_up_completion
        completion.reward = sum(
            [
                bool(
                    # Find first match of key followed by colon and capture following text
                    (
                        match := re.search(
                            rf"{key}: ([A-Za-z \.:-]+)",
                            answer,
                            re.IGNORECASE,
                        )
                    )
                    # Check if captured group matches expected value
                    and match.group(1).strip().lower() == value.strip().lower()
                )
                for key, value in solution.items()
            ]
        ) / len(solution)
        completion.reward -= (
            completion.all_absent_stop_tokens
            / (3 if reward_follow_up_completion else 2)
            / len(solution)
        )
        return completion

    async def on_sample(completions: list[EpisodeCompletion]) -> None:
        for completion in await asyncio.gather(
            *[reward_completion(completion) for completion in completions]
        ):
            completion.commit()

    example = random.choice(chain_of_thought_examples)

    return Episode(
        messages=[{"role": "user", "content": prompt}],
        examples=lambda: (
            [
                {"role": "user", "content": example["prompt"]},
                {
                    "role": "assistant",
                    "content": example["chain_of_thought"]
                    + (example["answer"] and f"\n\n---\n\n{example['answer']}"),
                },
            ]
            if random.random() < example_probability
            else []
        ),
        on_sample=on_sample,
    )


episodes_per_iteration = 64 * torch.cuda.device_count()


async def train_episodes() -> AsyncIterable[Episode | BaseException]:
    pending: set[asyncio.Task[Episode | BaseException]] = set()
    while True:
        pending.update(
            asyncio.create_task(sample_random_episode())
            for _ in range(episodes_per_iteration - len(pending))
        )
        done, pending = await asyncio.wait(pending, return_when=asyncio.FIRST_COMPLETED)
        for task in done:
            try:
                yield task.result()
            except BaseException as e:
                yield e


async def val_episodes() -> AsyncIterable[Episode | BaseException]:
    for fut in asyncio.as_completed(
        sample_random_episode() for _ in range(64 * torch.cuda.device_count())
    ):
        try:
            yield await fut
        except BaseException as e:
            yield e


model_name = "rl33"

trainer = Trainer(
    base_model="NousResearch/Hermes-2-Theta-Llama-3-8B",
    output_dir=f"./models/{model_name}",
    explore_options=ExploreOptions(
        iterations=8,
        num_parents=5,
        branch_factor=3,
        patience=5,
        sample_probability_power=None,
        sampling_kwargs={"max_tokens": 1024},
        split_method="prob",
        split_point_std_deviation=0.5,
    ),
    train_episodes=train_episodes(),
    episodes_per_iteration=episodes_per_iteration,
    max_mask_sequence_batch_size=1,
    val_episodes=val_episodes(),
    val_patience=15,
    val_samples_per_episode=3,
    val_sampling_kwargs={"max_tokens": 1024},
    tune_model=llama3_1_8b,
    tune_model_type="LLAMA3",
    tune_recipe_config=TuneRecipeConfig(
        seed=42,
        shuffle=True,
        num_output_chunks=4,
        resume_from_checkpoint=False,
        batch_size=1,
        epochs=1,
        max_steps_per_epoch=32,
        optimizer=ComponentConfig(
            "torch.optim.AdamW",
            # "bitsandbytes.optim.PagedAdamW8bit",
            # "bitsandbytes.optim.AdamW",
            # params=PLACEHOLDER,
            lr=4e-6,
            fused=True,
        ),
        loss=ComponentConfig(
            PPOLoss,
            policy_coef=0.0,
            clip_epsilon=0.2,
            unclipped_policy_coef=0.0,
            tanh_log_policy_coef=0.9,
            value_coef=0.0,
            entropy_coef=0.0,
            entropy_target=0.75,
            entropy_target_coef=0.15,
            kl_coef=0.25,
            weighted_entropy_coef=0.1,
            weighted_kl_coef=0.0,
            weighted_ce_coef=0.0,
            normalize_values=False,
            normalize_advantages=False,
        ),
        compile=False,
        optimizer_in_bwd=False,
        gradient_accumulation_steps=1,
        enable_activation_checkpointing=True,
        enable_activation_offloading=False,
        custom_sharded_layers=["tok_embeddings", "output"],
        log_every_n_steps=1,
        log_peak_memory_stats=True,
    ),
    # tune_run=False,
    tune_sequence_length=16384,
    vllm_config=vLLMConfig(
        env={"VLLM_ALLOW_LONG_MAX_MODEL_LEN": "1"},
        kwargs=dict(
            block_size=32,
            disable_log_requests=True,
            enable_prefix_caching=True,
            enforce_eager=True,
            gpu_memory_utilization=0.95,
            max_model_len=16384,
            max_num_seqs=4096,
            max_num_batched_tokens=16384,
            preemption_mode="swap",
            return_tokens_as_token_ids=True,
            swap_space=32,
        ),
        max_concurrent_samples=4096,
        timeout=120 + 15 * torch.cuda.device_count(),
    ),
    wandb_kwargs=dict(
        name=model_name,
        id=model_name,
    ),
)
# Out:
# INFO 12-14 21:09:59 llm_engine.py:237] Initializing an LLM engine (v0.6.3.post1) with config: model='NousResearch/Hermes-2-Theta-Llama-3-8B', speculative_config=None, tokenizer='NousResearch/Hermes-2-Theta-Llama-3-8B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=NousResearch/Hermes-2-Theta-Llama-3-8B, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, mm_processor_kwargs=None)
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: bradhilton. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/home/ubuntu/atreides/experiments/wandb/run-20241214_211000-rl33</code>
# Resuming run <strong><a href='https://wandb.ai/bradhilton/atreides-experiments/runs/rl33' target="_blank">rl33</a></strong> to <a href='https://wandb.ai/bradhilton/atreides-experiments' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bradhilton/atreides-experiments' target="_blank">https://wandb.ai/bradhilton/atreides-experiments</a>
#  View run at <a href='https://wandb.ai/bradhilton/atreides-experiments/runs/rl33' target="_blank">https://wandb.ai/bradhilton/atreides-experiments/runs/rl33</a>

# %%
await trainer.train(iterations=12, verbosity=1)
# Out:
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# Early stopping val evaluation due to expired patience (0 remaining episodes x 15 patience per episode = 0 seconds)
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl33/config.yaml
# 1|29|Loss: 0.0393: 100%|██████████| 29/29 [09:26<00:00, 19.27s/it, entropy=0.7355, entropy_target=0.0145, kl_div=0.1603, policy=0.0036, tanh_log_policy=-0.0027, unclipped_policy=-0.0102, value=2.2541, weighted_ce=-0.0051, weighted_entropy=0.0047, weighted_kl_div=0.0033]
# Saved iteration 5 model files to /home/ubuntu/atreides/experiments/models/rl33/0005
# Starting 1 vLLM servers...
# $ vllm serve /home/ubuntu/atreides/experiments/models/rl33/0005 --port=8000 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.95 --max-model-len=16384 --max-num-seqs=4096 --max-num-batched-tokens=16384 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=32 --api-key=default
# vLLM servers started succesfully. Logs can be found at ./logs/vllm.log
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl33/config.yaml
# 1|8|Loss: 0.0603:  28%|██▊       | 8/29 [02:42<06:48, 19.43s/it, entropy=0.6109, entropy_target=0.1391, kl_div=0.1505, policy=0.0083, tanh_log_policy=0.0026, unclipped_policy=0.0022, value=1.6979, weighted_ce=-0.0127, weighted_entropy=0.0059, weighted_kl_div=0.0114]

# %%
await trainer.get_completion_sampler()
# Out:
# Starting 1 vLLM servers...
# $ vllm serve NousResearch/Hermes-2-Theta-Llama-3-8B --port=8000 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.9 --max-model-len=16384 --max-num-seqs=2048 --max-num-batched-tokens=16384 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=32 --api-key=default
# INFO 12-14 20:59:28 api_server.py:528] vLLM API server version 0.6.3.post1
# INFO 12-14 20:59:28 api_server.py:529] args: Namespace(subparser='serve', model_tag='NousResearch/Hermes-2-Theta-Llama-3-8B', config='', host=None, port=8000, uvicorn_log_level='info', allow_credentials=False, allowed_origins=['*'], allowed_methods=['*'], allowed_headers=['*'], api_key='default', lora_modules=None, prompt_adapters=None, chat_template=None, response_role='assistant', ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_cert_reqs=0, root_path=None, middleware=[], return_tokens_as_token_ids=True, disable_frontend_multiprocessing=False, enable_auto_tool_choice=False, tool_call_parser=None, tool_parser_plugin='', model='NousResearch/Hermes-2-Theta-Llama-3-8B', tokenizer=None, skip_tokenizer_init=False, revision=None, code_revision=None, tokenizer_revision=None, tokenizer_mode='auto', trust_remote_code=False, download_dir=None, load_format='auto', config_format=<ConfigFormat.AUTO: 'auto'>, dtype='auto', kv_cache_dtype='auto', quantization_param_path=None, max_model_len=16384, guided_decoding_backend='outlines', distributed_executor_backend=None, worker_use_ray=False, pipeline_parallel_size=1, tensor_parallel_size=1, max_parallel_loading_workers=None, ray_workers_use_nsight=False, block_size=32, enable_prefix_caching=True, disable_sliding_window=False, use_v2_block_manager=False, num_lookahead_slots=0, seed=0, swap_space=32.0, cpu_offload_gb=0, gpu_memory_utilization=0.9, num_gpu_blocks_override=None, max_num_batched_tokens=16384, max_num_seqs=2048, max_logprobs=20, disable_log_stats=False, quantization=None, rope_scaling=None, rope_theta=None, enforce_eager=True, max_context_len_to_capture=None, max_seq_len_to_capture=8192, disable_custom_all_reduce=False, tokenizer_pool_size=0, tokenizer_pool_type='ray', tokenizer_pool_extra_config=None, limit_mm_per_prompt=None, mm_processor_kwargs=None, enable_lora=False, max_loras=1, max_lora_rank=16, lora_extra_vocab_size=256, lora_dtype='auto', long_lora_scaling_factors=None, max_cpu_loras=None, fully_sharded_loras=False, enable_prompt_adapter=False, max_prompt_adapters=1, max_prompt_adapter_token=0, device='auto', num_scheduler_steps=1, multi_step_stream_outputs=True, scheduler_delay_factor=0.0, enable_chunked_prefill=None, speculative_model=None, speculative_model_quantization=None, num_speculative_tokens=None, speculative_disable_mqa_scorer=False, speculative_draft_tensor_parallel_size=None, speculative_max_model_len=None, speculative_disable_by_batch_size=None, ngram_prompt_lookup_max=None, ngram_prompt_lookup_min=None, spec_decoding_acceptance_method='rejection_sampler', typical_acceptance_sampler_posterior_threshold=None, typical_acceptance_sampler_posterior_alpha=None, disable_logprobs_during_spec_decoding=None, model_loader_extra_config=None, ignore_patterns=[], preemption_mode='swap', served_model_name=None, qlora_adapter_name_or_path=None, otlp_traces_endpoint=None, collect_detailed_traces=None, disable_async_output_proc=False, override_neuron_config=None, scheduling_policy='fcfs', disable_log_requests=True, max_log_len=None, disable_fastapi_docs=False, dispatch_function=<function serve at 0x7e702cda0fe0>)
# INFO 12-14 20:59:28 api_server.py:166] Multiprocessing frontend to use ipc:///tmp/a177e778-517e-4238-98b1-c5103d346f61 for IPC Path.
# INFO 12-14 20:59:28 api_server.py:179] Started engine process with PID 74567
# WARNING 12-14 20:59:29 config.py:1786] User-specified max_model_len (16384) is greater than the derived max_model_len (max_position_embeddings=8192 or model_max_length=None in model's config.json). This may lead to incorrect model outputs or CUDA errors. Make sure the value is correct and within the model context size.
# WARNING 12-14 20:59:34 config.py:1786] User-specified max_model_len (16384) is greater than the derived max_model_len (max_position_embeddings=8192 or model_max_length=None in model's config.json). This may lead to incorrect model outputs or CUDA errors. Make sure the value is correct and within the model context size.
# WARNING 12-14 20:59:34 arg_utils.py:1019] [DEPRECATED] Block manager v1 has been removed, and setting --use-v2-block-manager to True or False has no effect on vLLM behavior. Please remove --use-v2-block-manager in your engine argument. If your use case is not supported by SelfAttnBlockSpaceManager (i.e. block manager v2), please file an issue with detailed information.
# WARNING 12-14 20:59:34 config.py:395] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# WARNING 12-14 20:59:39 arg_utils.py:1019] [DEPRECATED] Block manager v1 has been removed, and setting --use-v2-block-manager to True or False has no effect on vLLM behavior. Please remove --use-v2-block-manager in your engine argument. If your use case is not supported by SelfAttnBlockSpaceManager (i.e. block manager v2), please file an issue with detailed information.
# WARNING 12-14 20:59:39 config.py:395] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# INFO 12-14 20:59:39 llm_engine.py:237] Initializing an LLM engine (v0.6.3.post1) with config: model='NousResearch/Hermes-2-Theta-Llama-3-8B', speculative_config=None, tokenizer='NousResearch/Hermes-2-Theta-Llama-3-8B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=NousResearch/Hermes-2-Theta-Llama-3-8B, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=True, use_async_output_proc=False, use_cached_outputs=True, mm_processor_kwargs=None)
# INFO 12-14 20:59:40 model_runner.py:1056] Starting to load model NousResearch/Hermes-2-Theta-Llama-3-8B...
# INFO 12-14 20:59:41 weight_utils.py:243] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:00<00:00,  4.05it/s]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:01<00:01,  1.56it/s]
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:02<00:00,  1.25it/s]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.15it/s]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.28it/s]
# INFO 12-14 20:59:44 model_runner.py:1067] Loading model weights took 14.9595 GB
# INFO 12-14 20:59:45 gpu_executor.py:122] # GPU blocks: 11578, # CPU blocks: 8192
# INFO 12-14 20:59:45 gpu_executor.py:126] Maximum concurrency for 16384 tokens per request: 22.61x
# INFO 12-14 21:00:01 api_server.py:232] vLLM to use /tmp/tmpcu4ii5v7 as PROMETHEUS_MULTIPROC_DIR
# WARNING 12-14 21:00:01 serving_embedding.py:199] embedding_mode is False. Embedding API will not work.
# INFO 12-14 21:00:01 launcher.py:19] Available routes are:
# INFO 12-14 21:00:01 launcher.py:27] Route: /openapi.json, Methods: GET, HEAD
# INFO 12-14 21:00:01 launcher.py:27] Route: /docs, Methods: GET, HEAD
# INFO 12-14 21:00:01 launcher.py:27] Route: /docs/oauth2-redirect, Methods: GET, HEAD
# INFO 12-14 21:00:01 launcher.py:27] Route: /redoc, Methods: GET, HEAD
# INFO 12-14 21:00:01 launcher.py:27] Route: /health, Methods: GET
# INFO 12-14 21:00:01 launcher.py:27] Route: /tokenize, Methods: POST
# INFO 12-14 21:00:01 launcher.py:27] Route: /detokenize, Methods: POST
# INFO 12-14 21:00:01 launcher.py:27] Route: /v1/models, Methods: GET
# INFO 12-14 21:00:01 launcher.py:27] Route: /version, Methods: GET
# INFO 12-14 21:00:01 launcher.py:27] Route: /v1/chat/completions, Methods: POST
# INFO 12-14 21:00:01 launcher.py:27] Route: /v1/completions, Methods: POST
# INFO 12-14 21:00:01 launcher.py:27] Route: /v1/embeddings, Methods: POST
# INFO:     Started server process [74481]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on socket ('0.0.0.0', 8000) (Press CTRL+C to quit)
# INFO:     127.0.0.1:33974 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# vLLM server started succesfully. Logs can be found at ./logs/vllm.log

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
trainer._completion_sampler.samplers[0].semaphore.max_concurrent_actions *= 2

# %%
# %%prun
asyncio.run(trainer.explore(verbosity=0))
# Out:
#          276972809 function calls (268721619 primitive calls) in 483.300 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#  15707/60   82.604    0.005    1.332    0.022 {method 'poll' of 'select.epoll' objects}
#    3427/2   76.658    0.022    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#  4582/506   68.241    0.015   82.788    0.164 {method 'recv' of '_socket.socket' objects}
#        77   18.760    0.244   18.760    0.244 {method 'any' of 'torch._C.TensorBase' objects}
#   780/778   16.731    0.021  108.403    0.139 threading.py:323(wait)
#        76   13.972    0.184   25.251    0.332 pack.py:307(get_mask)
#       509   12.864    0.025  100.606    0.198 sock_client.py:242(_read_packet_bytes)
#        76   10.767    0.142   23.711    0.312 explore_result.py:181(_write_mask)
#  12632079   10.289    0.000   16.383    0.000 utils.py:54(get_token)
# 42884758/42132634    8.722    0.000   11.009    0.000 {built-in method builtins.isinstance}
#  27923446    7.774    0.000   11.590    0.000 connection.py:190(is_idle)
#      8216    7.079    0.001   26.356    0.003 connection_pool.py:230(_assign_requests_to_connections)
#       160    6.682    0.042    6.682    0.042 {method 'load_verify_locations' of '_ssl._SSLContext' objects}
#     37717    6.201    0.000    6.201    0.000 {built-in method torch.tensor}
#   8279916    4.594    0.000    8.137    0.000 typing.py:2340(get_origin)
#        76    4.339    0.057    4.339    0.057 {built-in method torch.tril}
#   2014267    4.338    0.000    4.921    0.000 _model_construction.py:268(__instancecheck__)
#  12769169    4.242    0.000   20.593    0.000 completion.py:896(<genexpr>)
#  27915851    3.816    0.000    3.816    0.000 http11.py:295(is_idle)
#  13845550    3.590    0.000    3.590    0.000 {method 'startswith' of 'str' objects}
# 1162647/3321    3.555    0.000   45.801    0.014 _transform.py:288(_async_transform_recursive)
# 3016369/639197    3.540    0.000   16.639    0.000 typing.py:407(_eval_type)
#  13309650    3.080    0.000    3.080    0.000 {method 'decode' of 'bytes' objects}
#        76    2.948    0.039    2.948    0.039 {built-in method torch.ones_like}
#     39004    2.872    0.000    7.273    0.000 {method 'validate_python' of 'pydantic_core._pydantic_core.SchemaValidator' objects}
#    124162    2.822    0.000   21.677    0.000 typing.py:2215(get_type_hints)
# 277315/276876    2.728    0.000   23.508    0.000 {method 'join' of 'str' objects}
#      3481    2.504    0.001    2.530    0.001 decoder.py:344(raw_decode)
# 15708/15648    2.364    0.000   81.985    0.005 selectors.py:451(select)
#    639194    2.278    0.000    5.123    0.000 typing.py:175(_type_check)
#     98349    2.150    0.000    4.101    0.000 completion.py:788(_split_weights)
#    639194    1.786    0.000   16.086    0.000 typing.py:916(_evaluate)
# 337815/332268    1.643    0.000    5.999    0.000 {built-in method builtins.sum}
#   1194385    1.452    0.000    1.452    0.000 completion.py:815(<lambda>)
# 2732285/1391055    1.350    0.000    3.961    0.000 typing.py:430(<genexpr>)
#   5182407    1.322    0.000    1.322    0.000 {method 'get' of 'dict' objects}
#   2043858    1.232    0.000    7.776    0.000 completion.py:604(token_count)
# 1390788/1162647    1.179    0.000    5.314    0.000 _typing.py:40(strip_annotated_type)
#       760    1.108    0.001    1.108    0.001 {built-in method torch._C._nn.pad}
#   2266568    1.103    0.000    2.366    0.000 {built-in method builtins.getattr}
#   1193719    1.086    0.000    1.822    0.000 typing.py:2370(get_args)
#   2549857    1.051    0.000    3.555    0.000 _typing.py:29(is_required_type)
#    200011    1.028    0.000    3.205    0.000 _sockets.py:58(extra_attributes)
#   2433108    0.984    0.000    3.317    0.000 _typing.py:11(is_annotated_type)
#   1159069    0.958    0.000    4.558    0.000 _transform.py:111(_get_annotated_type)
#      6941    0.955    0.000    0.955    0.000 {method 'encode_batch' of 'tokenizers.Tokenizer' objects}
#   2048025    0.943    0.000    5.687    0.000 completion.py:536(tokens_and_mask)
#   1162647    0.914    0.000    1.820    0.000 typing.py:448(is_typeddict)
#   5145217    0.895    0.000    0.896    0.000 completion.py:655(<genexpr>)
# 59712/59711    0.871    0.000  167.187    0.003 {method 'send' of 'coroutine' objects}
#   2043858    0.859    0.000    0.859    0.000 {method 'size' of 'torch._C.TensorBase' objects}
# 124162/6642    0.840    0.000   45.568    0.007 _transform.py:379(_async_transform_typeddict)
#      4167    0.834    0.000    2.633    0.001 explore_result.py:225(_get_completion_tensors)
#   1015167    0.820    0.000    1.269    0.000 utils.py:60(get_token_id)
#   2771247    0.793    0.000    1.032    0.000 {built-in method builtins.hasattr}
#    173868    0.752    0.000    2.095    0.000 main.py:858(__setattr__)
#   2043808    0.732    0.000    2.995    0.000 explore_result.py:122(<genexpr>)
#   2540831    0.728    0.000    1.200    0.000 typing.py:1279(__eq__)
#    973598    0.720    0.000    2.012    0.000 typing.py:392(inner)
#   1031843    0.695    0.000    1.928    0.000 _typing.py:25(is_union_type)
#        64    0.614    0.010   18.206    0.284 explore_result.py:87(_pack_episode)
#    639194    0.602    0.000    3.311    0.000 {built-in method builtins.eval}
#       153    0.595    0.004    0.595    0.004 {built-in method torch.stack}
# 108071/3321    0.588    0.000   21.222    0.006 _models.py:448(construct_type)
#   1948018    0.588    0.000    1.026    0.000 typing.py:1592(__eq__)
#    152196    0.576    0.000   28.039    0.000 completion.py:888(message_param)
#    157472    0.565    0.000    1.398    0.000 main.py:782(__copy__)
#   1162647    0.564    0.000    0.860    0.000 utils.py:181(lenient_issubclass)
#    111200    0.532    0.000    0.937    0.000 completion.py:936(joined_assistant_message_params)
#   1038485    0.528    0.000    1.512    0.000 _typing.py:19(is_iterable_type)
#    114895    0.525    0.000    0.525    0.000 {method 'search' of 're.Pattern' objects}
#    944887    0.518    0.000    5.755    0.000 http11.py:281(has_expired)
#    420881    0.486    0.000    0.636    0.000 _model_construction.py:257(__getattr__)
#   1038485    0.467    0.000    1.490    0.000 _typing.py:15(is_list_type)
#    157375    0.438    0.000    0.750    0.000 typing.py:1636(__hash__)
# 194576/21887    0.437    0.000   29.851    0.001 completion.py:421(all_message_params)
#    198332    0.433    0.000    1.018    0.000 _utils.py:7(is_socket_readable)
#    472416    0.424    0.000    0.713    0.000 copy.py:61(copy)
#   1787113    0.422    0.000    0.662    0.000 completion.py:848(__hash__)
#   2978751    0.419    0.000    0.419    0.000 {built-in method builtins.id}
#   1070430    0.415    0.000    0.855    0.000 {built-in method builtins.issubclass}
#    201690    0.407    0.000    0.407    0.000 {method 'getpeername' of '_socket.socket' objects}
# 15709/15708    0.404    0.000  389.752    0.025 nest_asyncio.py:100(_run_once)
# 24527/3321    0.401    0.000   20.931    0.006 _models.py:203(construct)
#    948307    0.382    0.000    6.139    0.000 connection.py:185(has_expired)
#     19296    0.381    0.000   65.824    0.003 1519314614.py:44(reward_completion)
#    948324    0.377    0.000    0.552    0.000 connection.py:195(is_closed)
#    152196    0.362    0.000    0.784    0.000 main.py:826(__getattr__)
#    375993    0.353    0.000    1.014    0.000 typing.py:1492(__subclasscheck__)
#   1535529    0.346    0.000    0.346    0.000 {method 'append' of 'list' objects}
#    375993    0.343    0.000    1.357    0.000 typing.py:1221(__instancecheck__)
#         9    0.341    0.038    0.341    0.038 {built-in method posix.unlink}
# 280189/256685    0.340    0.000    0.580    0.000 typing.py:1600(__hash__)
#     14642    0.329    0.000    0.329    0.000 {built-in method torch.cat}
#     90753    0.310    0.000    0.625    0.000 _models.py:212(__getitem__)
#    793380    0.303    0.000    0.303    0.000 {method 'get' of 'mappingproxy' objects}
#   1148586    0.301    0.000    0.301    0.000 typing.py:213(_should_unflatten_callable_args)
#    200011    0.288    0.000    3.790    0.000 _typedattr.py:58(extra)
#    598354    0.283    0.000    0.708    0.000 _asyncio.py:1186(_raw_socket)
#    200011    0.280    0.000    5.086    0.000 anyio.py:84(get_extra_info)
#   1139914    0.277    0.000    0.277    0.000 typing.py:251(is_union)
#    194576    0.273    0.000   28.431    0.000 completion.py:409(message_params)
#      4384    0.271    0.000    5.425    0.001 explore_result.py:214(<lambda>)
#    598354    0.267    0.000    0.425    0.000 transports.py:19(get_extra_info)
#    639194    0.256    0.000    0.399    0.000 typing.py:166(_type_convert)
#    198332    0.245    0.000    0.245    0.000 {method 'poll' of 'select.poll' objects}
#   1205214    0.244    0.000    0.244    0.000 {method 'extend' of 'list' objects}
#      6980    0.234    0.000    0.554    0.000 _headers.py:150(normalize_and_validate)
#    266684    0.231    0.000    0.231    0.000 {built-in method __new__ of type object at 0x7510a42eb4c0}
#   1010014    0.231    0.000    0.232    0.000 completion.py:458(logprobs)
#   1011069    0.229    0.000    0.229    0.000 {built-in method time.monotonic}
#    224819    0.229    0.000    1.103    0.000 {built-in method builtins.next}
#    514742    0.225    0.000    0.289    0.000 _models.py:173(__eq__)
# 63071/63070    0.224    0.000  168.308    0.003 tasks.py:308(__step_run_and_handle_result)
#    170547    0.224    0.000    0.368    0.000 main.py:927(_check_frozen)
#     41246    0.219    0.000    0.565    0.000 _asyncio.py:391(__enter__)
#     36211    0.218    0.000  117.890    0.003 completion_sampler.py:141(sample_completions)
# 843662/209168    0.218    0.000    0.218    0.000 completion.py:201(ancestors)
#    643365    0.216    0.000    0.216    0.000 {method 'items' of 'dict' objects}
# 482917/482753    0.214    0.000    0.214    0.000 {built-in method _abc._abc_subclasscheck}
#    512016    0.210    0.000    0.248    0.000 {method 'add' of 'set' objects}
#       509    0.210    0.000  369.213    0.725 router_sock.py:25(_read_message)
#   1032711    0.209    0.000    0.209    0.000 {method 'removeprefix' of 'str' objects}
# 823242/812925    0.208    0.000    0.214    0.000 {built-in method builtins.len}
#      3321    0.207    0.000   24.443    0.007 _response.py:388(parse)
#    375129    0.202    0.000    0.336    0.000 _models.py:94(encoding)
# 482917/482753    0.191    0.000    0.405    0.000 <frozen abc>:121(__subclasscheck__)
# 6951/6945    0.190    0.000    0.191    0.000 {method 'send' of '_socket.socket' objects}
#    773052    0.190    0.000    0.190    0.000 typing.py:1626(<genexpr>)
# 63071/63070    0.185    0.000  171.084    0.003 tasks.py:291(__step)
# 645955/562131    0.184    0.000    0.268    0.000 {built-in method builtins.hash}
#    427658    0.184    0.000    1.874    0.000 _transform.py:126(_maybe_transform_key)
#    181012    0.184    0.000    0.666    0.000 typing.py:113(get_origin)
#    510025    0.181    0.000    0.465    0.000 connection.py:165(can_handle_request)
#    122391    0.181    0.000    0.342    0.000 __init__.py:280(_compile)
#     41246    0.180    0.000    0.397    0.000 _asyncio.py:422(__exit__)
# 441703/58043    0.178    0.000    0.197    0.000 completion.py:214(descendants)
#     23844    0.176    0.000    0.308    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#    208406    0.176    0.000    0.409    0.000 socket.py:100(_intenum_converter)
#    944904    0.175    0.000    0.175    0.000 http11.py:298(is_closed)
#    205048    0.171    0.000    0.574    0.000 socket.py:517(family)
#    103919    0.171    0.000    0.210    0.000 contextlib.py:104(__init__)
#     93924    0.170    0.000    0.331    0.000 base_events.py:813(_call_soon)
# 246861/212813    0.170    0.000    0.187    0.000 completion.py:115(value)
#    130804    0.168    0.000    0.285    0.000 typing.py:521(__getitem__)
#    124162    0.168    0.000   21.887    0.000 typing_extensions.py:1197(get_type_hints)
#    150328    0.165    0.000    0.165    0.000 {method 'fullmatch' of 're.Pattern' objects}
#     21296    0.164    0.000    0.508    0.000 _models.py:64(__init__)
#      7158    0.162    0.000    0.842    0.000 _urlparse.py:152(urlparse)
#     85994    0.157    0.000    0.218    0.000 _impl.py:25(current_async_library)
#    208838    0.157    0.000    0.235    0.000 enum.py:720(__call__)
#     30556    0.152    0.000    0.152    0.000 {built-in method torch.full_like}
#    505308    0.151    0.000    0.225    0.000 connection.py:173(is_available)
#    116826    0.151    0.000    0.190    0.000 events.py:36(__init__)
#      3339    0.149    0.000    0.149    0.000 encoder.py:205(iterencode)
#     22233    0.148    0.000    0.570    0.000 _connection.py:260(_process_event)
#    508257    0.147    0.000    0.174    0.000 enum.py:202(__get__)
#        76    0.143    0.002    0.274    0.004 __init__.py:823(__add__)
#     53121    0.143    0.000    0.144    0.000 _asyncio.py:376(__init__)
#     19788    0.143    0.000    3.945    0.000 http11.py:72(handle_async_request)
#    200011    0.142    0.000    0.227    0.000 _sockets.py:636(convert_ipv6_sockaddr)
# 35132/35131    0.137    0.000    9.069    0.000 type_adapter.py:132(wrapped)
#    211034    0.135    0.000    0.223    0.000 _utils.py:31(normalize_header_key)
#    157472    0.133    0.000    1.534    0.000 main.py:324(model_copy)
#    208352    0.133    0.000    0.316    0.000 typing.py:1285(__hash__)
#     45093    0.132    0.000    0.289    0.000 typing.py:146(_generic_get_args)
#     93922    0.131    0.000    0.487    0.000 base_events.py:784(call_soon)
#    108071    0.130    0.000    0.733    0.000 typing.py:166(get_args)
# 100920/100859    0.130    0.000  265.586    0.003 {method 'run' of '_contextvars.Context' objects}
#    186254    0.129    0.000    7.404    0.000 episode.py:345(<genexpr>)
#    200274    0.126    0.000    0.209    0.000 <frozen importlib._bootstrap>:645(parent)
# 100920/100859    0.125    0.000  298.296    0.003 events.py:86(_run)
#   556/466    0.121    0.000  247.605    0.531 mailbox.py:125(_wait)
#    103919    0.121    0.000    0.331    0.000 contextlib.py:299(helper)
#    370845    0.121    0.000    0.121    0.000 {method 'lower' of 'str' objects}
#    103919    0.119    0.000    0.493    0.000 contextlib.py:141(__exit__)
#    761640    0.115    0.000    0.115    0.000 connection_pool.py:39(is_queued)
#   1010014    0.112    0.000    0.112    0.000 completion.py:527(<genexpr>)
#      3362    0.111    0.000    7.525    0.002 {built-in method builtins.sorted}
#    312620    0.111    0.000    0.111    0.000 {method 'copy' of 'dict' objects}
#     40002    0.110    0.000    1.131    0.000 episode.py:334(<lambda>)
#    139671    0.109    0.000    0.301    0.000 _util.py:84(validate)
#    103919    0.108    0.000    0.823    0.000 contextlib.py:132(__enter__)
#    372486    0.108    0.000    0.108    0.000 {built-in method builtins.vars}
#    538818    0.107    0.000    0.108    0.000 typing.py:2183(cast)
#     73581    0.106    0.000    0.107    0.000 inspect.py:1832(_shadowed_dict)
#    303658    0.105    0.000    0.105    0.000 {method 'encode' of 'str' objects}
#     24527    0.105    0.000    0.365    0.000 inspect.py:1845(getattr_static)
#    200011    0.104    0.000    0.507    0.000 trsock.py:76(getpeername)
#    112959    0.101    0.000    0.116    0.000 completion.py:829(<genexpr>)
#    107915    0.101    0.000    0.886    0.000 __init__.py:174(search)
#    200011    0.100    0.000    0.653    0.000 trsock.py:18(family)
#      1679    0.097    0.000    0.097    0.000 {method 'connect' of '_socket.socket' objects}
#     28888    0.096    0.000  108.969    0.004 completions.py:1620(create)
#    173868    0.095    0.000    0.163    0.000 _fields.py:328(is_valid_field_name)
#     16841    0.095    0.000    2.245    0.000 http11.py:216(_receive_event)
# 29080/28888    0.094    0.000   62.359    0.002 _base_client.py:1541(_request)
#    198332    0.094    0.000    0.150    0.000 trsock.py:56(fileno)
#      6941    0.093    0.000    0.298    0.000 runtime.py:93(new_context)
#     24171    0.092    0.000   16.177    0.001 connection_pool.py:159(handle_async_request)
#      6941    0.091    0.000    2.599    0.000 llm.py:463(chat)
#     45823    0.091    0.000    0.091    0.000 {method 'match' of 're.Pattern' objects}
#     18481    0.091    0.000    0.264    0.000 tasks.py:111(__init__)
# 19926/9963    0.090    0.000    0.232    0.000 copy.py:118(deepcopy)
#      7140    0.090    0.000    0.198    0.000 _models.py:130(keys)
#     24527    0.090    0.000    0.494    0.000 typing_extensions.py:626(__instancecheck__)
#    178140    0.089    0.000    0.147    0.000 _models.py:27(enforce_bytes)
#    104451    0.088    0.000    0.270    0.000 completion.py:148(advantage)
#      6941    0.086    0.000    0.626    0.000 tokenization_utils_base.py:1709(apply_chat_template)
#     24171    0.086    0.000   16.615    0.001 default.py:358(handle_async_request)
# 298551/29501    0.086    0.000    0.095    0.000 completion.py:228(depths)
#    203760    0.086    0.000    0.086    0.000 {method 'rpartition' of 'str' objects}
#    157375    0.085    0.000    0.085    0.000 typing.py:1625(_value_and_type_iter)
#      6941    0.085    0.000    1.389    0.000 tokenization_utils_fast.py:579(_encode_plus)
# 94147/19926    0.084    0.000   20.705    0.001 _models.py:382(_construct_field)
# 57682/43970    0.084    0.000    0.177    0.000 completion.py:630(sample_weight)
#     27202    0.084    0.000    0.801    0.000 _tasks.py:95(fail_after)
#     24527    0.082    0.000    0.092    0.000 inspect.py:1797(_check_instance)
#     57595    0.082    0.000    5.790    0.000 completion.py:647(max_splits)
#     36150    0.082    0.000    0.255    0.000 futures.py:161(__schedule_callbacks)
#    198332    0.081    0.000    0.081    0.000 {method 'register' of 'select.poll' objects}
#     38451    0.081    0.000    0.186    0.000 _compat.py:92(field_get_default)
#     13934    0.080    0.000   17.554    0.001 _models.py:916(aiter_bytes)
#      6941    0.080    0.000    1.217    0.000 tokenization_utils_fast.py:488(_batch_encode_plus)
#    225090    0.080    0.000    0.995    0.000 _utils.py:152(is_mapping)
#     24171    0.080    0.000   17.806    0.001 _client.py:1762(_send_single_request)
#    198332    0.079    0.000    0.297    0.000 _sockets.py:67(<lambda>)
#      3321    0.078    0.000    0.374    0.000 main.py:243(model_construct)
#    179360    0.078    0.000    0.078    0.000 {method 'pop' of 'dict' objects}
#    208838    0.078    0.000    0.078    0.000 enum.py:1123(__new__)
# 9862/3441    0.077    0.000    0.370    0.000 completion.py:675(split)
# 87549/9283    0.077    0.000    0.156    0.000 completion.py:94(commit)
#     10170    0.077    0.000    0.444    0.000 _asyncio.py:1190(receive)
#     10461    0.076    0.000    0.329    0.000 _models.py:61(enforce_headers)
#    139181    0.076    0.000    0.119    0.000 _urlparse.py:212(<genexpr>)
#    227959    0.075    0.000    0.075    0.000 {method 'lower' of 'bytes' objects}
#    502319    0.074    0.000    0.074    0.000 http11.py:274(is_available)
#     35130    0.073    0.000   13.655    0.000 _models.py:728(_validate_non_model_type)
#     27155    0.073    0.000    0.226    0.000 _asyncio.py:2294(create_cancel_scope)
# 87549/9283    0.070    0.000    0.254    0.000 completion.py:244(all_absent_stop_tokens)
#     16823    0.069    0.000    1.002    0.000 _connection.py:426(next_event)
#      5557    0.069    0.000    0.069    0.000 {method 'nonzero' of 'torch._C.TensorBase' objects}
#   556/466    0.069    0.000  582.296    1.250 mailbox.py:128(_get_and_clear)
#      4514    0.068    0.000    0.392    0.000 tasks.py:731(gather)
#     33129    0.068    0.000    0.291    0.000 {built-in method builtins.any}
#     13882    0.068    0.000    0.074    0.000 __init__.py:1023(__iter__)
# 105346/105213    0.067    0.000    0.162    0.000 {built-in method builtins.max}
#    185148    0.066    0.000    0.090    0.000 events.py:127(__lt__)
#     21466    0.065    0.000    0.275    0.000 _asyncio.py:2285(cancel_shielded_checkpoint)
#    213548    0.065    0.000    0.065    0.000 {built-in method _asyncio.current_task}
#     20809    0.065    0.000    0.101    0.000 _trace.py:10(__init__)
#     58043    0.064    0.000    6.077    0.000 episode.py:358(<genexpr>)
#     87549    0.063    0.000    0.184    0.000 completion.py:237(absent_stop_tokens)
#     81473    0.063    0.000    0.064    0.000 {built-in method _abc._abc_instancecheck}
#     22233    0.063    0.000    0.089    0.000 _state.py:318(_fire_state_triggered_transitions)
#     49852    0.063    0.000    0.091    0.000 _weakrefset.py:85(add)
#     13285    0.063    0.000    0.127    0.000 tasks.py:767(_done_callback)
#     47226    0.063    0.000    0.112    0.000 _models.py:274(__contains__)
#       509    0.062    0.000  105.087    0.206 sock_client.py:286(read_server_response)
#    157472    0.062    0.000    0.062    0.000 {method 'copy' of 'set' objects}
#     35130    0.061    0.000    7.318    0.000 type_adapter.py:341(validate_python)
#      3481    0.061    0.000    0.714    0.000 _models.py:1183(__init__)
#     24527    0.061    0.000    0.116    0.000 inspect.py:1806(_check_class)
#     35130    0.061    0.000   14.017    0.000 _models.py:677(validate_type)
#     25714    0.060    0.000    0.210    0.000 _connection.py:330(_respond_to_state_changes)
#     13934    0.060    0.000   17.353    0.001 _models.py:971(aiter_raw)
#    235723    0.060    0.000    0.060    0.000 completion.py:211(matches_model)
#      5067    0.059    0.000    0.059    0.000 _receivebuffer.py:53(__iadd__)
#    153987    0.059    0.000    0.059    0.000 {method 'groupdict' of 're.Match' objects}
#     53658    0.059    0.000    0.059    0.000 weakref.py:414(__getitem__)
#    203369    0.058    0.000    0.058    0.000 {method 'fileno' of '_socket.socket' objects}
#      6980    0.057    0.000    0.105    0.000 _receivebuffer.py:104(maybe_extract_lines)
#     88207    0.057    0.000    0.158    0.000 completion.py:838(<genexpr>)
#    156146    0.057    0.000    0.057    0.000 futures.py:181(done)
#      6941    0.056    0.000    2.902    0.000 tokenizer.py:38(encode)
#      6836    0.055    0.000    0.640    0.000 http11.py:159(_send_request_body)
#     27778    0.055    0.000    0.139    0.000 _connection.py:308(_get_io_object)
#     72941    0.055    0.000    0.320    0.000 typing.py:417(is_literal_type)
#     13996    0.055    0.000    0.951    0.000 _urls.py:77(__init__)
#     49777    0.053    0.000    0.078    0.000 _weakrefset.py:39(_remove)
#      6941    0.053    0.000    0.058    0.000 tokenization_utils_fast.py:282(_convert_encoding)
#     41246    0.053    0.000    0.081    0.000 weakref.py:451(get)
#     32792    0.053    0.000    0.285    0.000 futures.py:251(set_result)
#      3339    0.053    0.000    2.526    0.001 _base_client.py:446(_build_request)
#     25866    0.052    0.000    0.378    0.000 _asyncio.py:1733(acquire)
#      3506    0.052    0.000    0.052    0.000 {method 'flush' of '_io.TextIOWrapper' objects}
#     26184    0.052    0.000    4.725    0.000 connection.py:67(handle_async_request)
#      6980    0.052    0.000    0.447    0.000 _readers.py:94(maybe_read_from_SEND_RESPONSE_server)
#     11922    0.052    0.000    0.066    0.000 threading.py:1535(enumerate)
#    105517    0.051    0.000    0.078    0.000 _utils.py:47(normalize_header_value)
#      6941    0.051    0.000    1.472    0.000 tokenization_utils_base.py:3154(encode_plus)
#    171676    0.051    0.000    0.051    0.000 {method 'strip' of 'str' objects}
#      3499    0.051    0.000    0.579    0.000 _events.py:82(__init__)
#     24171    0.051    0.000   17.934    0.001 _client.py:1690(_send_handling_auth)
#     28888    0.051    0.000   63.008    0.002 _base_client.py:1825(post)
#      6941    0.051    0.000    1.559    0.000 tokenizer.py:54(patch)
#      9843    0.050    0.000    0.982    0.000 http11.py:337(__aiter__)
#     17332    0.050    0.000    0.776    0.000 anyio.py:39(write)
#    190227    0.050    0.000    0.051    0.000 base_events.py:2010(get_debug)
#     13882    0.050    0.000    0.155    0.000 tokenization_utils_base.py:220(__init__)
#      7572    0.050    0.000   15.978    0.002 connection_pool.py:369(aclose)
#      1654    0.050    0.000    0.050    0.000 {method 'shutdown' of '_socket.socket' objects}
#    198332    0.050    0.000    0.050    0.000 {built-in method select.poll}
#     24974    0.049    0.000    0.150    0.000 locks.py:199(wait)
#     55565    0.049    0.000    0.167    0.000 _eventloop.py:154(get_async_backend)
#     14476    0.049    0.000    0.189    0.000 _urlparse.py:452(quote)
#     27938    0.049    0.000    0.065    0.000 _headers.py:205(get_comma_header)
#     22233    0.049    0.000    0.161    0.000 _state.py:275(process_event)
#     18179    0.048    0.000    0.103    0.000 selectors.py:69(__getitem__)
#     41248    0.048    0.000    0.234    0.000 _asyncio.py:528(_timeout)
# 114978/9347    0.048    0.000    0.051    0.000 completion.py:222(leaves)
#     89920    0.047    0.000    0.071    0.000 completion.py:238(<genexpr>)
#      9283    0.047    0.000   13.140    0.001 episode.py:43(last_assistant_message)
#     15335    0.047    0.000   38.168    0.002 completion_sampler.py:415(sample_completions)
#     69681    0.047    0.000    0.073    0.000 _urlparse.py:162(<genexpr>)
#      3321    0.047    0.000   24.574    0.007 _base_client.py:1674(_process_response)
#     15475    0.046    0.000    0.176    0.000 base_events.py:766(call_at)
#     40216    0.046    0.000    0.075    0.000 futures.py:220(add_done_callback)
#     44169    0.046    0.000    0.267    0.000 completion.py:837(num_token_logprobs)
#     29848    0.045    0.000   35.651    0.001 _client.py:1639(send)
#     10170    0.045    0.000    0.940    0.000 anyio.py:23(read)
#     11875    0.045    0.000    0.248    0.000 _synchronization.py:197(__init__)
#     47390    0.045    0.000    0.068    0.000 tasks.py:653(sleep)
#     81473    0.045    0.000    0.109    0.000 <frozen abc>:117(__instancecheck__)
#      3499    0.045    0.000    1.209    0.000 _client.py:320(build_request)
#      3321    0.045    0.000   24.107    0.007 _response.py:128(_parse)
#     18481    0.045    0.000    0.313    0.000 base_events.py:450(create_task)
#    178830    0.045    0.000    0.045    0.000 threading.py:1198(ident)
#     40450    0.045    0.000    7.261    0.000 episode.py:352(<genexpr>)
#     14151    0.044    0.000    0.054    0.000 _models.py:287(origin)
#     55528    0.044    0.000    0.044    0.000 __init__.py:1009(__getitem__)
#     27848    0.044    0.000    0.065    0.000 message.py:421(__setitem__)
#      6941    0.044    0.000    0.113    0.000 chat_utils.py:390(_parse_chat_message_content_parts)
#     20823    0.044    0.000    0.056    0.000 <template>:4(root)
#      9843    0.044    0.000    0.896    0.000 http11.py:205(_receive_response_body)
#     38458    0.044    0.000    0.064    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#      5037    0.044    0.000    0.440    0.000 _sockets.py:114(connect_tcp)
#    108145    0.043    0.000    0.043    0.000 {method 'popleft' of 'collections.deque' objects}
#     13674    0.042    0.000    0.289    0.000 _asyncio.py:1225(send)
# 45368/7424    0.042    0.000    4.145    0.001 completion.py:607(all_token_count)
#     23247    0.042    0.000    0.140    0.000 _utils.py:298(strip_not_given)
# 22373/3321    0.042    0.000    0.075    0.000 completion.py:471(estimated_completion_tokens)
#    119177    0.041    0.000    0.041    0.000 {method 'append' of 'collections.deque' objects}
#   782/779    0.041    0.000  115.023    0.148 threading.py:637(wait)
#    113942    0.041    0.000    0.509    0.000 _utils.py:168(is_iterable)
#      1679    0.041    0.000    0.041    0.000 socket.py:221(__init__)
#     12479    0.040    0.000   17.631    0.001 _models.py:908(aread)
#    212401    0.039    0.000    0.039    0.000 {method 'isascii' of 'str' objects}
#     16823    0.039    0.000    0.600    0.000 _connection.py:398(_extract_next_receive_event)
#      3481    0.039    0.000    0.255    0.000 request.py:315(__init__)
#     10495    0.039    0.000    0.383    0.000 _connection.py:518(send_with_data_passthrough)
#     95507    0.038    0.000    0.054    0.000 completion.py:641(<genexpr>)
# 8399/5041    0.038    0.000    0.106    0.000 _asyncio.py:536(_deliver_cancellation)
#     21025    0.038    0.000   76.836    0.004 tasks.py:383(__wakeup)
#     18179    0.038    0.000    0.164    0.000 selectors.py:180(get_key)
#     51738    0.038    0.000    0.272    0.000 _utils.py:303(smart_deepcopy)
#      3321    0.038    0.000    0.060    0.000 _utils.py:241(wrapper)
#     10030    0.038    0.000    0.564    0.000 connection_pool.py:301(_close_connections)
#     10017    0.038    0.000    0.052    0.000 _base_client.py:2063(_merge_mappings)
#     21504    0.038    0.000    0.039    0.000 {method 'format' of 'str' objects}
#     70266    0.038    0.000    0.038    0.000 type_adapter.py:259(_with_frame_depth)
#     60916    0.037    0.000    0.058    0.000 base_events.py:733(time)
#      4167    0.037    0.000    0.037    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#      6962    0.037    0.000    0.096    0.000 _models.py:159(multi_items)
#     63070    0.037    0.000    0.037    0.000 {built-in method _asyncio._enter_task}
#     51738    0.037    0.000    0.309    0.000 fields.py:552(get_default)
#      1687    0.037    0.000    0.061    0.000 random.py:889(getrandbits)
#     35338    0.037    0.000    0.057    0.000 futures.py:286(__await__)
#      6678    0.037    0.000    0.047    0.000 _models.py:232(__setitem__)
#      9963    0.037    0.000    0.094    0.000 copy.py:247(_reconstruct)
#     36151    0.036    0.000    0.046    0.000 futures.py:72(__init__)
#      6941    0.036    0.000    0.155    0.000 chat_utils.py:450(_parse_chat_message_content)
#     13882    0.036    0.000    0.081    0.000 <frozen _collections_abc>:974(update)
#      3321    0.036    0.000    0.551    0.000 _models.py:810(construct)
#     21352    0.036    0.000    0.050    0.000 ipaddress.py:1213(_parse_octet)
#     15413    0.035    0.000    0.100    0.000 {built-in method _heapq.heappop}
#      3499    0.035    0.000    0.735    0.000 _models.py:311(__init__)
#      3499    0.035    0.000    0.318    0.000 _models.py:375(_prepare)
#     53936    0.035    0.000    0.064    0.000 request.py:397(add_header)
#     63070    0.035    0.000    0.035    0.000 {built-in method _asyncio._leave_task}
#    191047    0.035    0.000    0.035    0.000 {method 'isprintable' of 'str' objects}
#      6003    0.035    0.000    0.667    0.000 episode.py:417(_sample_completions)
#      6962    0.035    0.000    0.200    0.000 _models.py:1204(info)
#     23461    0.035    0.000    0.344    0.000 _models.py:170(get)
#     13351    0.035    0.000    0.260    0.000 tasks.py:670(ensure_future)
#     45456    0.034    0.000    0.040    0.000 futures.py:189(result)
#     57205    0.034    0.000    0.034    0.000 completion.py:828(_token_logprob_sequences)
#     82909    0.034    0.000    0.034    0.000 {method 'group' of 're.Match' objects}
#      7427    0.034    0.000    0.113    0.000 selectors.py:351(register)
#     28888    0.034    0.000   62.394    0.002 _base_client.py:1519(request)
#     15475    0.034    0.000    0.064    0.000 events.py:155(cancel)
#    135308    0.034    0.000    0.034    0.000 base_events.py:538(_check_closed)
#      3339    0.034    0.000    0.382    0.000 _base_client.py:411(_build_headers)
#     17635    0.033    0.000    0.035    0.000 {method 'join' of 'bytes' objects}
#      3659    0.033    0.000    0.304    0.000 _models.py:202(update)
#      6998    0.033    0.000    1.339    0.000 http11.py:147(_send_request_headers)
#     20110    0.033    0.000    0.089    0.000 _synchronization.py:21(current_async_library)
#     86006    0.033    0.000    0.033    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#     27494    0.033    0.000    0.033    0.000 _models.py:123(raw)
#      7419    0.032    0.000    0.163    0.000 selector_events.py:294(_remove_reader)
#      6941    0.032    0.000    0.072    0.000 runtime.py:165(__init__)
#      7427    0.032    0.000    0.032    0.000 {method 'unregister' of 'select.epoll' objects}
#     41246    0.032    0.000    0.055    0.000 _asyncio.py:371(__new__)
#     22902    0.032    0.000    0.037    0.000 events.py:72(cancel)
#     40002    0.031    0.000    0.467    0.000 completion.py:666(split_weight)
#    118945    0.031    0.000    0.031    0.000 _util.py:127(bytesify)
#      7572    0.031    0.000   16.070    0.002 _client.py:153(aclose)
#      6998    0.031    0.000    0.256    0.000 http11.py:245(_response_closed)
#      3499    0.030    0.000    0.039    0.000 _writers.py:22(write_headers)
#     62483    0.030    0.000    0.030    0.000 {built-in method builtins.min}
#      6941    0.030    0.000    0.214    0.000 chat_utils.py:502(parse_chat_messages)
#     57723    0.030    0.000    0.046    0.000 <frozen _collections_abc>:1022(__iter__)
#     25604    0.029    0.000    0.041    0.000 futures.py:301(_get_loop)
#      3481    0.029    0.000    0.139    0.000 _events.py:137(__init__)
#     25866    0.029    0.000    0.456    0.000 _synchronization.py:69(__aenter__)
#     15475    0.029    0.000    0.076    0.000 events.py:111(__init__)
#     61934    0.029    0.000    0.029    0.000 {method 'remove' of 'set' objects}
#     53936    0.029    0.000    0.029    0.000 {method 'capitalize' of 'str' objects}
#      6836    0.029    0.000    0.212    0.000 selector_events.py:1055(write)
#     15470    0.028    0.000    0.048    0.000 base_events.py:446(create_future)
#      9843    0.028    0.000    0.095    0.000 _readers.py:127(__call__)
#     18808    0.028    0.000    0.094    0.000 locks.py:181(set)
#     17405    0.028    0.000    0.117    0.000 _readers.py:64(_decode_header_lines)
#     75109    0.027    0.000    0.027    0.000 {built-in method _contextvars.copy_context}
#      6678    0.027    0.000    0.038    0.000 _models.py:256(__delitem__)
#      3481    0.027    0.000    0.044    0.000 parse.py:374(urlparse)
#      5748    0.027    0.000    0.193    0.000 selector_events.py:278(_add_reader)
#      6941    0.027    0.000    0.653    0.000 chat_utils.py:538(apply_hf_chat_template)
#      6979    0.027    0.000    0.029    0.000 _events.py:337(__init__)
#     17332    0.027    0.000    1.211    0.000 http11.py:170(_send_event)
#      7427    0.027    0.000    0.027    0.000 {method 'register' of 'select.epoll' objects}
#     19472    0.027    0.000    0.027    0.000 locks.py:166(__init__)
#      6941    0.026    0.000    0.404    0.000 environment.py:1272(render)
#      9843    0.026    0.000    1.077    0.000 default.py:255(__aiter__)
#    107915    0.026    0.000    0.026    0.000 enum.py:1286(value)
#      3486    0.026    0.000    0.070    0.000 tasks.py:522(_wait)
#     55082    0.026    0.000    0.040    0.000 inspect.py:302(isclass)
#     30109    0.026    0.000    0.026    0.000 {method 'split' of 'str' objects}
#     13987    0.025    0.000    0.026    0.000 completion.py:65(__init__)
#     14476    0.025    0.000    0.110    0.000 __init__.py:219(finditer)
#     24171    0.025    0.000   17.840    0.001 _client.py:1724(_send_handling_redirects)
#      7427    0.025    0.000    0.051    0.000 selectors.py:234(register)
#     67116    0.025    0.000    0.025    0.000 {method 'keys' of 'dict' objects}
#     11333    0.025    0.000   38.023    0.003 episode.py:66(follow_up)
#      6980    0.025    0.000    0.061    0.000 _connection.py:81(_body_framing)
#      9128    0.025    0.000    0.032    0.000 mixins.py:12(_get_loop)
#     49880    0.025    0.000    0.025    0.000 {method 'discard' of 'set' objects}
#      6941    0.025    0.000    0.106    0.000 tokenization_utils_base.py:1311(special_tokens_map)
#     11875    0.025    0.000    0.133    0.000 _tasks.py:28(__new__)
#     72389    0.025    0.000    0.091    0.000 <frozen _collections_abc>:868(__iter__)
#     23504    0.025    0.000    0.173    0.000 <string>:1(<module>)
#     31369    0.025    0.000    0.081    0.000 base_events.py:551(_asyncgen_firstiter_hook)
#      9963    0.025    0.000    0.119    0.000 completion_sampler.py:63(_wait_if_needed)
#      6998    0.024    0.000    1.458    0.000 http11.py:179(_receive_response_headers)
#      6648    0.024    0.000    0.082    0.000 completion_sampler.py:71(_wait)
#     18409    0.024    0.000    0.030    0.000 tasks.py:142(__del__)
#      3481    0.024    0.000    0.275    0.000 cookiejar.py:1680(extract_cookies)
#     25732    0.023    0.000    0.023    0.000 _state.py:301(_fire_event_triggered_transitions)
#     10337    0.023    0.000    0.517    0.000 _urlparse.py:125(copy_with)
#     15475    0.023    0.000    0.049    0.000 {built-in method _heapq.heappush}
#      6962    0.023    0.000    0.299    0.000 http11.py:351(aclose)
#      3339    0.023    0.000    0.875    0.000 _base_client.py:430(_prepare_url)
#      6642    0.023    0.000    0.204    0.000 completion_sampler.py:51(acquire)
#     33033    0.023    0.000    0.053    0.000 selectors.py:215(_fileobj_lookup)
#      8257    0.023    0.000    0.023    0.000 _receivebuffer.py:67(_extract)
#      6941    0.023    0.000    1.500    0.000 tokenization_utils_base.py:2750(encode)
#      3358    0.023    0.000    0.426    0.000 {method 'throw' of 'coroutine' objects}
#     33033    0.023    0.000    0.030    0.000 selectors.py:21(_fileobj_to_fd)
#       760    0.023    0.000    6.059    0.008 explore_result.py:330(_sequence_to_tensor)
#     49117    0.022    0.000    0.034    0.000 typing.py:1630(__eq__)
#      8274    0.022    0.000    0.022    0.000 _events.py:299(__init__)
#      7572    0.022    0.000   16.126    0.002 _models.py:999(aclose)
# 14038/1937    0.022    0.000    0.029    0.000 completion.py:497(num_prefix_tokens)
#     10603    0.022    0.000    0.194    0.000 completion_sampler.py:384(_remove_prefix_and_unwanted_leading_tokens)
#      5338    0.022    0.000    0.096    0.000 ipaddress.py:1187(_ip_int_from_string)
#     15708    0.022    0.000    0.032    0.000 selector_events.py:750(_process_events)
#      6980    0.021    0.000    0.069    0.000 _utils.py:292(_get_time)
#      1671    0.021    0.000    0.021    0.000 {function socket.close at 0x7510a1f6dd00}
#      9963    0.021    0.000    0.025    0.000 copy.py:231(_keep_alive)
#      6980    0.021    0.000    0.027    0.000 _urlparse.py:106(authority)
#     62858    0.021    0.000    0.021    0.000 _connection.py:212(their_state)
#      6941    0.021    0.000    0.021    0.000 chat_utils.py:122(__init__)
#     12933    0.021    0.000    0.038    0.000 _asyncio.py:1774(release)
#      7427    0.020    0.000    0.078    0.000 selectors.py:365(unregister)
#      9843    0.020    0.000    1.014    0.000 connection_pool.py:361(__aiter__)
#     39286    0.020    0.000    0.040    0.000 coroutines.py:32(iscoroutine)
#      3358    0.020    0.000    0.139    0.000 _asyncio.py:698(__aexit__)
#    185806    0.020    0.000    0.020    0.000 episode.py:377(<lambda>)
#         1    0.020    0.020    0.162    0.162 explore_result.py:270(_write_weights)
#      6941    0.020    0.000    0.025    0.000 tokenization_utils_base.py:2806(_get_padding_truncation_strategies)
#     10733    0.020    0.000    0.034    0.000 _asyncio.py:2266(checkpoint_if_cancelled)
#      3339    0.020    0.000    0.065    0.000 _client.py:376(default_headers)
#      4616    0.020    0.000    0.043    0.000 streams.py:580(readuntil)
#      7028    0.019    0.000    0.069    0.000 {built-in method from_bytes}
#      3481    0.019    0.000    2.568    0.001 decoder.py:333(decode)
#      9963    0.019    0.000    0.019    0.000 {method '__reduce_ex__' of 'object' objects}
#     14476    0.019    0.000    0.019    0.000 {method 'finditer' of 're.Pattern' objects}
#       557    0.019    0.000    0.209    0.000 interface_shared.py:517(_transport_keepalive_failed)
#      5748    0.019    0.000    0.162    0.000 selector_events.py:851(pause_reading)
#      6362    0.019    0.000    0.038    0.000 _receivebuffer.py:77(maybe_extract_at_most)
#       160    0.019    0.000    0.019    0.000 {method 'set_ciphers' of '_ssl._SSLContext' objects}
#     41132    0.018    0.000    0.031    0.000 _utils.py:164(is_list)
#      3358    0.018    0.000    0.463    0.000 connection.py:103(_connect)
#      5338    0.018    0.000    0.116    0.000 ipaddress.py:1286(__init__)
#   189/188    0.018    0.000    1.593    0.008 trainer.py:435(explore)
# 50448/7705    0.018    0.000    0.018    0.000 completion.py:511(root)
#      6941    0.018    0.000    0.018    0.000 chat_utils.py:246(__init__)
#     17405    0.018    0.000    0.032    0.000 _readers.py:43(_obsolete_line_fold)
#      6962    0.018    0.000    0.030    0.000 _decoders.py:238(flush)
#      9843    0.018    0.000    1.106    0.000 _client.py:149(__aiter__)
#     18481    0.018    0.000    0.052    0.000 {built-in method _asyncio._register_task}
#       448    0.018    0.000    7.899    0.018 episode.py:303(_get_sampleable_parents)
#     28338    0.017    0.000    0.026    0.000 completion.py:970(role)
#      4002    0.017    0.000    0.408    0.000 1519314614.py:84(on_sample)
#      6941    0.017    0.000    0.017    0.000 configuration_utils.py:202(__getattribute__)
#      3358    0.017    0.000    0.458    0.000 anyio.py:100(connect_tcp)
#      1679    0.017    0.000    0.080    0.000 _asyncio.py:749(_spawn)
#     67846    0.017    0.000    0.017    0.000 _exceptions.py:7(map_exceptions)
#      3339    0.017    0.000    0.194    0.000 _content.py:176(encode_json)
#      3481    0.017    0.000    2.640    0.001 __init__.py:299(loads)
#    145312    0.017    0.000    0.017    0.000 __init__.py:609(__missing__)
#      3481    0.017    0.000    1.008    0.000 _models.py:1035(extract_cookies)
#     57723    0.017    0.000    0.017    0.000 _headers.py:117(__getitem__)
#     39708    0.016    0.000    0.016    0.000 _connection.py:205(our_state)
#      3358    0.016    0.000    0.025    0.000 base_events.py:100(_ipaddr_info)
#     25747    0.016    0.000    0.016    0.000 {method 'update' of 'dict' objects}
#      3486    0.016    0.000    0.119    0.000 tasks.py:435(wait)
#      6962    0.016    0.000    0.027    0.000 message.py:529(get_all)
#     31324    0.016    0.000    0.016    0.000 __init__.py:1790(isEnabledFor)
#      5748    0.016    0.000    0.214    0.000 selector_events.py:925(_add_reader)
#      3321    0.016    0.000    0.042    0.000 typing_extensions.py:600(__subclasscheck__)
#     12792    0.016    0.000    0.035    0.000 _asyncio.py:1705(__init__)
#      5037    0.016    0.000    0.522    0.000 _asyncio.py:2519(connect_tcp)
#      3481    0.016    0.000    0.120    0.000 cookiejar.py:1599(make_cookies)
#      4167    0.016    0.000    0.016    0.000 {method 'clone' of 'torch._C.TensorBase' objects}
#         2    0.016    0.008    0.016    0.008 {method '__exit__' of 'sqlite3.Connection' objects}
#     10495    0.015    0.000    0.408    0.000 _connection.py:491(send)
#     30688    0.015    0.000    0.027    0.000 explore_result.py:170(<lambda>)
#     20345    0.015    0.000    0.022    0.000 nest_asyncio.py:37(_get_event_loop)
#      7572    0.015    0.000   15.996    0.002 default.py:260(aclose)
#     13882    0.015    0.000    0.022    0.000 utils.py:881(is_list_of)
#     15280    0.015    0.000    0.032    0.000 _asyncio.py:2254(current_time)
#      3481    0.015    0.000    0.042    0.000 _models.py:633(_get_content_decoder)
#      6980    0.015    0.000    0.039    0.000 _connection.py:72(_keep_alive)
#      3481    0.015    0.000    0.024    0.000 _models.py:180(get_list)
#      6941    0.015    0.000    0.015    0.000 tokenization_utils_fast.py:413(set_truncation_and_padding)
#     20899    0.015    0.000    0.030    0.000 llm.py:181(get_tokenizer)
#     11875    0.014    0.000    0.093    0.000 _synchronization.py:216(__exit__)
#      4384    0.014    0.000    0.014    0.000 {built-in method torch.full}
#      5037    0.014    0.000    0.023    0.000 selector_events.py:260(_ensure_fd_no_transport)
#     41246    0.014    0.000    0.014    0.000 _asyncio.py:579(_restart_cancellation_in_parent)
#      3321    0.014    0.000    0.019    0.000 {built-in method _bisect.insort_right}
#      6998    0.014    0.000    0.025    0.000 _auth.py:87(async_auth_flow)
#     24367    0.014    0.000    0.014    0.000 {method 'endswith' of 'bytearray' objects}
#      3339    0.014    0.000    0.027    0.000 _base_client.py:607(default_headers)
#      6962    0.014    0.000    0.202    0.000 _models.py:373(__init__)
#      1110    0.014    0.000    0.121    0.000 vllm.py:152(log_output)
#     12933    0.014    0.000    0.052    0.000 _synchronization.py:80(__aexit__)
#      1679    0.014    0.000    0.050    0.000 selector_events.py:779(__init__)
#      1687    0.014    0.000    0.018    0.000 {built-in method posix.urandom}
# 26536/3874    0.014    0.000    0.065    0.000 completion.py:489(<genexpr>)
#      3481    0.014    0.000    0.070    0.000 request.py:297(request_host)
#     11875    0.014    0.000    0.146    0.000 _synchronization.py:209(__enter__)
#     28249    0.014    0.000    0.014    0.000 futures.py:205(exception)
#      3321    0.013    0.000   21.286    0.006 _base_client.py:571(_process_response_data)
#      3481    0.013    0.000    0.023    0.000 __init__.py:244(detect_encoding)
#      3481    0.013    0.000    2.708    0.001 _models.py:765(json)
#      1679    0.013    0.000    0.187    0.000 selector_events.py:656(_sock_connect)
#     24527    0.013    0.000    0.013    0.000 _compat.py:109(get_model_config)
#     47128    0.013    0.000    0.013    0.000 tasks.py:641(__sleep0)
#     13882    0.013    0.000    0.094    0.000 __init__.py:1120(__init__)
#     36071    0.013    0.000    0.013    0.000 futures.py:91(__del__)
#      5037    0.013    0.000    0.460    0.000 base_events.py:1019(create_connection)
#      7158    0.013    0.000    0.100    0.000 _urlparse.py:303(encode_host)
#     18566    0.012    0.000    0.012    0.000 episode.py:45(<genexpr>)
#      6396    0.012    0.000    0.065    0.000 _synchronization.py:81(__new__)
#     24527    0.012    0.000    0.012    0.000 _compat.py:115(get_model_fields)
#      5194    0.012    0.000    0.130    0.000 tasks.py:412(create_task)
#    175/74    0.012    0.000    3.180    0.043 mailbox.py:249(wait)
#      3358    0.012    0.000    0.238    0.000 selector_events.py:631(sock_connect)
#     15706    0.012    0.000    0.031    0.000 _asyncio.py:2262(checkpoint)
#      3308    0.012    0.000    0.179    0.000 connection.py:168(aclose)
#      5011    0.012    0.000    0.012    0.000 {method 'remove' of 'list' objects}
#     19926    0.012    0.000    0.044    0.000 copy.py:252(<genexpr>)
#      4717    0.012    0.000    0.100    0.000 _synchronization.py:116(setup)
#      6941    0.012    0.000    0.012    0.000 tokenization_utils_base.py:1056(bos_token)
#      3339    0.012    0.000    0.164    0.000 encoder.py:183(encode)
#        49    0.012    0.000    0.015    0.000 _compiler.py:243(_optimize_charset)
#      3481    0.012    0.000    0.030    0.000 _urlparse.py:139(__str__)
#      4514    0.012    0.000    0.023    0.000 tasks.py:710(__init__)
#         2    0.012    0.006    0.027    0.013 explore_result.py:308(_normalize)
#     20899    0.012    0.000    0.015    0.000 llm_engine.py:594(get_tokenizer_group)
#      3481    0.012    0.000    0.050    0.000 request.py:370(_parse)
#      7101    0.012    0.000    0.015    0.000 <frozen _collections_abc>:819(keys)
#      3321    0.012    0.000    0.016    0.000 _base_client.py:1891(make_request_options)
#     41310    0.012    0.000    0.012    0.000 tasks.py:252(cancelling)
#     42797    0.012    0.000    0.012    0.000 {built-in method _asyncio.get_running_loop}
#      4069    0.012    0.000    0.137    0.000 selector_events.py:1009(_read_ready__data_received)
#     17043    0.011    0.000    0.047    0.000 completion.py:745(<genexpr>)
#      9283    0.011    0.000   12.963    0.001 episode.py:51(messages)
#      4002    0.011    0.000    0.012    0.000 completion_sampler.py:176(<genexpr>)
#      4069    0.011    0.000    0.064    0.000 _asyncio.py:1130(data_received)
#      1024    0.011    0.000    7.983    0.008 episode.py:228(sample_completions_v2)
#     10479    0.011    0.000    0.014    0.000 parse.py:676(unquote)
#      3481    0.011    0.000    0.079    0.000 request.py:339(full_url)
#     13882    0.011    0.000    0.014    0.000 tokenization_utils_base.py:4076(_eventual_warn_about_too_long_sequence)
#      6678    0.011    0.000    0.059    0.000 <frozen _collections_abc>:992(setdefault)
# ...
#         1    0.000    0.000    0.000    0.000 threading.py:975(start)
#        39    0.000    0.000    0.000    0.000 _generate_schema.py:2070(<lambda>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(__enter__)
#        24    0.000    0.000    0.000    0.000 inspect.py:2808(kind)
#         6    0.000    0.000    0.000    0.000 core_schema.py:3750(definitions_schema)
#        15    0.000    0.000    0.000    0.000 _core_utils.py:469(can_be_inlined)
#         1    0.000    0.000    0.000    0.000 ipkernel.py:768(init_closure)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#         3    0.000    0.000    0.000    0.000 _loader.py:21(get_plugins)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:124(setdefault)
#         6    0.000    0.000    0.000    0.000 _utils.py:94(is_valid_identifier)
#         1    0.000    0.000    0.000    0.000 queues.py:33(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:3343(signature)
#         1    0.000    0.000    0.000    0.000 base_events.py:2013(set_debug)
#         1    0.000    0.000    0.000    0.000 base_events.py:546(_asyncgen_finalizer_hook)
#         3    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 _typing_extra.py:321(_eval_type)
#        20    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         4    0.000    0.000    0.000    0.000 builtins.py:87(iter)
#         2    0.000    0.000    0.000    0.000 _typing_extra.py:222(merge_cls_and_parent_ns)
#         3    0.000    0.000    0.000    0.000 _typing_extra.py:249(eval_type_lenient)
#         1    0.000    0.000    0.000    0.000 parse.py:413(_splitnetloc)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.scandir}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.close}
#         4    0.000    0.000    0.000    0.000 core_schema.py:630(float_schema)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 random.py:126(__init__)
#         6    0.000    0.000    0.000    0.000 _signature.py:16(_field_name_for_signature)
#        22    0.000    0.000    0.000    0.000 inspect.py:2796(name)
#         2    0.000    0.000    0.000    0.000 utils.py:187(disable_on_exception)
#         3    0.000    0.000    0.001    0.000 _discriminated_union.py:37(apply_discriminators)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         2    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#        26    0.000    0.000    0.000    0.000 _typing_extra.py:574(is_zoneinfo_type)
#         5    0.000    0.000    0.000    0.000 <frozen _collections_abc>:182(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 util.py:174(register_after_fork)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:372(release)
#         1    0.000    0.000    0.000    0.000 synchronize.py:217(Condition)
#         1    0.000    0.000    0.000    0.000 inspect.py:2919(kwargs)
#         3    0.000    0.000    0.000    0.000 utils.py:152(wrapper_setattr)
#         9    0.000    0.000    0.000    0.000 {method 'is_dir' of 'posix.DirEntry' objects}
#        15    0.000    0.000    0.000    0.000 _generate_schema.py:333(tail)
#         1    0.000    0.000    0.000    0.000 _base.py:393(done)
#         6    0.000    0.000    0.000    0.000 inspect.py:3076(<genexpr>)
#         1    0.000    0.000    0.000    0.000 synchronize.py:121(_make_name)
#         2    0.000    0.000    0.000    0.000 _utils.py:85(is_model_class)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:221(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:193(__init__)
#        11    0.000    0.000    0.000    0.000 _generate_schema.py:789(_unpack_refs_defs)
#        15    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:670(_classify_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:162(__enter__)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:115(_type_has_config)
#         3    0.000    0.000    0.000    0.000 _typing_extra.py:263(eval_type_backport)
#         1    0.000    0.000    0.000    0.000 futures.py:383(_set_state)
#        15    0.000    0.000    0.000    0.000 _generate_schema.py:2564(__init__)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         3    0.000    0.000    0.000    0.000 core_schema.py:1206(literal_schema)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread._set_sentinel}
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:491(_verbose_message)
#         1    0.000    0.000    0.000    0.000 threading.py:1251(daemon)
#        18    0.000    0.000    0.000    0.000 _base_client.py:653(_parse_retry_after_header)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1524(find_spec)
#         1    0.000    0.000    0.000    0.000 threading.py:1038(_set_ident)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1226(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:232(__init__)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:327(_model_config)
#         1    0.000    0.000    0.000    0.000 utils.py:156(__init__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#        18    0.000    0.000    0.000    0.000 _core_utils.py:467(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 _core_utils.py:65(is_function_with_inner_schema)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:82(remove)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1222(__enter__)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:323(_defer_build)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:74(__new__)
#         1    0.000    0.000    0.000    0.000 threading.py:1042(_set_native_id)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:632(cached)
#         1    0.000    0.000    0.000    0.000 _base.py:428(result)
#        12    0.000    0.000    0.000    0.000 _core_utils.py:136(define_expected_missing_refs)
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:2516(__init__)
#         3    0.000    0.000    0.000    0.000 _typing_extra.py:296(_eval_type_backport)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         2    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:420(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:982(find_spec)
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:79(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:102(find_spec)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:100(_getattr_no_parents)
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:703(_validate_timestamp_pyc)
#         6    0.000    0.000    0.000    0.000 inspect.py:3089(parameters)
#         4    0.000    0.000    0.000    0.000 inspect.py:378(isfunction)
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fstat}
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:480(_call_with_frames_removed)
#         1    0.000    0.000    0.000    0.000 typing.py:1603(__repr__)
#         1    0.000    0.000    0.000    0.000 _base.py:383(cancelled)
#         1    0.000    0.000    0.000    0.000 context.py:237(get_context)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:647(_check_name_wrapper)
#         3    0.000    0.000    0.000    0.000 <frozen os>:808(getenv)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         1    0.000    0.000    0.000    0.000 <frozen genericpath>:99(samestat)
#         4    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'send' of 'async_generator_athrow' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method math.floor}
#         1    0.000    0.000    0.000    0.000 functools.py:979(__get__)
#         2    0.000    0.000    0.000    0.000 threading.py:1236(daemon)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         1    0.000    0.000    0.000    0.000 base_events.py:1995(_set_coroutine_origin_tracking)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:445(cb)
#         2    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:110(remove)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1128(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 explore_result.py:36(<lambda>)
#         1    0.000    0.000    0.000    0.000 import_hooks.py:233(find_spec)
#         1    0.000    0.000    0.000    0.000 threading.py:1356(_make_invoke_excepthook)
#         2    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:115(discard)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1206(path_stats)
#         1    0.000    0.000    0.000    0.000 threading.py:839(_newname)
#         1    0.000    0.000    0.000    0.000 _config.py:278(prepare_config)
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio._set_running_loop}
#         2    0.000    0.000    0.000    0.000 _mock_val_ser.py:142(<lambda>)
#         6    0.000    0.000    0.000    0.000 fields.py:580(rebuild_annotation)
#         1    0.000    0.000    0.000    0.000 synchronize.py:90(_make_methods)
#         1    0.000    0.000    0.000    0.000 _base.py:463(exception)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.find_frozen}
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:405(_types_namespace)
#         3    0.000    0.000    0.000    0.000 _typing_extra.py:95(literal_values)
#         1    0.000    0.000    0.000    0.000 synchronize.py:328(Event)
#         1    0.000    0.000    0.000    0.000 threading.py:1485(current_thread)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1473(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 synchronize.py:130(Semaphore)
#         1    0.000    0.000    0.000    0.000 queues.py:47(_init)
#         1    0.000    0.000    0.000    0.000 futures.py:389(_call_check_cancel)
#         1    0.000    0.000    0.000    0.000 typing.py:237(_type_repr)
#         2    0.000    0.000    0.000    0.000 _typing_extra.py:115(annotated_type)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         3    0.000    0.000    0.000    0.000 _config.py:208(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:185(_path_abspath)
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 util.py:48(debug)
#         1    0.000    0.000    0.000    0.000 parse.py:421(_checknetloc)
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:330(__init__)
#         1    0.000    0.000    0.000    0.000 type_adapter.py:305(validator)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:180(_path_isabs)
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:729(is_running)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:599(__init__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:166(Lock)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         1    0.000    0.000    0.000    0.000 context.py:197(get_start_method)
#         2    0.000    0.000    0.000    0.000 _model_construction.py:724(unpack_lenient_weakvaluedict)
#         1    0.000    0.000    0.000    0.000 notebook.py:272(close)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.daemon_threads_allowed}
#         1    0.000    0.000    0.000    0.000 synchronize.py:149(BoundedSemaphore)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of 'posix.ScandirIterator' objects}
#         2    0.000    0.000    0.000    0.000 _utils.py:290(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2888(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Task' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:398(__get_result)
#         3    0.000    0.000    0.000    0.000 _generate_schema.py:2583(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:2804(annotation)
#         1    0.000    0.000    0.000    0.000 synchronize.py:191(RLock)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1157(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:412(__init__)
#         1    0.000    0.000    0.000    0.000 process.py:37(current_process)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:570(<lambda>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:158(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:71(_relax_case)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:653(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1182(get_filename)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:990(create_module)

# %%
trainer.explore_results[-1].exceptions
# Out:
# [httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout('')]

# %%
await trainer.train(iterations=1, verbosity=2)
# Out:
# Starting 1 vLLM servers...
# $ vllm serve NousResearch/Hermes-2-Theta-Llama-3-8B --port=8001 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.9 --max-model-len=16384 --max-num-seqs=2048 --max-num-batched-tokens=16384 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=32 --api-key=default
# INFO 12-14 20:11:02 api_server.py:528] vLLM API server version 0.6.3.post1
# INFO 12-14 20:11:02 api_server.py:529] args: Namespace(subparser='serve', model_tag='NousResearch/Hermes-2-Theta-Llama-3-8B', config='', host=None, port=8001, uvicorn_log_level='info', allow_credentials=False, allowed_origins=['*'], allowed_methods=['*'], allowed_headers=['*'], api_key='default', lora_modules=None, prompt_adapters=None, chat_template=None, response_role='assistant', ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, ssl_cert_reqs=0, root_path=None, middleware=[], return_tokens_as_token_ids=True, disable_frontend_multiprocessing=False, enable_auto_tool_choice=False, tool_call_parser=None, tool_parser_plugin='', model='NousResearch/Hermes-2-Theta-Llama-3-8B', tokenizer=None, skip_tokenizer_init=False, revision=None, code_revision=None, tokenizer_revision=None, tokenizer_mode='auto', trust_remote_code=False, download_dir=None, load_format='auto', config_format=<ConfigFormat.AUTO: 'auto'>, dtype='auto', kv_cache_dtype='auto', quantization_param_path=None, max_model_len=16384, guided_decoding_backend='outlines', distributed_executor_backend=None, worker_use_ray=False, pipeline_parallel_size=1, tensor_parallel_size=1, max_parallel_loading_workers=None, ray_workers_use_nsight=False, block_size=32, enable_prefix_caching=True, disable_sliding_window=False, use_v2_block_manager=False, num_lookahead_slots=0, seed=0, swap_space=32.0, cpu_offload_gb=0, gpu_memory_utilization=0.9, num_gpu_blocks_override=None, max_num_batched_tokens=16384, max_num_seqs=2048, max_logprobs=20, disable_log_stats=False, quantization=None, rope_scaling=None, rope_theta=None, enforce_eager=True, max_context_len_to_capture=None, max_seq_len_to_capture=8192, disable_custom_all_reduce=False, tokenizer_pool_size=0, tokenizer_pool_type='ray', tokenizer_pool_extra_config=None, limit_mm_per_prompt=None, mm_processor_kwargs=None, enable_lora=False, max_loras=1, max_lora_rank=16, lora_extra_vocab_size=256, lora_dtype='auto', long_lora_scaling_factors=None, max_cpu_loras=None, fully_sharded_loras=False, enable_prompt_adapter=False, max_prompt_adapters=1, max_prompt_adapter_token=0, device='auto', num_scheduler_steps=1, multi_step_stream_outputs=True, scheduler_delay_factor=0.0, enable_chunked_prefill=None, speculative_model=None, speculative_model_quantization=None, num_speculative_tokens=None, speculative_disable_mqa_scorer=False, speculative_draft_tensor_parallel_size=None, speculative_max_model_len=None, speculative_disable_by_batch_size=None, ngram_prompt_lookup_max=None, ngram_prompt_lookup_min=None, spec_decoding_acceptance_method='rejection_sampler', typical_acceptance_sampler_posterior_threshold=None, typical_acceptance_sampler_posterior_alpha=None, disable_logprobs_during_spec_decoding=None, model_loader_extra_config=None, ignore_patterns=[], preemption_mode='swap', served_model_name=None, qlora_adapter_name_or_path=None, otlp_traces_endpoint=None, collect_detailed_traces=None, disable_async_output_proc=False, override_neuron_config=None, scheduling_policy='fcfs', disable_log_requests=True, max_log_len=None, disable_fastapi_docs=False, dispatch_function=<function serve at 0x7dee694a4fe0>)
# INFO 12-14 20:11:02 api_server.py:166] Multiprocessing frontend to use ipc:///tmp/7121d850-eb84-483c-9c14-56fc454c0657 for IPC Path.
# INFO 12-14 20:11:02 api_server.py:179] Started engine process with PID 33232
# WARNING 12-14 20:11:03 config.py:1786] User-specified max_model_len (16384) is greater than the derived max_model_len (max_position_embeddings=8192 or model_max_length=None in model's config.json). This may lead to incorrect model outputs or CUDA errors. Make sure the value is correct and within the model context size.
# WARNING 12-14 20:11:08 config.py:1786] User-specified max_model_len (16384) is greater than the derived max_model_len (max_position_embeddings=8192 or model_max_length=None in model's config.json). This may lead to incorrect model outputs or CUDA errors. Make sure the value is correct and within the model context size.
# WARNING 12-14 20:11:08 arg_utils.py:1019] [DEPRECATED] Block manager v1 has been removed, and setting --use-v2-block-manager to True or False has no effect on vLLM behavior. Please remove --use-v2-block-manager in your engine argument. If your use case is not supported by SelfAttnBlockSpaceManager (i.e. block manager v2), please file an issue with detailed information.
# WARNING 12-14 20:11:08 config.py:395] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# WARNING 12-14 20:11:13 arg_utils.py:1019] [DEPRECATED] Block manager v1 has been removed, and setting --use-v2-block-manager to True or False has no effect on vLLM behavior. Please remove --use-v2-block-manager in your engine argument. If your use case is not supported by SelfAttnBlockSpaceManager (i.e. block manager v2), please file an issue with detailed information.
# WARNING 12-14 20:11:13 config.py:395] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# INFO 12-14 20:11:13 llm_engine.py:237] Initializing an LLM engine (v0.6.3.post1) with config: model='NousResearch/Hermes-2-Theta-Llama-3-8B', speculative_config=None, tokenizer='NousResearch/Hermes-2-Theta-Llama-3-8B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=NousResearch/Hermes-2-Theta-Llama-3-8B, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=True, use_async_output_proc=False, use_cached_outputs=True, mm_processor_kwargs=None)
# INFO 12-14 20:11:15 model_runner.py:1056] Starting to load model NousResearch/Hermes-2-Theta-Llama-3-8B...
# INFO 12-14 20:11:15 weight_utils.py:243] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:00<00:00,  4.05it/s]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:01<00:01,  1.56it/s]
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:02<00:00,  1.25it/s]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.15it/s]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.28it/s]
# INFO 12-14 20:11:19 model_runner.py:1067] Loading model weights took 14.9595 GB
# INFO 12-14 20:11:20 gpu_executor.py:122] # GPU blocks: 11578, # CPU blocks: 8192
# INFO 12-14 20:11:20 gpu_executor.py:126] Maximum concurrency for 16384 tokens per request: 22.61x
# INFO 12-14 20:11:37 api_server.py:232] vLLM to use /tmp/tmp3n2vbgld as PROMETHEUS_MULTIPROC_DIR
# WARNING 12-14 20:11:37 serving_embedding.py:199] embedding_mode is False. Embedding API will not work.
# INFO 12-14 20:11:37 launcher.py:19] Available routes are:
# INFO 12-14 20:11:37 launcher.py:27] Route: /openapi.json, Methods: HEAD, GET
# INFO 12-14 20:11:37 launcher.py:27] Route: /docs, Methods: HEAD, GET
# INFO 12-14 20:11:37 launcher.py:27] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# INFO 12-14 20:11:37 launcher.py:27] Route: /redoc, Methods: HEAD, GET
# INFO 12-14 20:11:37 launcher.py:27] Route: /health, Methods: GET
# INFO 12-14 20:11:37 launcher.py:27] Route: /tokenize, Methods: POST
# INFO 12-14 20:11:37 launcher.py:27] Route: /detokenize, Methods: POST
# INFO 12-14 20:11:37 launcher.py:27] Route: /v1/models, Methods: GET
# INFO 12-14 20:11:37 launcher.py:27] Route: /version, Methods: GET
# INFO 12-14 20:11:37 launcher.py:27] Route: /v1/chat/completions, Methods: POST
# INFO 12-14 20:11:37 launcher.py:27] Route: /v1/completions, Methods: POST
# INFO 12-14 20:11:37 launcher.py:27] Route: /v1/embeddings, Methods: POST
# INFO:     Started server process [33152]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on socket ('0.0.0.0', 8001) (Press CTRL+C to quit)
# INFO:     127.0.0.1:47054 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# vLLM server started succesfully. Logs can be found at ./logs/vllm.log
# val: 0episode [00:00, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl33/config.yaml
# DEBUG:torchtune.utils._logging:Training is not distributed. If you want to train on multiple GPUs and are using the tune CLI, specify --nnodes 1 and --nproc_per_node [num_gpus]
# INFO:torchtune.utils._logging:Running FullFinetuneRecipe with resolved config:
#
# batch_size: 1
# checkpointer:
#   _component_: torchtune.training.checkpointing._checkpointer.FullModelHFCheckpointer
#   checkpoint_dir: /home/ubuntu/.cache/huggingface/hub/models--NousResearch--Hermes-2-Theta-Llama-3-8B/snapshots/57a73110702e7b05ba3f39fef36297454c680725
#   checkpoint_files:
#   - /home/ubuntu/.cache/huggingface/hub/models--NousResearch--Hermes-2-Theta-Llama-3-8B/snapshots/57a73110702e7b05ba3f39fef36297454c680725/model-00004-of-00004.safetensors
#   - /home/ubuntu/.cache/huggingface/hub/models--NousResearch--Hermes-2-Theta-Llama-3-8B/snapshots/57a73110702e7b05ba3f39fef36297454c680725/model-00001-of-00004.safetensors
#   - /home/ubuntu/.cache/huggingface/hub/models--NousResearch--Hermes-2-Theta-Llama-3-8B/snapshots/57a73110702e7b05ba3f39fef36297454c680725/model-00002-of-00004.safetensors
#   - /home/ubuntu/.cache/huggingface/hub/models--NousResearch--Hermes-2-Theta-Llama-3-8B/snapshots/57a73110702e7b05ba3f39fef36297454c680725/model-00003-of-00004.safetensors
#   model_type: LLAMA3
#   output_dir: /home/ubuntu/atreides/experiments/models/rl33
#   recipe_checkpoint: null
# compile: false
# custom_sharded_layers:
# - tok_embeddings
# - output
# dataset:
#   _component_: lib.rl.pack.PackedDataset
#   dir: /home/ubuntu/atreides/experiments/models/rl33/tensors
#   num_sequences: 40
#   sequence_length: 16384
# device: cuda
# dtype: bf16
# enable_activation_checkpointing: true
# enable_activation_offloading: false
# epochs: 1
# gradient_accumulation_steps: 1
# log_every_n_steps: 1
# log_peak_memory_stats: true
# loss:
#   _component_: lib.rl.ppo.PPOLoss
#   clip_epsilon: 0.2
#   entropy_coef: 0.0
#   entropy_target: 0.75
#   entropy_target_coef: 0.15
#   kl_coef: 0.25
#   normalize_advantages: false
#   normalize_values: false
#   policy_coef: 0.0
#   tanh_log_policy_coef: 0.9
#   unclipped_policy_coef: 0.0
#   value_coef: 0.0
#   weighted_ce_coef: 0.0
#   weighted_entropy_coef: 0.1
#   weighted_kl_coef: 0.0
# max_steps_per_epoch: 32
# metric_logger:
#   _component_: torchtune.training.metric_logging.WandBLogger
#   id: rl33
#   name: rl33
#   resume: allow
# model:
#   _component_: torchtune.models.llama3_1._model_builders.llama3_1_8b
# num_output_chunks: 4
# optimizer:
#   _component_: torch.optim.AdamW
#   fused: true
#   lr: 4.0e-06
# optimizer_in_bwd: false
# resume_from_checkpoint: false
# seed: 42
# shuffle: true
#
# INFO:torchtune.utils._logging:Hint: enable_activation_checkpointing is True, but enable_activation_offloading isn't. Enabling activation offloading should reduce memory further.
# DEBUG:torchtune.utils._logging:Setting manual seed to local seed 42. Local seed is seed + rank = 42 + 0
# wandb: Currently logged in as: bradhilton. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /home/ubuntu/atreides/experiments/wandb/run-20241214_201721-rl33
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Resuming run rl33
# wandb: ⭐️ View project at https://wandb.ai/bradhilton/torchtune
# wandb: 🚀 View run at https://wandb.ai/bradhilton/torchtune/runs/rl33
# INFO:torchtune.utils._logging:Logging /home/ubuntu/.cache/huggingface/hub/models--NousResearch--Hermes-2-Theta-Llama-3-8B/snapshots/57a73110702e7b05ba3f39fef36297454c680725/torchtune_config.yaml to W&B under Files
# INFO:torchtune.utils._logging:FSDP is enabled. Instantiating model and loading checkpoint on Rank 0 ...
# INFO:torchtune.utils._logging:Instantiating model and loading checkpoint took 2.97 secs
# INFO:torchtune.utils._logging:Memory stats after model init:
# 	GPU peak memory allocation: 15.02 GiB
# 	GPU peak memory reserved: 15.14 GiB
# 	GPU peak memory active: 15.02 GiB
# INFO:torchtune.utils._logging:Optimizer is initialized.
# INFO:torchtune.utils._logging:Loss is initialized.
# INFO:torchtune.utils._logging:Dataset and Sampler are initialized.
# WARNING:torchtune.utils._logging: Profiling disabled.
# INFO:torchtune.utils._logging: Profiler config after instantiation: {'enabled': False}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 await trainer.train(iterations=1, verbosity=2)
#
# File ~/atreides/experiments/lib/rl/trainer.py:281, in Trainer.train(self, iterations, test, verbosity)
#     276 for _ in range(iterations):
#     277     _, result = await asyncio.gather(
#     278         self.eval("val", 0, return_exceptions=True, verbosity=verbosity),
#     279         self.explore(1, return_exceptions=True, verbosity=verbosity),
#     280     )
# --> 281     await self.tune(result, verbosity=verbosity)
#     282 _, _ = await asyncio.gather(
#     283     self.eval("val", 0, return_exceptions=True, verbosity=verbosity),
#     284     self.eval("test", 1, verbosity=verbosity) if test else asyncio.sleep(0),
#     285 )
#
# File ~/atreides/experiments/lib/rl/trainer.py:680, in Trainer.tune(self, result, verbosity)
#     673     self.tune_recipe_config.reference_checkpointer = (
#     674         self._get_checkpointer_config(
#     675             await self._get_checkpoint_dir(self.reference_model),
#     676             checkpoint_files=self.reference_model_checkpoint_files,
#     677         )
#     678     )
#     679 if self.tune_run:
# --> 680     await self._tune_run(verbosity)
#     681 else:
#     682     cleanup_before_training()
#
# File ~/atreides/experiments/lib/rl/trainer.py:741, in Trainer._tune_run(self, verbosity)
#     739 if process.stderr:
#     740     tasks.append(asyncio.create_task(log_output(process.stderr, sys.stderr)))
# --> 741 _ = await asyncio.gather(*tasks)
#
# File ~/atreides/experiments/lib/rl/trainer.py:716, in Trainer._tune_run.<locals>.log_output(stream, io)
#     714 while True:
#     715     try:
# --> 716         chunk = await stream.read(4096)
#     717         if not chunk:
#     718             break
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/asyncio/streams.py:713, in StreamReader.read(self, n)
#     710     return b''.join(blocks)
#     712 if not self._buffer and not self._eof:
# --> 713     await self._wait_for_data('read')
#     715 # This will work right even if buffer is less than n bytes
#     716 data = bytes(memoryview(self._buffer)[:n])
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/asyncio/streams.py:545, in StreamReader._wait_for_data(self, func_name)
#     543 self._waiter = self._loop.create_future()
#     544 try:
# --> 545     await self._waiter
#     546 finally:
#     547     self._waiter = None
#
# CancelledError:

# %%
trainer.explore_results[0].exceptions
# Out:
# [httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout('')]

# %%
trainer.eval_exceptions["val"]
# Out:
# [httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout(''),
#  httpx.ReadTimeout('')]

# %%
await trainer.train(iterations=4, verbosity=1)
# Out:
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# Early stopping val evaluation due to expired patience (0 remaining episodes x 15 patience per episode = 0 seconds)
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl29/config.yaml
# 1|185|Loss: 0.0443: 100%|██████████| 185/185 [51:20<00:00, 16.53s/it, entropy=0.6468, entropy_target=0.1032, kl_div=0.0934, policy=-0.0291, tanh_log_policy=0.0026, unclipped_policy=-0.0323, value=1.9048, weighted_ce=0.0188, weighted_entropy=-0.0312, weighted_kl_div=-0.0066]
# Saved iteration 10 model files to /home/ubuntu/atreides/experiments/models/rl29/0010
# Starting 1 vLLM servers...
# $ vllm serve /home/ubuntu/atreides/experiments/models/rl29/0010 --port=8000 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.9 --max-model-len=16384 --max-num-seqs=512 --max-num-batched-tokens=65536 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=32 --api-key=default
# vLLM servers started succesfully. Logs can be found at ./logs/vllm.log
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl29/config.yaml
# 1|101|Loss: 0.0376: 100%|██████████| 101/101 [28:08<00:00, 16.61s/it, entropy=0.6686, entropy_target=0.0814, kl_div=0.0844, policy=-0.0282, tanh_log_policy=0.0022, unclipped_policy=-0.0298, value=1.0489, weighted_ce=0.0084, weighted_entropy=-0.0236, weighted_kl_div=-0.0026]
# Saved iteration 11 model files to /home/ubuntu/atreides/experiments/models/rl29/0011
# Starting 1 vLLM servers...
# $ vllm serve /home/ubuntu/atreides/experiments/models/rl29/0011 --port=8001 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.9 --max-model-len=16384 --max-num-seqs=512 --max-num-batched-tokens=65536 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=32 --api-key=default
# vLLM servers started succesfully. Logs can be found at ./logs/vllm.log
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl29/config.yaml
# 1|127|Loss: 0.0216: 100%|██████████| 128/128 [35:40<00:00, 16.64s/it, entropy=0.7464, entropy_target=0.0036, kl_div=0.0928, policy=-0.0009, tanh_log_policy=-0.0017, unclipped_policy=-0.0051, value=5.0248, weighted_ce=-0.0075, weighted_entropy=0.0059, weighted_kl_div=0.0063]
# Saved iteration 12 model files to /home/ubuntu/atreides/experiments/models/rl29/0012
# Starting 1 vLLM servers...
# $ vllm serve /home/ubuntu/atreides/experiments/models/rl29/0012 --port=8001 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.9 --max-model-len=16384 --max-num-seqs=512 --max-num-batched-tokens=65536 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=32 --api-key=default
# vLLM servers started succesfully. Logs can be found at ./logs/vllm.log
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl29/config.yaml
# 1|143|Loss: 0.0361: 100%|██████████| 143/143 [39:47<00:00, 16.62s/it, entropy=0.6294, entropy_target=0.1206, kl_div=0.0729, policy=0.0015, tanh_log_policy=-0.0001, unclipped_policy=0.0004, value=1.1154, weighted_ce=-0.0008, weighted_entropy=0.0014, weighted_kl_div=0.0005]
# Saved iteration 13 model files to /home/ubuntu/atreides/experiments/models/rl29/0013
# Starting 1 vLLM servers...
# $ vllm serve /home/ubuntu/atreides/experiments/models/rl29/0013 --port=8000 --block-size=32 --disable-log-requests --enable-prefix-caching --enforce-eager --gpu-memory-utilization=0.9 --max-model-len=16384 --max-num-seqs=512 --max-num-batched-tokens=65536 --preemption-mode=swap --return-tokens-as-token-ids --swap-space=32 --api-key=default
# vLLM servers started succesfully. Logs can be found at ./logs/vllm.log
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# Early stopping val evaluation due to expired patience (0 remaining episodes x 15 patience per episode = 0 seconds)

# %%
await trainer.train(iterations=12, verbosity=1)
# Out:
# val:   0%|          | 0/64 [00:00<?, ?episode/s]
# explore:   0%|          | 0/64 [00:00<?, ?episode/s]
# Early stopping val evaluation due to expired patience (0 remaining episodes x 15 patience per episode = 0 seconds)
# Early stopping exploration due to expired patience (0 remaining episodes x 5 patience per episode = 0 seconds)
# $ tune run lib.rl.recipe.TuneRecipe --config /home/ubuntu/atreides/experiments/models/rl29/config.yaml
# 1|100|Loss: 0.0312:  45%|████▌     | 100/222 [27:53<33:44, 16.59s/it, entropy=0.8347, entropy_target=0.0847, kl_div=0.0736, policy=-0.0045, tanh_log_policy=-0.0004, unclipped_policy=-0.0056, value=2.1442, weighted_ce=0.0013, weighted_entropy=-0.0045, weighted_kl_div=-0.0014]
